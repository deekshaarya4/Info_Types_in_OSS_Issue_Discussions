# %% [markdown]
# # Nested Leave-One-Issue-Out Cross Validation For Logistic Regression On Textual Features using SMOTE

# %%
import numpy as np
import pandas as pd
import xlrd as xl
from pandas import ExcelWriter
from pandas import ExcelFile
import pprint
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
import re
import pickle
from operator import itemgetter
import time, datetime
from functools import partial, update_wrapper
from openpyxl import load_workbook

from sklearn.feature_extraction.text import TfidfVectorizer

from imblearn.over_sampling import SMOTE

from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as Imb_Pipeline

from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate, LeaveOneGroupOut
from sklearn.metrics import precision_recall_fscore_support, classification_report, accuracy_score, make_scorer, confusion_matrix

pp = pprint.PrettyPrinter(indent=4)

## Ignore warnings
import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn
np.warnings.filterwarnings('ignore')

# %% [markdown]
# #### Use spaCy parser for word tokenization of a sentence:

# %%
import spacy
eng = spacy.load('en')
from spacy.lang.en import English
parser = English()

# %% [markdown]
# #### Define stopwords as punctuation + common contractions:

# %%
from string import punctuation
from nltk.corpus import stopwords

stop_words = list(punctuation) + ["'s","'m","n't","'re","-","'ll",'...'] #+ stopwords.words('english')

# %% [markdown]
# #### Code to lemmatize and tokenize:

# %%
def get_lemma(item):
    return WordNetLemmatizer().lemmatize(item)

def tokenize(line):
    line_tokens = []
    tokens = parser(line)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            line_tokens.append('URL')
        elif token.orth_.startswith('@'):
            line_tokens.append('SCREEN_NAME')
        elif str(token) not in stop_words:
            line_tokens.append(get_lemma(token.lower_))
    return line_tokens

# %% [markdown]
# #### Read from the pickled file:

# %%
all_data = pd.read_pickle('../../data/text_conv_data.pkl')

print("Size of corpus: "+str(len(all_data)))
# Out:
# Size of corpus: 4330

# %%
X = all_data['Text Content'].values
y = all_data['Code'].values
doc_groups = all_data['Document'].values

print("Number of unique labels: "+str(len(set(y))))

labels = list(set(y))
labels.sort()

pp.pprint(labels)
# Out:
# Number of unique labels: 13
# [   'Action on Issue',
#     'Bug Reproduction',
#     'Contribution and Commitment',
#     'Expected Behaviour',
#     'Investigation and Exploration',
#     'Social Conversation',
#     'Motivation',
#     'Observed Bug Behaviour',
#     'Potential New Issues and Requests',
#     'Solution Discussion',
#     'Task Progress',
#     'Solution Usage',
#     'Workarounds']

# %% [markdown]
# # Nested Cross-Validation on Logistic Regression:

# %%
# To be used within GridSearch
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# To be used in outer CV
# outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
logo = LeaveOneGroupOut()
outer_cv = logo.split(X,y,groups=doc_groups)

# %% [markdown]
# ## Define Pipelines
#
# 1. Pipeline2: tfidf + SMOTE

# %%
pipeline2 = Imb_Pipeline([
    ('vect', TfidfVectorizer(tokenizer=tokenize)),
    ('smote', SMOTE()),
    ('clf', LogisticRegression())
])

### Hyperparameter to search
parameters = {
    'vect__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams
    'clf__C': (0.01, 0.1, 1, 10),
}

# %% [markdown]
# ## Nested Cross Validation using GridSearch

# %%
### Define and create the scoring functions

def score_func(y_true, y_pred, score_index, i):
    return(precision_recall_fscore_support(y_true,y_pred,labels=labels)[score_index][i])

def avg_score(y_true, y_pred, score_index):
    return precision_recall_fscore_support(y_true,y_pred,average='weighted')[score_index]

def sum_support(y_true, y_pred):
    return len(y_true)

### Create partials for each of the metrics returned
score_funcs = {v: partial(score_func, score_index=k) for k, v in {0:'precision',1:'recall',2:'fscore',3:'support'}.items()}
prec_score = partial(score_func, score_index=0)
update_wrapper(prec_score,score_func)
rec_score = partial(score_func, score_index=1)
update_wrapper(rec_score,score_func)
f_score = partial(score_func, score_index=2)
update_wrapper(f_score,score_func)
support_score = partial(score_func, score_index=3)
update_wrapper(support_score,score_func)

### Create a callable scoring function for each of the metrics for each classification label
scorer = {}
for label_id in range(0,13):
    scorer['label'+str(label_id)+'_precision'] = make_scorer(prec_score, i=label_id)
    scorer['label'+str(label_id)+'_recall'] = make_scorer(rec_score, i=label_id)
    scorer['label'+str(label_id)+'_fscore'] = make_scorer(f_score, i=label_id)
    scorer['label'+str(label_id)+'_support'] = make_scorer(support_score, i=label_id)

### Create a callable scoring function for avg/total of the metrics across classification labels
scorer['avg_precision'] = make_scorer(avg_score,score_index=0)
scorer['avg_recall'] = make_scorer(avg_score,score_index=1)
scorer['avg_fscore'] = make_scorer(avg_score,score_index=2)
scorer['total_support'] = make_scorer(sum_support)

### Perform Nested cross-validation on Pipeline2
start = time.time()
clf2 = GridSearchCV(pipeline2, parameters, cv=inner_cv, scoring='f1_weighted')
clf2_results = cross_validate(clf2, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline2 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))
# Out:
# Completed Pipeline2 scenario in 20:10:37.328375

# %% [markdown]
# # Display and Save Training and Testing Results for each Fold:

# %% [markdown]
# ## Pipeline2 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../../results/LOIO.xlsx')
book = load_workbook('../../results/LOIO.xlsx')
writer = pd.ExcelWriter('../../results/LOIO.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,15):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf2_results['train_label'+str(label_id)+'_precision'][i],clf2_results['train_label'+str(label_id)+'_recall'][i],clf2_results['train_label'+str(label_id)+'_fscore'][i],clf2_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf2_results['test_label'+str(label_id)+'_precision'][i],clf2_results['test_label'+str(label_id)+'_recall'][i],clf2_results['test_label'+str(label_id)+'_fscore'][i],clf2_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf2_results['train_avg_precision'][i],clf2_results['train_avg_recall'][i],clf2_results['train_avg_fscore'][i],clf2_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf2_results['test_avg_precision'][i],clf2_results['test_avg_recall'][i],clf2_results['test_avg_fscore'][i],clf2_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'LTS',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'LTS',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'LTS',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['LTS_train_'+str(i)] = train_report
    result_dict['LTS_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      53.0
# Bug Reproduction                        0.98    0.97      0.97     245.0
# Contribution and Commitment             0.97    1.00      0.98      58.0
# Expected Behaviour                      0.98    0.98      0.98     119.0
# Investigation and Exploration           1.00    0.97      0.98     377.0
# Social Conversation                     1.00    0.99      0.99     546.0
# Motivation                              1.00    1.00      1.00     261.0
# Observed Bug Behaviour                  0.73    0.97      0.83     131.0
# Potential New Issues and Requests       0.99    1.00      0.99     208.0
# Solution Discussion                     1.00    0.97      0.98    1338.0
# Task Progress                           0.87    1.00      0.93     104.0
# Solution Usage                          0.99    0.97      0.98     368.0
# Workarounds                             0.99    0.98      0.98      86.0
# Avg/Total                               0.98    0.98      0.98    3894.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.50    0.25      0.33       8.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.67    0.32      0.43      25.0
# Expected Behaviour                      0.00    0.00      0.00       5.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.93    0.76      0.84     252.0
# Motivation                              0.38    0.22      0.28      27.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.11    0.05      0.06      22.0
# Solution Discussion                     0.34    0.59      0.43      73.0
# Task Progress                           0.27    0.33      0.30      21.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.68    0.59      0.62     436.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      60.0
# Bug Reproduction                        0.97    0.97      0.97     245.0
# Contribution and Commitment             0.98    1.00      0.99      80.0
# Expected Behaviour                      1.00    0.98      0.99      42.0
# Investigation and Exploration           0.99    0.97      0.98     377.0
# Social Conversation                     1.00    0.99      0.99     716.0
# Motivation                              1.00    1.00      1.00     134.0
# Observed Bug Behaviour                  0.75    0.96      0.84     131.0
# Potential New Issues and Requests       0.99    0.99      0.99     217.0
# Solution Discussion                     1.00    0.97      0.98    1231.0
# Task Progress                           0.86    1.00      0.93     113.0
# Solution Usage                          0.98    0.97      0.97     272.0
# Workarounds                             0.98    0.97      0.98      66.0
# Avg/Total                               0.98    0.98      0.98    3684.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.40    0.67      0.50       3.0
# Expected Behaviour                      0.89    0.10      0.18      82.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.70    0.76      0.73      82.0
# Motivation                              0.68    0.08      0.15     154.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.04    0.08      0.05      13.0
# Solution Discussion                     0.37    0.79      0.50     180.0
# Task Progress                           0.30    0.25      0.27      12.0
# Solution Usage                          0.24    0.12      0.16      96.0
# Workarounds                             0.33    0.04      0.08      23.0
# Avg/Total                               0.52    0.38      0.33     646.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      58.0
# Bug Reproduction                        1.00    0.96      0.98     216.0
# Contribution and Commitment             0.97    1.00      0.99      77.0
# Expected Behaviour                      1.00    0.98      0.99     124.0
# Investigation and Exploration           0.99    0.97      0.98     309.0
# Social Conversation                     1.00    0.99      1.00     773.0
# Motivation                              1.00    1.00      1.00     288.0
# Observed Bug Behaviour                  0.73    0.99      0.84     125.0
# Potential New Issues and Requests       0.99    0.99      0.99     167.0
# Solution Discussion                     1.00    0.97      0.99    1386.0
# Task Progress                           0.85    1.00      0.92     117.0
# Solution Usage                          1.00    0.97      0.98     368.0
# Workarounds                             0.99    0.98      0.98      89.0
# Avg/Total                               0.98    0.98      0.98    4097.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       3.0
# Bug Reproduction                        0.38    0.31      0.34      29.0
# Contribution and Commitment             0.33    0.33      0.33       6.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.41    0.19      0.26      68.0
# Social Conversation                     0.41    0.68      0.52      25.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.00    0.00      0.00       6.0
# Potential New Issues and Requests       0.18    0.03      0.05      63.0
# Solution Discussion                     0.20    0.60      0.30      25.0
# Task Progress                           0.20    0.12      0.15       8.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.30    0.25      0.23     233.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      55.0
# Bug Reproduction                        0.99    0.97      0.98     201.0
# Contribution and Commitment             0.97    1.00      0.99      75.0
# Expected Behaviour                      1.00    0.98      0.99     124.0
# Investigation and Exploration           1.00    0.97      0.98     351.0
# Social Conversation                     1.00    1.00      1.00     752.0
# Motivation                              1.00    1.00      1.00     288.0
# Observed Bug Behaviour                  0.74    0.98      0.85     121.0
# Potential New Issues and Requests       0.99    0.99      0.99     218.0
# Solution Discussion                     1.00    0.98      0.99    1318.0
# Task Progress                           0.84    1.00      0.91     107.0
# Solution Usage                          1.00    0.96      0.98     366.0
# Workarounds                             0.99    0.98      0.98      85.0
# Avg/Total                               0.99    0.98      0.98    4061.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.62    0.83      0.71       6.0
# Bug Reproduction                        0.50    0.20      0.29      44.0
# Contribution and Commitment             0.50    0.12      0.20       8.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.27    0.23      0.25      26.0
# Social Conversation                     0.65    0.74      0.69      46.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.00    0.00      0.00      10.0
# Potential New Issues and Requests       0.12    0.08      0.10      12.0
# Solution Discussion                     0.53    0.42      0.47      93.0
# Task Progress                           0.50    0.33      0.40      18.0
# Solution Usage                          0.02    0.50      0.04       2.0
# Workarounds                             0.00    0.00      0.00       4.0
# Avg/Total                               0.47    0.38      0.41     269.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      53.0
# Bug Reproduction                        0.99    0.97      0.98     244.0
# Contribution and Commitment             1.00    1.00      1.00      83.0
# Expected Behaviour                      1.00    0.98      0.99     121.0
# Investigation and Exploration           0.99    0.98      0.98     376.0
# Social Conversation                     1.00    0.99      1.00     757.0
# Motivation                              1.00    1.00      1.00     272.0
# Observed Bug Behaviour                  0.74    0.98      0.84     131.0
# Potential New Issues and Requests       1.00    0.99      0.99     229.0
# Solution Discussion                     1.00    0.97      0.99    1214.0
# Task Progress                           0.85    1.00      0.92     117.0
# Solution Usage                          0.99    0.97      0.98     367.0
# Workarounds                             0.99    0.98      0.98      87.0
# Avg/Total                               0.98    0.98      0.98    4051.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.83    0.62      0.71       8.0
# Bug Reproduction                        0.00    0.00      0.00       1.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       1.0
# Social Conversation                     0.61    0.68      0.64      41.0
# Motivation                              0.06    0.06      0.06      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.07    1.00      0.12       1.0
# Solution Discussion                     0.87    0.60      0.71     197.0
# Task Progress                           0.50    0.38      0.43       8.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       2.0
# Avg/Total                               0.74    0.56      0.63     279.0
#
# ------------------------- FOLD 5: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      55.0
# Bug Reproduction                        0.98    0.98      0.98     160.0
# Contribution and Commitment             1.00    1.00      1.00      78.0
# Expected Behaviour                      1.00    0.98      0.99     124.0
# Investigation and Exploration           0.99    0.97      0.98     266.0
# Social Conversation                     1.00    0.99      0.99     759.0
# Motivation                              1.00    1.00      1.00     287.0
# Observed Bug Behaviour                  0.99    0.94      0.97     125.0
# Potential New Issues and Requests       0.99    0.99      0.99     230.0
# Solution Discussion                     1.00    0.97      0.99    1349.0
# Task Progress                           0.85    1.00      0.92     122.0
# Solution Usage                          0.91    0.99      0.95     368.0
# Workarounds                             0.99    0.98      0.98      89.0
# Avg/Total                               0.98    0.98      0.98    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.50      0.67       6.0
# Bug Reproduction                        0.58    0.38      0.46      85.0
# Contribution and Commitment             0.50    0.20      0.29       5.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.65    0.30      0.41     111.0
# Social Conversation                     0.53    0.79      0.64      39.0
# Motivation                              0.00    0.00      0.00       1.0
# Observed Bug Behaviour                  0.05    0.17      0.08       6.0
# Potential New Issues and Requests       0.00    0.00      0.00       0.0
# Solution Discussion                     0.35    0.40      0.38      62.0
# Task Progress                           0.14    0.33      0.20       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.54    0.40      0.44     318.0
#
# ------------------------- FOLD 6: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      59.0
# Bug Reproduction                        0.99    0.97      0.98     204.0
# Contribution and Commitment             0.98    1.00      0.99      80.0
# Expected Behaviour                      1.00    0.98      0.99     124.0
# Investigation and Exploration           0.99    0.98      0.98     365.0
# Social Conversation                     1.00    0.99      0.99     760.0
# Motivation                              1.00    1.00      1.00     278.0
# Observed Bug Behaviour                  0.99    0.95      0.97     127.0
# Potential New Issues and Requests       1.00    0.99      0.99     228.0
# Solution Discussion                     1.00    0.98      0.99    1219.0
# Task Progress                           0.88    1.00      0.93     120.0
# Solution Usage                          0.92    0.99      0.95     368.0
# Workarounds                             1.00    0.99      0.99      80.0
# Avg/Total                               0.99    0.98      0.98    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       2.0
# Bug Reproduction                        0.50    0.24      0.33      41.0
# Contribution and Commitment             0.00    0.00      0.00       3.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.17    0.42      0.24      12.0
# Social Conversation                     0.52    0.61      0.56      38.0
# Motivation                              0.20    0.20      0.20      10.0
# Observed Bug Behaviour                  0.00    0.00      0.00       4.0
# Potential New Issues and Requests       0.07    0.50      0.12       2.0
# Solution Discussion                     0.76    0.55      0.64     192.0
# Task Progress                           0.08    0.20      0.11       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       9.0
# Avg/Total                               0.60    0.46      0.51     318.0
#
# ------------------------- FOLD 7: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      52.0
# Bug Reproduction                        0.98    0.96      0.97     245.0
# Contribution and Commitment             1.00    1.00      1.00      78.0
# Expected Behaviour                      0.98    0.98      0.98     123.0
# Investigation and Exploration           0.98    0.97      0.98     377.0
# Social Conversation                     0.99    0.99      0.99     726.0
# Motivation                              1.00    1.00      1.00     285.0
# Observed Bug Behaviour                  0.75    0.98      0.85     131.0
# Potential New Issues and Requests       1.00    0.99      0.99     226.0
# Solution Discussion                     1.00    0.97      0.98    1342.0
# Task Progress                           0.85    1.00      0.92     120.0
# Solution Usage                          1.00    0.96      0.98     105.0
# Workarounds                             0.99    0.98      0.98      89.0
# Avg/Total                               0.98    0.98      0.98    3899.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.44      0.62       9.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.77    0.67      0.72      72.0
# Motivation                              0.00    0.00      0.00       3.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       4.0
# Solution Discussion                     0.19    0.55      0.29      69.0
# Task Progress                           0.12    0.20      0.15       5.0
# Solution Usage                          0.60    0.06      0.10     263.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.55    0.25      0.24     431.0
#
# ------------------------- FOLD 8: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      57.0
# Bug Reproduction                        0.97    0.97      0.97     245.0
# Contribution and Commitment             0.98    1.00      0.99      81.0
# Expected Behaviour                      0.98    0.98      0.98     121.0
# Investigation and Exploration           0.99    0.96      0.98     377.0
# Social Conversation                     1.00    0.99      0.99     774.0
# Motivation                              1.00    1.00      1.00     272.0
# Observed Bug Behaviour                  0.72    0.97      0.83     131.0
# Potential New Issues and Requests       0.98    0.99      0.98     179.0
# Solution Discussion                     1.00    0.97      0.98    1386.0
# Task Progress                           0.85    1.00      0.92     120.0
# Solution Usage                          0.98    0.97      0.97     368.0
# Workarounds                             0.99    0.98      0.98      83.0
# Avg/Total                               0.98    0.98      0.98    4194.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.50      0.67       4.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.20    0.50      0.29       2.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.65    0.54      0.59      24.0
# Motivation                              0.20    0.19      0.19      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      51.0
# Solution Discussion                     0.24    0.64      0.34      25.0
# Task Progress                           0.14    0.20      0.17       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             1.00    0.17      0.29       6.0
# Avg/Total                               0.26    0.27      0.23     136.0
#
# ------------------------- FOLD 9: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      58.0
# Bug Reproduction                        1.00    0.96      0.98     245.0
# Contribution and Commitment             0.98    1.00      0.99      78.0
# Expected Behaviour                      1.00    0.98      0.99     118.0
# Investigation and Exploration           0.99    0.97      0.98     349.0
# Social Conversation                     1.00    0.99      1.00     766.0
# Motivation                              1.00    1.00      1.00     282.0
# Observed Bug Behaviour                  0.70    1.00      0.82     115.0
# Potential New Issues and Requests       0.99    0.99      0.99     229.0
# Solution Discussion                     1.00    0.97      0.99    1335.0
# Task Progress                           0.85    1.00      0.92     111.0
# Solution Usage                          0.99    0.97      0.98     365.0
# Workarounds                             0.98    0.98      0.98      59.0
# Avg/Total                               0.98    0.98      0.98    4110.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.67      0.80       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.60    0.60      0.60       5.0
# Expected Behaviour                      0.33    0.17      0.22       6.0
# Investigation and Exploration           0.14    0.07      0.10      28.0
# Social Conversation                     0.63    0.59      0.61      32.0
# Motivation                              0.22    0.33      0.27       6.0
# Observed Bug Behaviour                  0.00    0.00      0.00      16.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.49    0.72      0.58      76.0
# Task Progress                           0.36    0.29      0.32      14.0
# Solution Usage                          0.11    0.33      0.17       3.0
# Workarounds                             0.67    0.07      0.12      30.0
# Avg/Total                               0.44    0.41      0.38     220.0
#
# ------------------------- FOLD 10: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      56.0
# Bug Reproduction                        0.97    0.97      0.97     238.0
# Contribution and Commitment             0.98    1.00      0.99      83.0
# Expected Behaviour                      0.98    0.98      0.98     124.0
# Investigation and Exploration           0.99    0.97      0.98     353.0
# Social Conversation                     1.00    0.99      0.99     788.0
# Motivation                              1.00    1.00      1.00     288.0
# Observed Bug Behaviour                  0.72    0.97      0.82     123.0
# Potential New Issues and Requests       1.00    0.99      0.99     202.0
# Solution Discussion                     1.00    0.97      0.98    1411.0
# Task Progress                           0.85    1.00      0.92     122.0
# Solution Usage                          0.98    0.97      0.98     368.0
# Workarounds                             0.99    0.98      0.98      88.0
# Avg/Total                               0.98    0.98      0.98    4244.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.67    0.80      0.73       5.0
# Bug Reproduction                        0.56    0.71      0.63       7.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.56    0.38      0.45      24.0
# Social Conversation                     0.60    0.60      0.60      10.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.40    0.25      0.31       8.0
# Potential New Issues and Requests       0.00    0.00      0.00      28.0
# Solution Discussion                     0.00    0.00      0.00       0.0
# Task Progress                           0.50    0.67      0.57       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       1.0
# Avg/Total                               0.37    0.33      0.34      86.0
#
# ------------------------- FOLD 11: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      60.0
# Bug Reproduction                        0.98    0.97      0.97     245.0
# Contribution and Commitment             0.98    1.00      0.99      81.0
# Expected Behaviour                      0.97    0.98      0.98     118.0
# Investigation and Exploration           0.99    0.97      0.98     377.0
# Social Conversation                     0.99    0.99      0.99     755.0
# Motivation                              1.00    1.00      1.00     268.0
# Observed Bug Behaviour                  0.73    0.97      0.83     131.0
# Potential New Issues and Requests       0.99    0.99      0.99     225.0
# Solution Discussion                     1.00    0.96      0.98    1224.0
# Task Progress                           0.85    1.00      0.92     121.0
# Solution Usage                          0.99    0.97      0.98     368.0
# Workarounds                             0.99    0.98      0.98      86.0
# Avg/Total                               0.98    0.98      0.98    4059.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       2.0
# Expected Behaviour                      0.15    0.50      0.23       6.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.77    0.53      0.63      43.0
# Motivation                              0.23    0.30      0.26      20.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       5.0
# Solution Discussion                     0.86    0.64      0.73     187.0
# Task Progress                           0.00    0.00      0.00       4.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.73    0.56      0.63     271.0
#
# ------------------------- FOLD 12: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      59.0
# Bug Reproduction                        0.99    0.95      0.97     207.0
# Contribution and Commitment             1.00    1.00      1.00      76.0
# Expected Behaviour                      1.00    0.98      0.99     123.0
# Investigation and Exploration           0.99    0.97      0.98     273.0
# Social Conversation                     1.00    0.99      1.00     756.0
# Motivation                              1.00    1.00      1.00     288.0
# Observed Bug Behaviour                  0.92    0.94      0.93      50.0
# Potential New Issues and Requests       0.99    0.99      0.99     228.0
# Solution Discussion                     1.00    0.97      0.99    1367.0
# Task Progress                           0.86    1.00      0.92     125.0
# Solution Usage                          0.91    0.99      0.95     368.0
# Workarounds                             0.99    0.98      0.98      81.0
# Avg/Total                               0.98    0.98      0.98    4001.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       2.0
# Bug Reproduction                        0.41    0.47      0.44      38.0
# Contribution and Commitment             0.50    0.29      0.36       7.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.47    0.20      0.28     104.0
# Social Conversation                     0.52    0.55      0.53      42.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.00    0.00      0.00      81.0
# Potential New Issues and Requests       0.00    0.00      0.00       2.0
# Solution Discussion                     0.16    0.43      0.24      44.0
# Task Progress                           0.00    0.00      0.00       0.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.50    0.12      0.20       8.0
# Avg/Total                               0.31    0.26      0.25     329.0
#
# ------------------------- FOLD 13: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      61.0
# Bug Reproduction                        0.98    0.96      0.97     245.0
# Contribution and Commitment             1.00    1.00      1.00      76.0
# Expected Behaviour                      0.99    0.99      0.99     110.0
# Investigation and Exploration           0.99    0.98      0.98     374.0
# Social Conversation                     0.99    0.99      0.99     760.0
# Motivation                              1.00    1.00      1.00     255.0
# Observed Bug Behaviour                  0.97    0.95      0.96     131.0
# Potential New Issues and Requests       1.00    0.99      0.99     205.0
# Solution Discussion                     1.00    0.96      0.98    1288.0
# Task Progress                           0.84    1.00      0.91     120.0
# Solution Usage                          0.88    0.99      0.93     366.0
# Workarounds                             0.99    0.98      0.98      89.0
# Avg/Total                               0.98    0.98      0.98    4080.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       0.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.60    0.43      0.50       7.0
# Expected Behaviour                      0.20    0.07      0.11      14.0
# Investigation and Exploration           0.06    0.33      0.11       3.0
# Social Conversation                     0.64    0.61      0.62      38.0
# Motivation                              0.06    0.03      0.04      33.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.14    0.08      0.10      25.0
# Solution Discussion                     0.60    0.63      0.62     123.0
# Task Progress                           0.20    0.20      0.20       5.0
# Solution Usage                          0.00    0.00      0.00       2.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.45    0.44      0.44     250.0
#
# ------------------------- FOLD 14: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      58.0
# Bug Reproduction                        0.98    0.96      0.97     245.0
# Contribution and Commitment             0.98    1.00      0.99      78.0
# Expected Behaviour                      0.98    0.98      0.98     121.0
# Investigation and Exploration           0.99    0.98      0.98     377.0
# Social Conversation                     1.00    0.99      0.99     784.0
# Motivation                              1.00    1.00      1.00     286.0
# Observed Bug Behaviour                  0.73    0.98      0.84     131.0
# Potential New Issues and Requests       1.00    0.99      0.99     229.0
# Solution Discussion                     1.00    0.97      0.98    1346.0
# Task Progress                           0.85    1.00      0.92     111.0
# Solution Usage                          0.99    0.97      0.98     367.0
# Workarounds                             0.99    0.98      0.98      89.0
# Avg/Total                               0.98    0.98      0.98    4222.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.50    0.60      0.55       5.0
# Expected Behaviour                      0.67    0.67      0.67       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.42    0.71      0.53      14.0
# Motivation                              0.11    0.50      0.18       2.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.80    0.51      0.62      65.0
# Task Progress                           0.57    0.29      0.38      14.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.68    0.52      0.57     108.0

# %% [markdown]
# ### Get list of average weighted F1 scores and average support-weighted F1 score

# %%
avg_f1 = []
for i in range(0,15):
    avg_f1.append(float('%.4f' % round(clf2_results['test_avg_fscore'][i],4)))
    
print('Pipeline2:')
print(avg_f1)

sum = 0
den = 0
for i in range(0,15):
    sum += clf2_results['test_avg_fscore'][i] * clf2_results['test_total_support'][i]
    den += clf2_results['test_total_support'][i]
print('Pipeline2: Total weighted F-Score: '+('%.4f' % round(sum/den,4)))
# Out:
# Pipeline2:
# [0.6206, 0.3258, 0.2338, 0.4052, 0.6316, 0.4366, 0.5113, 0.244, 0.2328, 0.3794, 0.3371, 0.6281, 0.2523, 0.4385, 0.5673]
# Pipeline2: Total weighted F-Score: 0.4147

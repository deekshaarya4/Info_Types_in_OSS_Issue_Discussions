# %% [markdown]
# # Nested 5-Fold Cross Validation For Logistic Regression On Contextual Features

# %%
import numpy as np
import pandas as pd
import xlrd as xl
from pandas import ExcelWriter
from pandas import ExcelFile
import pprint
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
import re
import pickle
from operator import itemgetter
import time, datetime
from functools import partial, update_wrapper
from openpyxl import load_workbook

from sklearn.feature_extraction.text import TfidfVectorizer

from imblearn.over_sampling import SMOTE 

from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as Imb_Pipeline

from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate
from sklearn.metrics import precision_recall_fscore_support, classification_report, accuracy_score, make_scorer, confusion_matrix

pp = pprint.PrettyPrinter(indent=4)

## Ignore warnings
import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn
np.warnings.filterwarnings('ignore')

# %%
### Read from the pickled file
all_data = pd.read_pickle('../../data/text_conv_data.pkl')

print("Size of corpus: "+str(len(all_data)))
# Out:
# Size of corpus: 4330

# %%
X = all_data.drop(['Code','Text Content','Document'], axis=1)

y = all_data['Code'].values

print("Number of unique labels: "+str(len(set(y))))

labels = list(set(y))
labels.sort()

pp.pprint(labels)
# Out:
# Number of unique labels: 13
# [   'Action on Issue',
#     'Bug Reproduction',
#     'Contribution and Commitment',
#     'Expected Behaviour',
#     'Investigation and Exploration',
#     'Social Conversation',
#     'Motivation',
#     'Observed Bug Behaviour',
#     'Potential New Issues and Requests',
#     'Solution Discussion',
#     'Task Progress',
#     'Solution Usage',
#     'Workarounds']

# %% [markdown]
# # Nested Cross-Validation on Logistic Regression:

# %%
# To be used within GridSearch
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# To be used in outer CV
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# ## Define Pipelines
#
# 1. Pipeline1: class_weight=balanced
# 2. Pipeline2: SMOTE

# %%
pipeline1 = Pipeline([
    ('clf', LogisticRegression(class_weight='balanced')),
])

pipeline2 = Imb_Pipeline([
    ('smote', SMOTE()),
    ('clf', LogisticRegression())
])

### Hyperparameters to search
parameters = {
    'clf__C': (0.01, 0.1, 1, 10),
}

# %% [markdown]
# ## Nested Cross Validation using GridSearch

# %%
### Define and create the scoring functions

def score_func(y_true, y_pred, score_index, i):
    return(precision_recall_fscore_support(y_true,y_pred)[score_index][i])

def avg_score(y_true, y_pred, score_index):
    return precision_recall_fscore_support(y_true,y_pred,average='weighted')[score_index]

def sum_support(y_true, y_pred):
    return len(y_true)

### Create partials for each of the metrics returned
score_funcs = {v: partial(score_func, score_index=k) for k, v in {0:'precision',1:'recall',2:'fscore',3:'support'}.items()}
prec_score = partial(score_func, score_index=0)
update_wrapper(prec_score,score_func)
rec_score = partial(score_func, score_index=1)
update_wrapper(rec_score,score_func)
f_score = partial(score_func, score_index=2)
update_wrapper(f_score,score_func)
support_score = partial(score_func, score_index=3)
update_wrapper(support_score,score_func)

### Create a callable scoring function for each of the metrics for each classification label
scorer = {}
for label_id in range(0,13):
    scorer['label'+str(label_id)+'_precision'] = make_scorer(prec_score, i=label_id)
    scorer['label'+str(label_id)+'_recall'] = make_scorer(rec_score, i=label_id)
    scorer['label'+str(label_id)+'_fscore'] = make_scorer(f_score, i=label_id)
    scorer['label'+str(label_id)+'_support'] = make_scorer(support_score, i=label_id)

### Create a callable scoring function for avg/total of the metrics across classification labels
scorer['avg_precision'] = make_scorer(avg_score,score_index=0)
scorer['avg_recall'] = make_scorer(avg_score,score_index=1)
scorer['avg_fscore'] = make_scorer(avg_score,score_index=2)
scorer['total_support'] = make_scorer(sum_support)

### Perform Nested cross-validation on Pipeline1
start = time.time()
clf1 = GridSearchCV(pipeline1, parameters, cv=inner_cv, scoring='f1_weighted')
clf1_results = cross_validate(clf1, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline1 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))

### Perform Nested cross-validation on Pipeline2
start = time.time()
clf2 = GridSearchCV(pipeline2, parameters, cv=inner_cv, scoring='f1_weighted')
clf2_results = cross_validate(clf2, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline2 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))
# Out:
# Completed Pipeline1 scenario in 0:01:32.939930
# Completed Pipeline2 scenario in 0:07:06.275653

# %% [markdown]
# # Display and Save Training and Testing Results for each Fold:

# %% [markdown]
# ## Pipeline1 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../../results/5FOLD.xlsx')
book = load_workbook('../../results/5FOLD.xlsx')
writer = pd.ExcelWriter('../../results/5FOLD.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,5):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf1_results['train_label'+str(label_id)+'_precision'][i],clf1_results['train_label'+str(label_id)+'_recall'][i],clf1_results['train_label'+str(label_id)+'_fscore'][i],clf1_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf1_results['test_label'+str(label_id)+'_precision'][i],clf1_results['test_label'+str(label_id)+'_recall'][i],clf1_results['test_label'+str(label_id)+'_fscore'][i],clf1_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf1_results['train_avg_precision'][i],clf1_results['train_avg_recall'][i],clf1_results['train_avg_fscore'][i],clf1_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf1_results['test_avg_precision'][i],clf1_results['test_avg_recall'][i],clf1_results['test_avg_fscore'][i],clf1_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'LCC',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'LCC',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'LCC',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['LCC_train_'+str(i)] = train_report
    result_dict['LCC_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.14    0.52      0.22      48.0
# Bug Reproduction                        0.17    0.19      0.18     196.0
# Contribution and Commitment             0.09    0.24      0.13      66.0
# Expected Behaviour                      0.11    0.18      0.14      99.0
# Investigation and Exploration           0.30    0.17      0.22     301.0
# Social Conversation                     0.53    0.68      0.60     638.0
# Motivation                              0.27    0.27      0.27     230.0
# Observed Bug Behaviour                  0.29    0.64      0.40     104.0
# Potential New Issues and Requests       0.17    0.17      0.17     184.0
# Solution Discussion                     0.65    0.27      0.38    1128.0
# Task Progress                           0.13    0.10      0.11     100.0
# Solution Usage                          0.29    0.44      0.35     294.0
# Workarounds                             0.14    0.18      0.16      71.0
# Avg/Total                               0.42    0.35      0.35    3459.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.14    0.46      0.22      13.0
# Bug Reproduction                        0.17    0.18      0.17      49.0
# Contribution and Commitment             0.08    0.24      0.12      17.0
# Expected Behaviour                      0.09    0.16      0.11      25.0
# Investigation and Exploration           0.30    0.21      0.25      76.0
# Social Conversation                     0.57    0.57      0.57     160.0
# Motivation                              0.29    0.33      0.31      58.0
# Observed Bug Behaviour                  0.28    0.56      0.37      27.0
# Potential New Issues and Requests       0.07    0.09      0.08      46.0
# Solution Discussion                     0.68    0.30      0.42     283.0
# Task Progress                           0.05    0.04      0.04      25.0
# Solution Usage                          0.25    0.41      0.31      74.0
# Workarounds                             0.06    0.06      0.06      18.0
# Avg/Total                               0.42    0.33      0.35     871.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.14    0.51      0.21      49.0
# Bug Reproduction                        0.22    0.20      0.21     196.0
# Contribution and Commitment             0.10    0.27      0.14      66.0
# Expected Behaviour                      0.12    0.26      0.17      99.0
# Investigation and Exploration           0.30    0.16      0.21     301.0
# Social Conversation                     0.53    0.66      0.59     638.0
# Motivation                              0.28    0.24      0.26     230.0
# Observed Bug Behaviour                  0.31    0.55      0.40     105.0
# Potential New Issues and Requests       0.11    0.07      0.09     184.0
# Solution Discussion                     0.64    0.31      0.42    1129.0
# Task Progress                           0.11    0.09      0.10     100.0
# Solution Usage                          0.27    0.44      0.34     294.0
# Workarounds                             0.09    0.17      0.12      71.0
# Avg/Total                               0.41    0.35      0.35    3462.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.17    0.67      0.27      12.0
# Bug Reproduction                        0.16    0.14      0.15      49.0
# Contribution and Commitment             0.07    0.24      0.11      17.0
# Expected Behaviour                      0.08    0.20      0.12      25.0
# Investigation and Exploration           0.27    0.17      0.21      76.0
# Social Conversation                     0.53    0.74      0.62     160.0
# Motivation                              0.27    0.21      0.24      58.0
# Observed Bug Behaviour                  0.31    0.62      0.41      26.0
# Potential New Issues and Requests       0.22    0.13      0.16      46.0
# Solution Discussion                     0.61    0.27      0.38     282.0
# Task Progress                           0.11    0.08      0.09      25.0
# Solution Usage                          0.34    0.43      0.38      74.0
# Workarounds                             0.11    0.17      0.13      18.0
# Avg/Total                               0.41    0.35      0.35     868.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.17    0.57      0.26      49.0
# Bug Reproduction                        0.16    0.16      0.16     196.0
# Contribution and Commitment             0.07    0.18      0.10      66.0
# Expected Behaviour                      0.12    0.21      0.15      99.0
# Investigation and Exploration           0.25    0.17      0.21     302.0
# Social Conversation                     0.53    0.66      0.59     638.0
# Motivation                              0.28    0.30      0.29     230.0
# Observed Bug Behaviour                  0.31    0.60      0.41     105.0
# Potential New Issues and Requests       0.15    0.12      0.14     184.0
# Solution Discussion                     0.65    0.29      0.40    1129.0
# Task Progress                           0.15    0.08      0.10     100.0
# Solution Usage                          0.27    0.40      0.32     294.0
# Workarounds                             0.12    0.20      0.15      71.0
# Avg/Total                               0.41    0.35      0.35    3463.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.14    0.50      0.22      12.0
# Bug Reproduction                        0.18    0.16      0.17      49.0
# Contribution and Commitment             0.10    0.29      0.15      17.0
# Expected Behaviour                      0.13    0.20      0.16      25.0
# Investigation and Exploration           0.29    0.16      0.21      75.0
# Social Conversation                     0.56    0.74      0.64     160.0
# Motivation                              0.22    0.21      0.21      58.0
# Observed Bug Behaviour                  0.31    0.65      0.43      26.0
# Potential New Issues and Requests       0.16    0.15      0.15      46.0
# Solution Discussion                     0.64    0.30      0.41     282.0
# Task Progress                           0.15    0.12      0.13      25.0
# Solution Usage                          0.33    0.46      0.39      74.0
# Workarounds                             0.06    0.11      0.08      18.0
# Avg/Total                               0.42    0.36      0.36     867.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.16    0.51      0.24      49.0
# Bug Reproduction                        0.17    0.21      0.19     196.0
# Contribution and Commitment             0.11    0.36      0.17      67.0
# Expected Behaviour                      0.13    0.21      0.16      99.0
# Investigation and Exploration           0.28    0.17      0.21     302.0
# Social Conversation                     0.52    0.67      0.59     639.0
# Motivation                              0.26    0.25      0.26     231.0
# Observed Bug Behaviour                  0.31    0.57      0.40     105.0
# Potential New Issues and Requests       0.15    0.13      0.14     184.0
# Solution Discussion                     0.64    0.29      0.40    1129.0
# Task Progress                           0.13    0.10      0.11     100.0
# Solution Usage                          0.27    0.41      0.33     295.0
# Workarounds                             0.08    0.10      0.09      71.0
# Avg/Total                               0.41    0.35      0.35    3467.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.14    0.42      0.20      12.0
# Bug Reproduction                        0.12    0.14      0.13      49.0
# Contribution and Commitment             0.02    0.06      0.03      16.0
# Expected Behaviour                      0.12    0.20      0.15      25.0
# Investigation and Exploration           0.32    0.13      0.19      75.0
# Social Conversation                     0.54    0.70      0.61     159.0
# Motivation                              0.26    0.30      0.28      57.0
# Observed Bug Behaviour                  0.31    0.58      0.40      26.0
# Potential New Issues and Requests       0.15    0.15      0.15      46.0
# Solution Discussion                     0.62    0.27      0.38     282.0
# Task Progress                           0.06    0.04      0.05      25.0
# Solution Usage                          0.25    0.40      0.30      73.0
# Workarounds                             0.15    0.22      0.18      18.0
# Avg/Total                               0.40    0.34      0.34     863.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.15    0.53      0.24      49.0
# Bug Reproduction                        0.19    0.20      0.19     196.0
# Contribution and Commitment             0.09    0.28      0.14      67.0
# Expected Behaviour                      0.13    0.22      0.16     100.0
# Investigation and Exploration           0.29    0.17      0.21     302.0
# Social Conversation                     0.55    0.69      0.61     639.0
# Motivation                              0.27    0.30      0.28     231.0
# Observed Bug Behaviour                  0.29    0.60      0.39     105.0
# Potential New Issues and Requests       0.13    0.09      0.11     184.0
# Solution Discussion                     0.65    0.30      0.41    1129.0
# Task Progress                           0.15    0.12      0.13     100.0
# Solution Usage                          0.29    0.46      0.35     295.0
# Workarounds                             0.14    0.11      0.12      72.0
# Avg/Total                               0.42    0.36      0.36    3469.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.09    0.33      0.14      12.0
# Bug Reproduction                        0.21    0.27      0.23      49.0
# Contribution and Commitment             0.04    0.12      0.06      16.0
# Expected Behaviour                      0.03    0.04      0.03      24.0
# Investigation and Exploration           0.30    0.23      0.26      75.0
# Social Conversation                     0.47    0.61      0.53     159.0
# Motivation                              0.22    0.25      0.23      57.0
# Observed Bug Behaviour                  0.30    0.62      0.40      26.0
# Potential New Issues and Requests       0.10    0.07      0.08      46.0
# Solution Discussion                     0.67    0.26      0.37     282.0
# Task Progress                           0.04    0.04      0.04      25.0
# Solution Usage                          0.28    0.41      0.34      73.0
# Workarounds                             0.15    0.12      0.13      17.0
# Avg/Total                               0.40    0.32      0.32     861.0

# %% [markdown]
# ## Pipeline2 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../../results/5FOLD_CONTEXTUAL.xlsx')
book = load_workbook('../../results/5FOLD_CONTEXTUAL.xlsx')
writer = pd.ExcelWriter('../../results/5FOLD_CONTEXTUAL.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,5):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf2_results['train_label'+str(label_id)+'_precision'][i],clf2_results['train_label'+str(label_id)+'_recall'][i],clf2_results['train_label'+str(label_id)+'_fscore'][i],clf2_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf2_results['test_label'+str(label_id)+'_precision'][i],clf2_results['test_label'+str(label_id)+'_recall'][i],clf2_results['test_label'+str(label_id)+'_fscore'][i],clf2_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf2_results['train_avg_precision'][i],clf2_results['train_avg_recall'][i],clf2_results['train_avg_fscore'][i],clf2_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf2_results['test_avg_precision'][i],clf2_results['test_avg_recall'][i],clf2_results['test_avg_fscore'][i],clf2_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'LCS',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'LCS',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'LCS',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['LCS_train_'+str(i)] = train_report
    result_dict['LCS_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.14    0.60      0.22      48.0
# Bug Reproduction                        0.18    0.24      0.21     196.0
# Contribution and Commitment             0.08    0.38      0.13      66.0
# Expected Behaviour                      0.13    0.28      0.18      99.0
# Investigation and Exploration           0.29    0.17      0.22     301.0
# Social Conversation                     0.61    0.55      0.58     638.0
# Motivation                              0.22    0.32      0.26     230.0
# Observed Bug Behaviour                  0.27    0.68      0.38     104.0
# Potential New Issues and Requests       0.13    0.27      0.17     184.0
# Solution Discussion                     0.43    0.01      0.02    1128.0
# Task Progress                           0.12    0.13      0.13     100.0
# Solution Usage                          0.28    0.41      0.33     294.0
# Workarounds                             0.10    0.21      0.14      71.0
# Avg/Total                               0.35    0.26      0.23    3459.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.18    0.54      0.27      13.0
# Bug Reproduction                        0.14    0.16      0.15      49.0
# Contribution and Commitment             0.08    0.41      0.13      17.0
# Expected Behaviour                      0.11    0.32      0.16      25.0
# Investigation and Exploration           0.26    0.14      0.18      76.0
# Social Conversation                     0.59    0.48      0.53     160.0
# Motivation                              0.20    0.33      0.25      58.0
# Observed Bug Behaviour                  0.23    0.52      0.32      27.0
# Potential New Issues and Requests       0.06    0.15      0.09      46.0
# Solution Discussion                     0.83    0.02      0.03     283.0
# Task Progress                           0.09    0.08      0.08      25.0
# Solution Usage                          0.22    0.32      0.26      74.0
# Workarounds                             0.05    0.11      0.07      18.0
# Avg/Total                               0.46    0.22      0.20     871.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.12    0.65      0.20      49.0
# Bug Reproduction                        0.19    0.21      0.20     196.0
# Contribution and Commitment             0.08    0.32      0.12      66.0
# Expected Behaviour                      0.12    0.33      0.17      99.0
# Investigation and Exploration           0.31    0.11      0.16     301.0
# Social Conversation                     0.60    0.57      0.58     638.0
# Motivation                              0.20    0.27      0.23     230.0
# Observed Bug Behaviour                  0.27    0.64      0.38     105.0
# Potential New Issues and Requests       0.12    0.24      0.16     184.0
# Solution Discussion                     0.70    0.03      0.06    1129.0
# Task Progress                           0.12    0.11      0.12     100.0
# Solution Usage                          0.21    0.35      0.26     294.0
# Workarounds                             0.09    0.20      0.12      71.0
# Avg/Total                               0.43    0.25      0.22    3462.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.10    0.67      0.18      12.0
# Bug Reproduction                        0.20    0.22      0.21      49.0
# Contribution and Commitment             0.08    0.29      0.13      17.0
# Expected Behaviour                      0.08    0.24      0.11      25.0
# Investigation and Exploration           0.25    0.12      0.16      76.0
# Social Conversation                     0.54    0.58      0.56     160.0
# Motivation                              0.23    0.28      0.25      58.0
# Observed Bug Behaviour                  0.24    0.62      0.34      26.0
# Potential New Issues and Requests       0.17    0.35      0.23      46.0
# Solution Discussion                     0.70    0.02      0.05     282.0
# Task Progress                           0.10    0.08      0.09      25.0
# Solution Usage                          0.33    0.45      0.38      74.0
# Workarounds                             0.07    0.11      0.09      18.0
# Avg/Total                               0.43    0.26      0.23     868.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.12    0.53      0.19      49.0
# Bug Reproduction                        0.17    0.22      0.19     196.0
# Contribution and Commitment             0.08    0.36      0.12      66.0
# Expected Behaviour                      0.14    0.28      0.19      99.0
# Investigation and Exploration           0.26    0.16      0.19     302.0
# Social Conversation                     0.59    0.52      0.55     638.0
# Motivation                              0.21    0.33      0.25     230.0
# Observed Bug Behaviour                  0.28    0.70      0.40     105.0
# Potential New Issues and Requests       0.14    0.27      0.18     184.0
# Solution Discussion                     0.61    0.04      0.07    1129.0
# Task Progress                           0.10    0.07      0.08     100.0
# Solution Usage                          0.27    0.43      0.33     294.0
# Workarounds                             0.10    0.17      0.12      71.0
# Avg/Total                               0.40    0.26      0.23    3463.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.13    0.58      0.21      12.0
# Bug Reproduction                        0.25    0.31      0.28      49.0
# Contribution and Commitment             0.08    0.41      0.14      17.0
# Expected Behaviour                      0.14    0.24      0.18      25.0
# Investigation and Exploration           0.32    0.16      0.21      75.0
# Social Conversation                     0.66    0.60      0.63     160.0
# Motivation                              0.17    0.26      0.21      58.0
# Observed Bug Behaviour                  0.28    0.69      0.40      26.0
# Potential New Issues and Requests       0.12    0.26      0.16      46.0
# Solution Discussion                     0.62    0.04      0.07     282.0
# Task Progress                           0.07    0.08      0.08      25.0
# Solution Usage                          0.32    0.46      0.38      74.0
# Workarounds                             0.05    0.11      0.07      18.0
# Avg/Total                               0.43    0.27      0.25     867.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.16    0.59      0.25      49.0
# Bug Reproduction                        0.20    0.32      0.24     196.0
# Contribution and Commitment             0.09    0.46      0.15      67.0
# Expected Behaviour                      0.14    0.30      0.19      99.0
# Investigation and Exploration           0.26    0.16      0.20     302.0
# Social Conversation                     0.58    0.56      0.57     639.0
# Motivation                              0.21    0.26      0.23     231.0
# Observed Bug Behaviour                  0.28    0.67      0.40     105.0
# Potential New Issues and Requests       0.12    0.24      0.16     184.0
# Solution Discussion                     0.64    0.04      0.08    1129.0
# Task Progress                           0.11    0.15      0.12     100.0
# Solution Usage                          0.26    0.36      0.30     295.0
# Workarounds                             0.13    0.23      0.16      71.0
# Avg/Total                               0.42    0.26      0.24    3467.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.12    0.42      0.19      12.0
# Bug Reproduction                        0.11    0.16      0.13      49.0
# Contribution and Commitment             0.05    0.25      0.09      16.0
# Expected Behaviour                      0.13    0.24      0.17      25.0
# Investigation and Exploration           0.33    0.15      0.20      75.0
# Social Conversation                     0.60    0.60      0.60     159.0
# Motivation                              0.18    0.26      0.21      57.0
# Observed Bug Behaviour                  0.26    0.65      0.37      26.0
# Potential New Issues and Requests       0.14    0.30      0.19      46.0
# Solution Discussion                     0.62    0.04      0.07     282.0
# Task Progress                           0.03    0.04      0.04      25.0
# Solution Usage                          0.21    0.32      0.25      73.0
# Workarounds                             0.17    0.28      0.21      18.0
# Avg/Total                               0.41    0.25      0.23     863.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.14    0.55      0.23      49.0
# Bug Reproduction                        0.19    0.23      0.21     196.0
# Contribution and Commitment             0.09    0.48      0.15      67.0
# Expected Behaviour                      0.12    0.28      0.17     100.0
# Investigation and Exploration           0.24    0.12      0.16     302.0
# Social Conversation                     0.61    0.58      0.60     639.0
# Motivation                              0.22    0.30      0.25     231.0
# Observed Bug Behaviour                  0.25    0.65      0.36     105.0
# Potential New Issues and Requests       0.11    0.23      0.15     184.0
# Solution Discussion                     0.69    0.03      0.06    1129.0
# Task Progress                           0.13    0.17      0.15     100.0
# Solution Usage                          0.27    0.41      0.32     295.0
# Workarounds                             0.17    0.18      0.17      72.0
# Avg/Total                               0.43    0.26      0.24    3469.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.11    0.50      0.18      12.0
# Bug Reproduction                        0.19    0.29      0.23      49.0
# Contribution and Commitment             0.02    0.12      0.04      16.0
# Expected Behaviour                      0.02    0.04      0.03      24.0
# Investigation and Exploration           0.28    0.17      0.21      75.0
# Social Conversation                     0.53    0.49      0.51     159.0
# Motivation                              0.17    0.23      0.20      57.0
# Observed Bug Behaviour                  0.28    0.69      0.40      26.0
# Potential New Issues and Requests       0.13    0.24      0.17      46.0
# Solution Discussion                     0.89    0.03      0.05     282.0
# Task Progress                           0.02    0.04      0.03      25.0
# Solution Usage                          0.27    0.38      0.32      73.0
# Workarounds                             0.13    0.18      0.15      17.0
# Avg/Total                               0.48    0.23      0.21     861.0

# %% [markdown]
# # Nested 5-Fold Cross Validation For Logistic Regression On Both Textual+Conversational Features

# %%
import numpy as np
import pandas as pd
import xlrd as xl
from pandas import ExcelWriter
from pandas import ExcelFile
import pprint
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
import re
import pickle
from operator import itemgetter
import time, datetime
from functools import partial, update_wrapper
from openpyxl import load_workbook
from copy import deepcopy

from sklearn.externals.joblib import Parallel, delayed
from sklearn.pipeline import FeatureUnion, _fit_transform_one, _transform_one
from scipy import sparse

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from imblearn.over_sampling import SMOTE

from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from imblearn.pipeline import Pipeline as Imb_Pipeline

from sklearn_pandas import DataFrameMapper, gen_features
from sklearn.preprocessing import FunctionTransformer

from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate
from sklearn.metrics import precision_recall_fscore_support, classification_report, accuracy_score, make_scorer, confusion_matrix

pp = pprint.PrettyPrinter(indent=4)

## Ignore warnings
import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn
np.warnings.filterwarnings('ignore')

# %% [markdown]
# #### Use spaCy parser for word tokenization of a sentence:

# %%
import spacy
eng = spacy.load('en')
from spacy.lang.en import English
parser = English()

# %% [markdown]
# #### Define stopwords as punctuation + common contractions:

# %%
from string import punctuation
from nltk.corpus import stopwords

stop_words = list(punctuation) + ["'s","'m","n't","'re","-","'ll",'...'] #+ stopwords.words('english')

# %% [markdown]
# #### Code to lemmatize and tokenize:

# %%
def get_lemma(item):
    return WordNetLemmatizer().lemmatize(item)

def tokenize(line):
    line_tokens = []
    tokens = parser(line)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            line_tokens.append('URL')
        elif token.orth_.startswith('@'):
            line_tokens.append('SCREEN_NAME')
        elif str(token) not in stop_words:
            line_tokens.append(get_lemma(token.lower_))
    return line_tokens

# %%
### Read from the pickled file
all_data = pd.read_pickle('../../data/text_conv_data.pkl')

print("Size of corpus: "+str(len(all_data)))
print("Feature Size: "+str(len(list(all_data.columns.values))-1))
# Out:
# Size of corpus: 4330
# Feature Size: 23

# %%
X = all_data.drop(['Code','Document'], axis=1)
y = all_data[['Code']]

print("Number of unique labels: "+str(len(set(y['Code']))))

labels = list(set(y['Code']))
labels.sort()

pp.pprint(labels)
# Out:
# Number of unique labels: 13
# [   'Action on Issue',
#     'Bug Reproduction',
#     'Contribution and Commitment',
#     'Expected Behaviour',
#     'Investigation and Exploration',
#     'Social Conversation',
#     'Motivation',
#     'Observed Bug Behaviour',
#     'Potential New Issues and Requests',
#     'Solution Discussion',
#     'Task Progress',
#     'Solution Usage',
#     'Workarounds']

# %% [markdown]
# # Nested Cross-Validation on Logistic Regression:

# %%
# To be used within GridSearch
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# To be used in outer CV
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

non_transform_features = [col for col in X.columns.values if col not in ['Text Content']]

# %% [markdown]
# ## Define pandas-compatible feature unificator
#
# This is just a pandas compatible feature unificator.
#
# This is necessary because we have two types of features: textual + conversational
#
# Hence, we first use tf-idf to vectorize the textual content and then append the conversational features to this vector using the feature unificator.

# %%
class PandasFeatureUnion(FeatureUnion):
    def fit_transform(self, X, y=None, **fit_params):
        self._validate_transformers()
        result = Parallel(n_jobs=self.n_jobs)(
            delayed(_fit_transform_one)(trans, weight, X, y,
                                        **fit_params)
            for name, trans, weight in self._iter())
        if not result:
            return np.zeros((X.shape[0], 0))
        Xs, transformers = zip(*result)
        self._update_transformer_list(transformers)
        if any(sparse.issparse(f) for f in Xs):
            Xs = sparse.hstack(Xs).tocsr()
        else:
            Xs = self.merge_dataframes_by_column(Xs)
        return Xs

    def merge_dataframes_by_column(self, Xs):
        return pd.concat(Xs, axis="columns", copy=False)

    def transform(self, X):
        Xs = Parallel(n_jobs=self.n_jobs)(
            delayed(_transform_one)(trans, weight, X)
            for name, trans, weight in self._iter())
        if not Xs:
            return np.zeros((X.shape[0], 0))
        if any(sparse.issparse(f) for f in Xs):
            Xs = sparse.hstack(Xs).tocsr()
        else:
            Xs = self.merge_dataframes_by_column(Xs)
        return Xs

# %%
class PandasTransform(TransformerMixin, BaseEstimator):
    def __init__(self, columns):
        self.columns = columns
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None, copy=None):
        return X.loc[:, self.columns].astype(float)

# %% [markdown]
# ## Define Pipelines
#
# 1. Pipeline1: tfidf + class_weight=balanced
# 2. Pipeline2: tfidf + SMOTE

# %%
class ItemSelector(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
    def fit(self, x, y=None):
        print(self)
        return self
    def transform(self, data_array):
        print(len(data_array[:, self.columns]))
        return data_array[:, self.columns]

### Simply select the conversational features, and tfidf-vectorize the textual content
ling_features = PandasTransform(non_transform_features)
tfidf_text_features = Pipeline([('extract_field',FunctionTransformer(lambda x: x['Text Content'],validate=False)),('vect',TfidfVectorizer(tokenizer=tokenize))])

### Combine the two types of feature vectors
feature_union1 = PandasFeatureUnion([
    ('selector',ling_features),
    ('text_vectorizer',tfidf_text_features)
])

pipeline1 = Pipeline([
    ('features',feature_union1),
    ('clf', LogisticRegression(class_weight='balanced')),
])
pipeline2 = Imb_Pipeline([
    ('features', feature_union1),
    ('smote', SMOTE()),
    ('clf', LogisticRegression())
])

### Hyperparameters to search
parameters = {
    'features__text_vectorizer__vect__ngram_range': ((1,1),(1,2)),
    'clf__C': (0.01, 0.1, 1, 10),
}

# %% [markdown]
# ## Nested Cross Validation using GridSearch

# %%
### Define and create the scoring functions

def score_func(y_true, y_pred, score_index, i):
    return(precision_recall_fscore_support(y_true,y_pred)[score_index][i])

def avg_score(y_true, y_pred, score_index):
    return precision_recall_fscore_support(y_true,y_pred,average='weighted')[score_index]

def sum_support(y_true, y_pred):
    return len(y_true)

### Create partials for each of the metrics returned
score_funcs = {v: partial(score_func, score_index=k) for k, v in {0:'precision',1:'recall',2:'fscore',3:'support'}.items()}
prec_score = partial(score_func, score_index=0)
update_wrapper(prec_score,score_func)
rec_score = partial(score_func, score_index=1)
update_wrapper(rec_score,score_func)
f_score = partial(score_func, score_index=2)
update_wrapper(f_score,score_func)
support_score = partial(score_func, score_index=3)
update_wrapper(support_score,score_func)

### Create a callable scoring function for each of the metrics for each classification label
scorer = {}
for label_id in range(0,13):
    scorer['label'+str(label_id)+'_precision'] = make_scorer(prec_score, i=label_id)
    scorer['label'+str(label_id)+'_recall'] = make_scorer(rec_score, i=label_id)
    scorer['label'+str(label_id)+'_fscore'] = make_scorer(f_score, i=label_id)
    scorer['label'+str(label_id)+'_support'] = make_scorer(support_score, i=label_id)

### Create a callable scoring function for avg/total of the metrics across classification labels
scorer['avg_precision'] = make_scorer(avg_score,score_index=0)
scorer['avg_recall'] = make_scorer(avg_score,score_index=1)
scorer['avg_fscore'] = make_scorer(avg_score,score_index=2)
scorer['total_support'] = make_scorer(sum_support)

### Perform Nested cross-validation on Pipeline1
start = time.time()
clf1 = GridSearchCV(pipeline1, parameters, cv=inner_cv, scoring='f1_weighted')
clf1_results = cross_validate(clf1, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline1 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))

### Perform Nested cross-validation on Pipeline2
start = time.time()
clf2 = GridSearchCV(pipeline2, parameters, cv=inner_cv, scoring='f1_weighted')
clf2_results = cross_validate(clf2, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline2 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))
# Out:
# Completed Pipeline1 scenario in 1:10:25.689485
# Completed Pipeline2 scenario in 2:52:08.357369

# %% [markdown]
# # Display and Save Training and Testing Results for each Fold:

# %% [markdown]
# ## Pipeline1 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

writer = pd.ExcelWriter('../../results/5FOLD.xlsx')
# book = load_workbook('../../results/5FOLD.xlsx')
# writer = pd.ExcelWriter('../../results/5FOLD.xlsx')
# writer.book = book
# writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,5):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf1_results['train_label'+str(label_id)+'_precision'][i],clf1_results['train_label'+str(label_id)+'_recall'][i],clf1_results['train_label'+str(label_id)+'_fscore'][i],clf1_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf1_results['test_label'+str(label_id)+'_precision'][i],clf1_results['test_label'+str(label_id)+'_recall'][i],clf1_results['test_label'+str(label_id)+'_fscore'][i],clf1_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf1_results['train_avg_precision'][i],clf1_results['train_avg_recall'][i],clf1_results['train_avg_fscore'][i],clf1_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf1_results['test_avg_precision'][i],clf1_results['test_avg_recall'][i],clf1_results['test_avg_fscore'][i],clf1_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'LBC',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'LBC',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'LBC',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['LBC_train_'+str(i)] = train_report
    result_dict['LBC_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      48.0
# Bug Reproduction                        0.92    0.99      0.95     196.0
# Contribution and Commitment             0.97    1.00      0.99      66.0
# Expected Behaviour                      0.95    0.99      0.97      99.0
# Investigation and Exploration           0.89    0.96      0.93     301.0
# Social Conversation                     0.95    0.95      0.95     638.0
# Motivation                              0.92    1.00      0.96     230.0
# Observed Bug Behaviour                  0.93    0.98      0.95     104.0
# Potential New Issues and Requests       0.95    0.98      0.97     184.0
# Solution Discussion                     0.99    0.87      0.93    1128.0
# Task Progress                           0.80    0.99      0.88     100.0
# Solution Usage                          0.88    0.97      0.92     294.0
# Workarounds                             0.96    0.99      0.97      71.0
# Avg/Total                               0.94    0.94      0.94    3459.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.53    0.69      0.60      13.0
# Bug Reproduction                        0.48    0.51      0.50      49.0
# Contribution and Commitment             0.53    0.59      0.56      17.0
# Expected Behaviour                      0.48    0.44      0.46      25.0
# Investigation and Exploration           0.43    0.41      0.42      76.0
# Social Conversation                     0.76    0.69      0.72     160.0
# Motivation                              0.40    0.29      0.34      58.0
# Observed Bug Behaviour                  0.41    0.48      0.44      27.0
# Potential New Issues and Requests       0.22    0.24      0.23      46.0
# Solution Discussion                     0.63    0.63      0.63     283.0
# Task Progress                           0.31    0.32      0.31      25.0
# Solution Usage                          0.49    0.65      0.56      74.0
# Workarounds                             0.21    0.17      0.19      18.0
# Avg/Total                               0.55    0.54      0.54     871.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.91    0.97      0.94     196.0
# Contribution and Commitment             1.00    1.00      1.00      66.0
# Expected Behaviour                      0.95    0.98      0.97      99.0
# Investigation and Exploration           0.90    0.93      0.92     301.0
# Social Conversation                     0.95    0.96      0.95     638.0
# Motivation                              0.92    0.99      0.96     230.0
# Observed Bug Behaviour                  0.94    0.97      0.96     105.0
# Potential New Issues and Requests       0.95    0.96      0.96     184.0
# Solution Discussion                     0.99    0.88      0.93    1129.0
# Task Progress                           0.83    0.99      0.90     100.0
# Solution Usage                          0.85    0.97      0.90     294.0
# Workarounds                             0.93    0.99      0.96      71.0
# Avg/Total                               0.94    0.94      0.94    3462.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.83      0.91      12.0
# Bug Reproduction                        0.53    0.49      0.51      49.0
# Contribution and Commitment             0.58    0.41      0.48      17.0
# Expected Behaviour                      0.41    0.52      0.46      25.0
# Investigation and Exploration           0.43    0.47      0.45      76.0
# Social Conversation                     0.72    0.76      0.74     160.0
# Motivation                              0.44    0.34      0.39      58.0
# Observed Bug Behaviour                  0.57    0.65      0.61      26.0
# Potential New Issues and Requests       0.29    0.28      0.29      46.0
# Solution Discussion                     0.65    0.62      0.63     282.0
# Task Progress                           0.27    0.32      0.29      25.0
# Solution Usage                          0.57    0.68      0.62      74.0
# Workarounds                             0.70    0.39      0.50      18.0
# Avg/Total                               0.58    0.58      0.58     868.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.93    0.97      0.95     196.0
# Contribution and Commitment             0.99    1.00      0.99      66.0
# Expected Behaviour                      0.97    0.99      0.98      99.0
# Investigation and Exploration           0.89    0.95      0.92     302.0
# Social Conversation                     0.95    0.95      0.95     638.0
# Motivation                              0.93    1.00      0.96     230.0
# Observed Bug Behaviour                  0.91    0.99      0.95     105.0
# Potential New Issues and Requests       0.95    0.96      0.95     184.0
# Solution Discussion                     0.98    0.89      0.93    1129.0
# Task Progress                           0.90    0.99      0.94     100.0
# Solution Usage                          0.88    0.97      0.92     294.0
# Workarounds                             0.93    0.99      0.96      71.0
# Avg/Total                               0.94    0.94      0.94    3463.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.64    0.75      0.69      12.0
# Bug Reproduction                        0.49    0.55      0.52      49.0
# Contribution and Commitment             0.44    0.47      0.46      17.0
# Expected Behaviour                      0.33    0.24      0.28      25.0
# Investigation and Exploration           0.50    0.47      0.48      75.0
# Social Conversation                     0.72    0.74      0.73     160.0
# Motivation                              0.35    0.41      0.38      58.0
# Observed Bug Behaviour                  0.52    0.54      0.53      26.0
# Potential New Issues and Requests       0.39    0.30      0.34      46.0
# Solution Discussion                     0.63    0.60      0.61     282.0
# Task Progress                           0.21    0.16      0.18      25.0
# Solution Usage                          0.53    0.69      0.60      74.0
# Workarounds                             0.25    0.22      0.24      18.0
# Avg/Total                               0.55    0.56      0.55     867.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.96    0.98      0.97     196.0
# Contribution and Commitment             1.00    1.00      1.00      67.0
# Expected Behaviour                      0.97    0.98      0.97      99.0
# Investigation and Exploration           0.96    0.98      0.97     302.0
# Social Conversation                     0.99    0.99      0.99     639.0
# Motivation                              0.99    1.00      0.99     231.0
# Observed Bug Behaviour                  0.94    0.99      0.96     105.0
# Potential New Issues and Requests       0.99    0.99      0.99     184.0
# Solution Discussion                     1.00    0.96      0.98    1129.0
# Task Progress                           0.92    1.00      0.96     100.0
# Solution Usage                          0.94    0.98      0.96     295.0
# Workarounds                             0.97    0.97      0.97      71.0
# Avg/Total                               0.98    0.98      0.98    3467.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.60    0.50      0.55      12.0
# Bug Reproduction                        0.49    0.57      0.53      49.0
# Contribution and Commitment             0.50    0.19      0.27      16.0
# Expected Behaviour                      0.58    0.28      0.38      25.0
# Investigation and Exploration           0.50    0.48      0.49      75.0
# Social Conversation                     0.72    0.79      0.75     159.0
# Motivation                              0.45    0.37      0.40      57.0
# Observed Bug Behaviour                  0.52    0.50      0.51      26.0
# Potential New Issues and Requests       0.46    0.28      0.35      46.0
# Solution Discussion                     0.63    0.67      0.65     282.0
# Task Progress                           0.53    0.32      0.40      25.0
# Solution Usage                          0.45    0.64      0.53      73.0
# Workarounds                             0.20    0.11      0.14      18.0
# Avg/Total                               0.57    0.58      0.57     863.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.98    0.98      0.98     196.0
# Contribution and Commitment             1.00    1.00      1.00      67.0
# Expected Behaviour                      0.97    0.98      0.98     100.0
# Investigation and Exploration           0.97    0.98      0.98     302.0
# Social Conversation                     0.99    0.99      0.99     639.0
# Motivation                              0.99    1.00      0.99     231.0
# Observed Bug Behaviour                  0.97    1.00      0.99     105.0
# Potential New Issues and Requests       1.00    0.99      1.00     184.0
# Solution Discussion                     0.99    0.97      0.98    1129.0
# Task Progress                           0.85    1.00      0.92     100.0
# Solution Usage                          0.96    0.98      0.97     295.0
# Workarounds                             0.99    0.99      0.99      72.0
# Avg/Total                               0.98    0.98      0.98    3469.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.73    0.67      0.70      12.0
# Bug Reproduction                        0.56    0.55      0.56      49.0
# Contribution and Commitment             0.50    0.50      0.50      16.0
# Expected Behaviour                      0.12    0.08      0.10      24.0
# Investigation and Exploration           0.44    0.49      0.47      75.0
# Social Conversation                     0.71    0.77      0.73     159.0
# Motivation                              0.38    0.30      0.33      57.0
# Observed Bug Behaviour                  0.57    0.65      0.61      26.0
# Potential New Issues and Requests       0.32    0.13      0.18      46.0
# Solution Discussion                     0.61    0.64      0.63     282.0
# Task Progress                           0.45    0.36      0.40      25.0
# Solution Usage                          0.45    0.58      0.50      73.0
# Workarounds                             0.50    0.24      0.32      17.0
# Avg/Total                               0.54    0.56      0.55     861.0

# %% [markdown]
# ## Pipeline2 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../../results/5FOLD.xlsx')
book = load_workbook('../../results/5FOLD.xlsx')
writer = pd.ExcelWriter('../../results/5FOLD.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,5):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf2_results['train_label'+str(label_id)+'_precision'][i],clf2_results['train_label'+str(label_id)+'_recall'][i],clf2_results['train_label'+str(label_id)+'_fscore'][i],clf2_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf2_results['test_label'+str(label_id)+'_precision'][i],clf2_results['test_label'+str(label_id)+'_recall'][i],clf2_results['test_label'+str(label_id)+'_fscore'][i],clf2_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf2_results['train_avg_precision'][i],clf2_results['train_avg_recall'][i],clf2_results['train_avg_fscore'][i],clf2_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf2_results['test_avg_precision'][i],clf2_results['test_avg_recall'][i],clf2_results['test_avg_fscore'][i],clf2_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'LBS',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'LBS',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'LBS',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['LBS_train_'+str(i)] = train_report
    result_dict['LBS_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      48.0
# Bug Reproduction                        0.98    0.99      0.99     196.0
# Contribution and Commitment             1.00    1.00      1.00      66.0
# Expected Behaviour                      1.00    0.99      0.99      99.0
# Investigation and Exploration           0.97    0.98      0.98     301.0
# Social Conversation                     1.00    1.00      1.00     638.0
# Motivation                              1.00    1.00      1.00     230.0
# Observed Bug Behaviour                  1.00    0.98      0.99     104.0
# Potential New Issues and Requests       1.00    0.99      1.00     184.0
# Solution Discussion                     1.00    0.98      0.99    1128.0
# Task Progress                           0.89    1.00      0.94     100.0
# Solution Usage                          0.95    0.98      0.97     294.0
# Workarounds                             0.97    0.97      0.97      71.0
# Avg/Total                               0.99    0.99      0.99    3459.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.44    0.62      0.52      13.0
# Bug Reproduction                        0.46    0.43      0.44      49.0
# Contribution and Commitment             0.56    0.53      0.55      17.0
# Expected Behaviour                      0.76    0.52      0.62      25.0
# Investigation and Exploration           0.45    0.42      0.44      76.0
# Social Conversation                     0.71    0.69      0.70     160.0
# Motivation                              0.42    0.28      0.33      58.0
# Observed Bug Behaviour                  0.50    0.48      0.49      27.0
# Potential New Issues and Requests       0.31    0.26      0.28      46.0
# Solution Discussion                     0.60    0.67      0.64     283.0
# Task Progress                           0.44    0.28      0.34      25.0
# Solution Usage                          0.50    0.72      0.59      74.0
# Workarounds                             0.50    0.22      0.31      18.0
# Avg/Total                               0.56    0.56      0.55     871.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.97    0.98      0.98     196.0
# Contribution and Commitment             1.00    1.00      1.00      66.0
# Expected Behaviour                      0.98    0.98      0.98      99.0
# Investigation and Exploration           0.96    0.98      0.97     301.0
# Social Conversation                     1.00    0.99      0.99     638.0
# Motivation                              1.00    1.00      1.00     230.0
# Observed Bug Behaviour                  1.00    0.98      0.99     105.0
# Potential New Issues and Requests       0.99    0.99      0.99     184.0
# Solution Discussion                     1.00    0.98      0.99    1129.0
# Task Progress                           0.90    1.00      0.95     100.0
# Solution Usage                          0.96    0.98      0.97     294.0
# Workarounds                             0.96    0.97      0.97      71.0
# Avg/Total                               0.99    0.98      0.99    3462.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.75    0.75      0.75      12.0
# Bug Reproduction                        0.49    0.41      0.44      49.0
# Contribution and Commitment             0.67    0.35      0.46      17.0
# Expected Behaviour                      0.38    0.40      0.39      25.0
# Investigation and Exploration           0.44    0.50      0.47      76.0
# Social Conversation                     0.69    0.77      0.73     160.0
# Motivation                              0.51    0.33      0.40      58.0
# Observed Bug Behaviour                  0.44    0.62      0.52      26.0
# Potential New Issues and Requests       0.33    0.24      0.28      46.0
# Solution Discussion                     0.61    0.63      0.62     282.0
# Task Progress                           0.29    0.28      0.29      25.0
# Solution Usage                          0.54    0.64      0.58      74.0
# Workarounds                             0.71    0.28      0.40      18.0
# Avg/Total                               0.56    0.56      0.55     868.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.98    0.99      0.98     196.0
# Contribution and Commitment             1.00    1.00      1.00      66.0
# Expected Behaviour                      1.00    0.99      0.99      99.0
# Investigation and Exploration           0.98    0.98      0.98     302.0
# Social Conversation                     1.00    0.99      0.99     638.0
# Motivation                              1.00    1.00      1.00     230.0
# Observed Bug Behaviour                  0.94    0.98      0.96     105.0
# Potential New Issues and Requests       0.98    0.99      0.98     184.0
# Solution Discussion                     1.00    0.98      0.99    1129.0
# Task Progress                           0.98    0.99      0.99     100.0
# Solution Usage                          0.95    0.98      0.97     294.0
# Workarounds                             0.99    0.99      0.99      71.0
# Avg/Total                               0.99    0.99      0.99    3463.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.67    0.67      0.67      12.0
# Bug Reproduction                        0.52    0.57      0.54      49.0
# Contribution and Commitment             0.31    0.29      0.30      17.0
# Expected Behaviour                      0.43    0.24      0.31      25.0
# Investigation and Exploration           0.51    0.48      0.50      75.0
# Social Conversation                     0.77    0.79      0.78     160.0
# Motivation                              0.34    0.36      0.35      58.0
# Observed Bug Behaviour                  0.43    0.50      0.46      26.0
# Potential New Issues and Requests       0.44    0.26      0.33      46.0
# Solution Discussion                     0.62    0.66      0.64     282.0
# Task Progress                           0.31    0.20      0.24      25.0
# Solution Usage                          0.48    0.62      0.54      74.0
# Workarounds                             0.50    0.22      0.31      18.0
# Avg/Total                               0.56    0.57      0.56     867.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.97    0.98      0.98     196.0
# Contribution and Commitment             1.00    1.00      1.00      67.0
# Expected Behaviour                      0.98    0.98      0.98      99.0
# Investigation and Exploration           0.96    0.99      0.97     302.0
# Social Conversation                     1.00    0.99      0.99     639.0
# Motivation                              0.99    1.00      0.99     231.0
# Observed Bug Behaviour                  0.96    0.99      0.98     105.0
# Potential New Issues and Requests       0.98    0.99      0.98     184.0
# Solution Discussion                     1.00    0.97      0.98    1129.0
# Task Progress                           0.91    0.99      0.95     100.0
# Solution Usage                          0.94    0.98      0.96     295.0
# Workarounds                             0.97    0.97      0.97      71.0
# Avg/Total                               0.98    0.98      0.98    3467.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.55    0.50      0.52      12.0
# Bug Reproduction                        0.48    0.59      0.53      49.0
# Contribution and Commitment             0.23    0.19      0.21      16.0
# Expected Behaviour                      0.47    0.32      0.38      25.0
# Investigation and Exploration           0.49    0.47      0.48      75.0
# Social Conversation                     0.72    0.79      0.75     159.0
# Motivation                              0.41    0.44      0.42      57.0
# Observed Bug Behaviour                  0.50    0.50      0.50      26.0
# Potential New Issues and Requests       0.43    0.33      0.37      46.0
# Solution Discussion                     0.67    0.63      0.65     282.0
# Task Progress                           0.53    0.36      0.43      25.0
# Solution Usage                          0.42    0.60      0.50      73.0
# Workarounds                             0.25    0.11      0.15      18.0
# Avg/Total                               0.57    0.57      0.57     863.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.98    0.98      0.98     196.0
# Contribution and Commitment             1.00    1.00      1.00      67.0
# Expected Behaviour                      0.94    0.99      0.97     100.0
# Investigation and Exploration           0.98    0.98      0.98     302.0
# Social Conversation                     1.00    1.00      1.00     639.0
# Motivation                              1.00    1.00      1.00     231.0
# Observed Bug Behaviour                  1.00    1.00      1.00     105.0
# Potential New Issues and Requests       0.99    0.99      0.99     184.0
# Solution Discussion                     1.00    0.97      0.99    1129.0
# Task Progress                           0.87    0.99      0.93     100.0
# Solution Usage                          0.96    0.98      0.97     295.0
# Workarounds                             0.99    0.99      0.99      72.0
# Avg/Total                               0.99    0.99      0.99    3469.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.73    0.67      0.70      12.0
# Bug Reproduction                        0.57    0.61      0.59      49.0
# Contribution and Commitment             0.44    0.44      0.44      16.0
# Expected Behaviour                      0.09    0.08      0.09      24.0
# Investigation and Exploration           0.44    0.48      0.46      75.0
# Social Conversation                     0.73    0.76      0.75     159.0
# Motivation                              0.37    0.30      0.33      57.0
# Observed Bug Behaviour                  0.53    0.62      0.57      26.0
# Potential New Issues and Requests       0.36    0.17      0.24      46.0
# Solution Discussion                     0.63    0.65      0.64     282.0
# Task Progress                           0.48    0.40      0.43      25.0
# Solution Usage                          0.46    0.58      0.51      73.0
# Workarounds                             0.50    0.29      0.37      17.0
# Avg/Total                               0.55    0.56      0.55     861.0

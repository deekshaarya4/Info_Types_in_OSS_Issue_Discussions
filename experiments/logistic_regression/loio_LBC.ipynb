# %% [markdown]
# # Nested Leave-One-Issue-Out Cross Validation For Logistic Regression On Both Textual+Contextual Features using class_weight=balanced

# %%
import numpy as np
import pandas as pd
import xlrd as xl
from pandas import ExcelWriter
from pandas import ExcelFile
import pprint
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
import re
import pickle
from operator import itemgetter
import time, datetime
from functools import partial, update_wrapper
from openpyxl import load_workbook
from copy import deepcopy

from sklearn.externals.joblib import Parallel, delayed
from sklearn.pipeline import FeatureUnion, _fit_transform_one, _transform_one
from scipy import sparse

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from imblearn.over_sampling import SMOTE

from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from imblearn.pipeline import Pipeline as Imb_Pipeline

from sklearn.preprocessing import FunctionTransformer

from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate, LeaveOneGroupOut
from sklearn.metrics import precision_recall_fscore_support, classification_report, accuracy_score, make_scorer, confusion_matrix

pp = pprint.PrettyPrinter(indent=4)

## Ignore warnings
import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn
np.warnings.filterwarnings('ignore')

# %% [markdown]
# #### Use spaCy parser for word tokenization of a sentence:

# %%
import spacy
eng = spacy.load('en')
from spacy.lang.en import English
parser = English()

# %% [markdown]
# #### Define stopwords as punctuation + common contractions:

# %%
from string import punctuation
from nltk.corpus import stopwords

stop_words = list(punctuation) + ["'s","'m","n't","'re","-","'ll",'...'] #+ stopwords.words('english')

# %% [markdown]
# #### Code to lemmatize and tokenize:

# %%
def get_lemma(item):
    return WordNetLemmatizer().lemmatize(item)

def tokenize(line):
    line_tokens = []
    tokens = parser(line)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            line_tokens.append('URL')
        elif token.orth_.startswith('@'):
            line_tokens.append('SCREEN_NAME')
        elif str(token) not in stop_words:
            line_tokens.append(get_lemma(token.lower_))
    return line_tokens

# %%
### Read from the pickled file
all_data = pd.read_pickle('../../data/text_conv_data.pkl')

print("Size of corpus: "+str(len(all_data)))
print("Feature Size: "+str(len(list(all_data.columns.values))-1))
# Out:
# Size of corpus: 4330
# Feature Size: 23

# %%
X = all_data.drop(['Code','Document'], axis=1)
y = all_data[['Code']]
doc_groups = all_data['Document'].values

print("Number of unique labels: "+str(len(set(y['Code']))))

labels = list(set(y['Code']))
labels.sort()

pp.pprint(labels)
# Out:
# Number of unique labels: 13
# [   'Action on Issue',
#     'Bug Reproduction',
#     'Contribution and Commitment',
#     'Expected Behaviour',
#     'Investigation and Exploration',
#     'Social Conversation',
#     'Motivation',
#     'Observed Bug Behaviour',
#     'Potential New Issues and Requests',
#     'Solution Discussion',
#     'Task Progress',
#     'Solution Usage',
#     'Workarounds']

# %% [markdown]
# # Nested Cross-Validation on Logistic Regression:

# %%
# To be used within GridSearch
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# To be used in outer CV
logo = LeaveOneGroupOut()
outer_cv = logo.split(X,y,groups=doc_groups)

non_transform_features = [col for col in X.columns.values if col not in ['Text Content']]

# %% [markdown]
# ## Define pandas-compatible feature unificator
#
# This is just a pandas compatible feature unificator.
#
# This is necessary because we have two types of features: textual + conversational
#
# Hence, we first use tf-idf to vectorize the textual content and then append the conversational features to this vector using the feature unificator.

# %%
class PandasFeatureUnion(FeatureUnion):
    def fit_transform(self, X, y=None, **fit_params):
        self._validate_transformers()
        result = Parallel(n_jobs=self.n_jobs)(
            delayed(_fit_transform_one)(
                transformer=trans,
                X=X,
                y=y,
                weight=weight,
                **fit_params)
            for name, trans, weight in self._iter())
        if not result:
            return np.zeros((X.shape[0], 0))
        Xs, transformers = zip(*result)
        self._update_transformer_list(transformers)
        if any(sparse.issparse(f) for f in Xs):
            Xs = sparse.hstack(Xs).tocsr()
        else:
            Xs = self.merge_dataframes_by_column(Xs)
        return Xs

    def merge_dataframes_by_column(self, Xs):
        return pd.concat(Xs, axis="columns", copy=False)

    def transform(self, X):
        Xs = Parallel(n_jobs=self.n_jobs)(
            delayed(_transform_one)(
                transformer=trans,
                X=X,
                y=None,
                weight=weight)
            for name, trans, weight in self._iter())
        if not Xs:
            return np.zeros((X.shape[0], 0))
        if any(sparse.issparse(f) for f in Xs):
            Xs = sparse.hstack(Xs).tocsr()
        else:
            Xs = self.merge_dataframes_by_column(Xs)
        return Xs

# %%
class PandasTransform(TransformerMixin, BaseEstimator):
    def __init__(self, columns):
        self.columns = columns
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None, copy=None):
        return X.loc[:, self.columns].astype(float)

# %% [markdown]
# ## Define Pipelines
#
# 1. Pipeline1: tfidf + class_weight=balanced

# %%
class ItemSelector(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
    def fit(self, x, y=None):
        return self
    def transform(self, data_array):
        return data_array[:, self.columns]

### Simply select the conversational features, and tfidf-vectorize the textual content
ling_features = PandasTransform(non_transform_features)
tfidf_text_features = Pipeline([('extract_field',FunctionTransformer(lambda x: x['Text Content'],validate=False)),('vect',TfidfVectorizer(tokenizer=tokenize))])

### Combine the two types of feature vectors
feature_union1 = PandasFeatureUnion([
    ('selector',ling_features),
    ('text_vectorizer',tfidf_text_features)
])

pipeline1 = Pipeline([
    ('features',feature_union1),
    ('clf', LogisticRegression(class_weight='balanced')),
])

### Hyperparameters to search
parameters = {
    'features__text_vectorizer__vect__ngram_range': ((1,1),(1,2)),
    'clf__C': (0.01, 0.1, 1, 10),
}

# %% [markdown]
# ## Nested Cross Validation using GridSearch

# %%
### Define and create the scoring functions

def score_func(y_true, y_pred, score_index, i):
    return(precision_recall_fscore_support(y_true,y_pred, labels=labels)[score_index][i])

def avg_score(y_true, y_pred, score_index):
    return precision_recall_fscore_support(y_true,y_pred,average='weighted')[score_index]

def sum_support(y_true, y_pred):
    return len(y_true)

### Create partials for each of the metrics returned
score_funcs = {v: partial(score_func, score_index=k) for k, v in {0:'precision',1:'recall',2:'fscore',3:'support'}.items()}
prec_score = partial(score_func, score_index=0)
update_wrapper(prec_score,score_func)
rec_score = partial(score_func, score_index=1)
update_wrapper(rec_score,score_func)
f_score = partial(score_func, score_index=2)
update_wrapper(f_score,score_func)
support_score = partial(score_func, score_index=3)
update_wrapper(support_score,score_func)

### Create a callable scoring function for each of the metrics for each classification label
scorer = {}
for label_id in range(0,13):
    scorer['label'+str(label_id)+'_precision'] = make_scorer(prec_score, i=label_id)
    scorer['label'+str(label_id)+'_recall'] = make_scorer(rec_score, i=label_id)
    scorer['label'+str(label_id)+'_fscore'] = make_scorer(f_score, i=label_id)
    scorer['label'+str(label_id)+'_support'] = make_scorer(support_score, i=label_id)

### Create a callable scoring function for avg/total of the metrics across classification labels
scorer['avg_precision'] = make_scorer(avg_score,score_index=0)
scorer['avg_recall'] = make_scorer(avg_score,score_index=1)
scorer['avg_fscore'] = make_scorer(avg_score,score_index=2)
scorer['total_support'] = make_scorer(sum_support)

### Perform Nested cross-validation on Pipeline1
start = time.time()
clf1 = GridSearchCV(pipeline1, parameters, cv=inner_cv, scoring='f1_weighted')
clf1_results = cross_validate(clf1, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline1 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))
# Out:
# Completed Pipeline1 scenario in 11:31:18.514105

# %% [markdown]
# # Display and Save Training and Testing Results for each Fold:

# %% [markdown]
# ## Pipeline1 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../../results/LOIO.xlsx')
book = load_workbook('../../results/LOIO.xlsx')
writer = pd.ExcelWriter('../../results/LOIO.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,15):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf1_results['train_label'+str(label_id)+'_precision'][i],clf1_results['train_label'+str(label_id)+'_recall'][i],clf1_results['train_label'+str(label_id)+'_fscore'][i],clf1_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf1_results['test_label'+str(label_id)+'_precision'][i],clf1_results['test_label'+str(label_id)+'_recall'][i],clf1_results['test_label'+str(label_id)+'_fscore'][i],clf1_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf1_results['train_avg_precision'][i],clf1_results['train_avg_recall'][i],clf1_results['train_avg_fscore'][i],clf1_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf1_results['test_avg_precision'][i],clf1_results['test_avg_recall'][i],clf1_results['test_avg_fscore'][i],clf1_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'LBC',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'LBC',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'LBC',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['LBC_train_'+str(i)] = train_report
    result_dict['LBC_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      53.0
# Bug Reproduction                        0.98    0.99      0.98     245.0
# Contribution and Commitment             1.00    1.00      1.00      58.0
# Expected Behaviour                      0.99    0.98      0.99     119.0
# Investigation and Exploration           0.96    0.98      0.97     377.0
# Social Conversation                     0.99    0.99      0.99     546.0
# Motivation                              0.98    1.00      0.99     261.0
# Observed Bug Behaviour                  0.97    0.99      0.98     131.0
# Potential New Issues and Requests       1.00    1.00      1.00     208.0
# Solution Discussion                     0.99    0.97      0.98    1338.0
# Task Progress                           0.99    1.00      1.00     104.0
# Solution Usage                          0.95    0.98      0.96     368.0
# Workarounds                             0.91    0.98      0.94      86.0
# Avg/Total                               0.98    0.98      0.98    3894.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.75    0.38      0.50       8.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.60    0.12      0.20      25.0
# Expected Behaviour                      0.00    0.00      0.00       5.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.91    0.87      0.89     252.0
# Motivation                              0.33    0.04      0.07      27.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      22.0
# Solution Discussion                     0.41    0.52      0.46      73.0
# Task Progress                           0.42    0.24      0.30      21.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.68    0.62      0.63     436.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      60.0
# Bug Reproduction                        0.98    0.98      0.98     245.0
# Contribution and Commitment             1.00    1.00      1.00      80.0
# Expected Behaviour                      0.91    1.00      0.95      42.0
# Investigation and Exploration           0.95    0.98      0.96     377.0
# Social Conversation                     0.99    0.98      0.98     716.0
# Motivation                              1.00    1.00      1.00     134.0
# Observed Bug Behaviour                  0.98    0.99      0.99     131.0
# Potential New Issues and Requests       1.00    0.99      0.99     217.0
# Solution Discussion                     0.99    0.96      0.98    1231.0
# Task Progress                           0.89    0.99      0.94     113.0
# Solution Usage                          0.93    0.98      0.95     272.0
# Workarounds                             0.97    0.98      0.98      66.0
# Avg/Total                               0.98    0.98      0.98    3684.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.33    1.00      0.50       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.25    0.67      0.36       3.0
# Expected Behaviour                      0.20    0.01      0.02      82.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.55    0.76      0.64      82.0
# Motivation                              0.71    0.08      0.14     154.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.14    0.08      0.10      13.0
# Solution Discussion                     0.39    0.75      0.51     180.0
# Task Progress                           0.25    0.17      0.20      12.0
# Solution Usage                          0.24    0.24      0.24      96.0
# Workarounds                             1.00    0.04      0.08      23.0
# Avg/Total                               0.45    0.37      0.31     646.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      58.0
# Bug Reproduction                        0.98    0.99      0.98     216.0
# Contribution and Commitment             1.00    1.00      1.00      77.0
# Expected Behaviour                      0.98    0.98      0.98     124.0
# Investigation and Exploration           0.97    0.98      0.98     309.0
# Social Conversation                     0.99    0.98      0.99     773.0
# Motivation                              0.99    1.00      0.99     288.0
# Observed Bug Behaviour                  0.98    0.99      0.99     125.0
# Potential New Issues and Requests       0.99    0.99      0.99     167.0
# Solution Discussion                     0.99    0.97      0.98    1386.0
# Task Progress                           0.86    1.00      0.92     117.0
# Solution Usage                          0.94    0.98      0.96     368.0
# Workarounds                             0.99    0.98      0.98      89.0
# Avg/Total                               0.98    0.98      0.98    4097.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.12    0.33      0.18       3.0
# Bug Reproduction                        0.50    0.34      0.41      29.0
# Contribution and Commitment             0.12    0.17      0.14       6.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.40    0.34      0.37      68.0
# Social Conversation                     0.41    0.76      0.54      25.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.60    0.50      0.55       6.0
# Potential New Issues and Requests       0.00    0.00      0.00      63.0
# Solution Discussion                     0.31    0.88      0.46      25.0
# Task Progress                           0.50    0.25      0.33       8.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.29    0.35      0.30     233.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      55.0
# Bug Reproduction                        0.91    0.97      0.94     201.0
# Contribution and Commitment             0.96    1.00      0.98      75.0
# Expected Behaviour                      0.90    0.99      0.95     124.0
# Investigation and Exploration           0.89    0.95      0.92     351.0
# Social Conversation                     0.95    0.95      0.95     752.0
# Motivation                              0.91    0.99      0.95     288.0
# Observed Bug Behaviour                  0.93    0.99      0.96     121.0
# Potential New Issues and Requests       0.94    0.97      0.95     218.0
# Solution Discussion                     0.99    0.87      0.92    1318.0
# Task Progress                           0.80    0.99      0.89     107.0
# Solution Usage                          0.87    0.96      0.91     366.0
# Workarounds                             0.92    0.98      0.95      85.0
# Avg/Total                               0.94    0.93      0.93    4061.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.83    0.83      0.83       6.0
# Bug Reproduction                        0.75    0.20      0.32      44.0
# Contribution and Commitment             0.75    0.38      0.50       8.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.33    0.08      0.12      26.0
# Social Conversation                     0.58    0.78      0.67      46.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.55    0.60      0.57      10.0
# Potential New Issues and Requests       0.00    0.00      0.00      12.0
# Solution Discussion                     0.59    0.46      0.52      93.0
# Task Progress                           0.25    0.22      0.24      18.0
# Solution Usage                          0.00    0.00      0.00       2.0
# Workarounds                             0.00    0.00      0.00       4.0
# Avg/Total                               0.54    0.40      0.43     269.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      53.0
# Bug Reproduction                        0.98    0.99      0.98     244.0
# Contribution and Commitment             1.00    1.00      1.00      83.0
# Expected Behaviour                      0.98    0.98      0.98     121.0
# Investigation and Exploration           0.97    0.98      0.97     376.0
# Social Conversation                     0.99    0.98      0.99     757.0
# Motivation                              0.99    1.00      0.99     272.0
# Observed Bug Behaviour                  0.98    0.99      0.99     131.0
# Potential New Issues and Requests       0.99    0.99      0.99     229.0
# Solution Discussion                     0.99    0.96      0.98    1214.0
# Task Progress                           0.85    1.00      0.92     117.0
# Solution Usage                          0.94    0.98      0.96     367.0
# Workarounds                             0.99    0.98      0.98      87.0
# Avg/Total                               0.98    0.98      0.98    4051.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.62      0.77       8.0
# Bug Reproduction                        0.00    0.00      0.00       1.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       1.0
# Social Conversation                     0.52    0.78      0.63      41.0
# Motivation                              0.03    0.06      0.04      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.89    0.57      0.70     197.0
# Task Progress                           0.75    0.38      0.50       8.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       2.0
# Avg/Total                               0.76    0.55      0.62     279.0
#
# ------------------------- FOLD 5: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      55.0
# Bug Reproduction                        0.99    0.99      0.99     160.0
# Contribution and Commitment             1.00    1.00      1.00      78.0
# Expected Behaviour                      0.98    0.98      0.98     124.0
# Investigation and Exploration           0.95    0.98      0.96     266.0
# Social Conversation                     0.99    0.98      0.99     759.0
# Motivation                              0.98    1.00      0.99     287.0
# Observed Bug Behaviour                  0.97    0.98      0.98     125.0
# Potential New Issues and Requests       0.99    0.99      0.99     230.0
# Solution Discussion                     0.99    0.97      0.98    1349.0
# Task Progress                           0.87    1.00      0.93     122.0
# Solution Usage                          0.95    0.98      0.96     368.0
# Workarounds                             0.99    0.98      0.98      89.0
# Avg/Total                               0.98    0.98      0.98    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.67    0.33      0.44       6.0
# Bug Reproduction                        0.71    0.49      0.58      85.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.75    0.30      0.43     111.0
# Social Conversation                     0.58    0.87      0.69      39.0
# Motivation                              0.00    0.00      0.00       1.0
# Observed Bug Behaviour                  0.50    0.83      0.62       6.0
# Potential New Issues and Requests       0.00    0.00      0.00       0.0
# Solution Discussion                     0.35    0.47      0.40      62.0
# Task Progress                           0.20    0.33      0.25       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.62    0.46      0.49     318.0
#
# ------------------------- FOLD 6: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      59.0
# Bug Reproduction                        0.99    0.99      0.99     204.0
# Contribution and Commitment             1.00    1.00      1.00      80.0
# Expected Behaviour                      0.95    0.99      0.97     124.0
# Investigation and Exploration           0.96    0.98      0.97     365.0
# Social Conversation                     0.99    0.98      0.99     760.0
# Motivation                              0.99    1.00      0.99     278.0
# Observed Bug Behaviour                  0.98    0.98      0.98     127.0
# Potential New Issues and Requests       1.00    0.99      0.99     228.0
# Solution Discussion                     1.00    0.97      0.98    1219.0
# Task Progress                           0.88    1.00      0.94     120.0
# Solution Usage                          0.95    0.98      0.97     368.0
# Workarounds                             0.99    0.99      0.99      80.0
# Avg/Total                               0.98    0.98      0.98    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       2.0
# Bug Reproduction                        0.41    0.39      0.40      41.0
# Contribution and Commitment             0.33    0.33      0.33       3.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.15    0.33      0.21      12.0
# Social Conversation                     0.35    0.76      0.48      38.0
# Motivation                              0.09    0.10      0.10      10.0
# Observed Bug Behaviour                  0.23    0.75      0.35       4.0
# Potential New Issues and Requests       0.00    0.00      0.00       2.0
# Solution Discussion                     0.78    0.28      0.41     192.0
# Task Progress                           0.07    0.20      0.10       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       9.0
# Avg/Total                               0.58    0.34      0.38     318.0
#
# ------------------------- FOLD 7: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      52.0
# Bug Reproduction                        0.97    0.99      0.98     245.0
# Contribution and Commitment             1.00    1.00      1.00      78.0
# Expected Behaviour                      0.99    0.98      0.99     123.0
# Investigation and Exploration           0.97    0.99      0.98     377.0
# Social Conversation                     0.99    0.98      0.99     726.0
# Motivation                              0.98    1.00      0.99     285.0
# Observed Bug Behaviour                  0.98    0.99      0.98     131.0
# Potential New Issues and Requests       0.99    0.99      0.99     226.0
# Solution Discussion                     1.00    0.97      0.98    1342.0
# Task Progress                           0.90    1.00      0.94     120.0
# Solution Usage                          0.91    0.98      0.94     105.0
# Workarounds                             0.99    0.98      0.98      89.0
# Avg/Total                               0.98    0.98      0.98    3899.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.44      0.62       9.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.66    0.74      0.70      72.0
# Motivation                              0.00    0.00      0.00       3.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       4.0
# Solution Discussion                     0.22    0.52      0.31      69.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.68    0.06      0.11     263.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.58    0.25      0.24     431.0
#
# ------------------------- FOLD 8: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.98    1.00      0.99      57.0
# Bug Reproduction                        0.91    0.98      0.94     245.0
# Contribution and Commitment             0.96    1.00      0.98      81.0
# Expected Behaviour                      0.92    0.98      0.95     121.0
# Investigation and Exploration           0.89    0.94      0.91     377.0
# Social Conversation                     0.95    0.94      0.94     774.0
# Motivation                              0.92    0.99      0.95     272.0
# Observed Bug Behaviour                  0.94    0.99      0.97     131.0
# Potential New Issues and Requests       0.94    0.97      0.95     179.0
# Solution Discussion                     0.98    0.87      0.92    1386.0
# Task Progress                           0.80    0.99      0.89     120.0
# Solution Usage                          0.87    0.96      0.91     368.0
# Workarounds                             0.90    0.98      0.94      83.0
# Avg/Total                               0.94    0.93      0.93    4194.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.50      0.67       4.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.33    0.50      0.40       2.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.67    0.42      0.51      24.0
# Motivation                              0.29    0.12      0.17      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       1.00    0.08      0.15      51.0
# Solution Discussion                     0.24    0.76      0.37      25.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             1.00    0.17      0.29       6.0
# Avg/Total                               0.65    0.29      0.27     136.0
#
# ------------------------- FOLD 9: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      58.0
# Bug Reproduction                        0.91    0.98      0.94     245.0
# Contribution and Commitment             0.96    1.00      0.98      78.0
# Expected Behaviour                      0.93    0.98      0.95     118.0
# Investigation and Exploration           0.88    0.95      0.92     349.0
# Social Conversation                     0.95    0.95      0.95     766.0
# Motivation                              0.92    0.99      0.95     282.0
# Observed Bug Behaviour                  0.94    1.00      0.97     115.0
# Potential New Issues and Requests       0.94    0.97      0.95     229.0
# Solution Discussion                     0.98    0.87      0.92    1335.0
# Task Progress                           0.84    0.98      0.91     111.0
# Solution Usage                          0.88    0.96      0.92     365.0
# Workarounds                             0.84    1.00      0.91      59.0
# Avg/Total                               0.94    0.93      0.93    4110.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.67      0.80       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.60    0.60      0.60       5.0
# Expected Behaviour                      0.75    0.50      0.60       6.0
# Investigation and Exploration           0.27    0.11      0.15      28.0
# Social Conversation                     0.65    0.62      0.63      32.0
# Motivation                              0.09    0.17      0.12       6.0
# Observed Bug Behaviour                  0.30    0.19      0.23      16.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.51    0.61      0.55      76.0
# Task Progress                           0.33    0.29      0.31      14.0
# Solution Usage                          0.20    0.33      0.25       3.0
# Workarounds                             1.00    0.13      0.24      30.0
# Avg/Total                               0.54    0.41      0.42     220.0
#
# ------------------------- FOLD 10: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.98    1.00      0.99      56.0
# Bug Reproduction                        0.91    0.97      0.94     238.0
# Contribution and Commitment             0.95    1.00      0.98      83.0
# Expected Behaviour                      0.92    0.98      0.95     124.0
# Investigation and Exploration           0.88    0.95      0.91     353.0
# Social Conversation                     0.94    0.94      0.94     788.0
# Motivation                              0.92    0.99      0.95     288.0
# Observed Bug Behaviour                  0.93    0.99      0.96     123.0
# Potential New Issues and Requests       0.93    0.97      0.95     202.0
# Solution Discussion                     0.98    0.86      0.92    1411.0
# Task Progress                           0.81    0.99      0.89     122.0
# Solution Usage                          0.85    0.96      0.90     368.0
# Workarounds                             0.91    0.97      0.94      88.0
# Avg/Total                               0.93    0.93      0.93    4244.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.80    0.80      0.80       5.0
# Bug Reproduction                        0.67    0.57      0.62       7.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.60    0.12      0.21      24.0
# Social Conversation                     0.46    0.60      0.52      10.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.75    0.75      0.75       8.0
# Potential New Issues and Requests       0.44    0.14      0.22      28.0
# Solution Discussion                     0.00    0.00      0.00       0.0
# Task Progress                           0.40    0.67      0.50       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       1.0
# Avg/Total                               0.55    0.34      0.37      86.0
#
# ------------------------- FOLD 11: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      60.0
# Bug Reproduction                        0.98    0.99      0.98     245.0
# Contribution and Commitment             1.00    1.00      1.00      81.0
# Expected Behaviour                      0.97    0.98      0.97     118.0
# Investigation and Exploration           0.96    0.98      0.97     377.0
# Social Conversation                     0.99    0.98      0.99     755.0
# Motivation                              0.99    1.00      0.99     268.0
# Observed Bug Behaviour                  0.99    0.99      0.99     131.0
# Potential New Issues and Requests       1.00    0.99      1.00     225.0
# Solution Discussion                     0.99    0.97      0.98    1224.0
# Task Progress                           0.87    1.00      0.93     121.0
# Solution Usage                          0.95    0.98      0.96     368.0
# Workarounds                             0.95    0.98      0.97      86.0
# Avg/Total                               0.98    0.98      0.98    4059.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.33    1.00      0.50       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.50    1.00      0.67       2.0
# Expected Behaviour                      0.67    0.33      0.44       6.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.83    0.44      0.58      43.0
# Motivation                              0.25    0.20      0.22      20.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.01    0.20      0.03       5.0
# Solution Discussion                     0.88    0.61      0.72     187.0
# Task Progress                           0.50    0.25      0.33       4.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.79    0.53      0.63     271.0
#
# ------------------------- FOLD 12: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.98    1.00      0.99      59.0
# Bug Reproduction                        0.89    0.98      0.93     207.0
# Contribution and Commitment             0.97    1.00      0.99      76.0
# Expected Behaviour                      0.92    0.98      0.94     123.0
# Investigation and Exploration           0.90    0.97      0.93     273.0
# Social Conversation                     0.95    0.93      0.94     756.0
# Motivation                              0.92    0.99      0.95     288.0
# Observed Bug Behaviour                  0.91    1.00      0.95      50.0
# Potential New Issues and Requests       0.93    0.96      0.95     228.0
# Solution Discussion                     0.98    0.88      0.93    1367.0
# Task Progress                           0.84    0.99      0.91     125.0
# Solution Usage                          0.87    0.96      0.92     368.0
# Workarounds                             0.91    0.98      0.94      81.0
# Avg/Total                               0.94    0.94      0.94    4001.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       2.0
# Bug Reproduction                        0.40    0.37      0.38      38.0
# Contribution and Commitment             0.29    0.29      0.29       7.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.45    0.33      0.38     104.0
# Social Conversation                     0.47    0.55      0.51      42.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.33    0.02      0.05      81.0
# Potential New Issues and Requests       0.00    0.00      0.00       2.0
# Solution Discussion                     0.16    0.14      0.15      44.0
# Task Progress                           0.00    0.00      0.00       0.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.67    0.25      0.36       8.0
# Avg/Total                               0.38    0.25      0.27     329.0
#
# ------------------------- FOLD 13: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      61.0
# Bug Reproduction                        0.98    0.99      0.98     245.0
# Contribution and Commitment             1.00    1.00      1.00      76.0
# Expected Behaviour                      1.00    0.99      1.00     110.0
# Investigation and Exploration           0.95    0.98      0.97     374.0
# Social Conversation                     0.99    0.98      0.98     760.0
# Motivation                              0.98    1.00      0.99     255.0
# Observed Bug Behaviour                  0.96    0.99      0.98     131.0
# Potential New Issues and Requests       0.99    0.99      0.99     205.0
# Solution Discussion                     1.00    0.96      0.98    1288.0
# Task Progress                           0.88    1.00      0.93     120.0
# Solution Usage                          0.94    0.98      0.96     366.0
# Workarounds                             0.97    0.98      0.97      89.0
# Avg/Total                               0.98    0.98      0.98    4080.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       0.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             1.00    0.14      0.25       7.0
# Expected Behaviour                      0.00    0.00      0.00      14.0
# Investigation and Exploration           0.00    0.00      0.00       3.0
# Social Conversation                     0.67    0.58      0.62      38.0
# Motivation                              0.15    0.21      0.17      33.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      25.0
# Solution Discussion                     0.52    0.59      0.55     123.0
# Task Progress                           0.18    0.40      0.25       5.0
# Solution Usage                          0.00    0.00      0.00       2.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.41    0.42      0.40     250.0
#
# ------------------------- FOLD 14: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.98    1.00      0.99      58.0
# Bug Reproduction                        0.91    0.98      0.94     245.0
# Contribution and Commitment             0.95    1.00      0.98      78.0
# Expected Behaviour                      0.92    0.98      0.95     121.0
# Investigation and Exploration           0.89    0.94      0.92     377.0
# Social Conversation                     0.94    0.94      0.94     784.0
# Motivation                              0.92    0.99      0.95     286.0
# Observed Bug Behaviour                  0.95    0.99      0.97     131.0
# Potential New Issues and Requests       0.94    0.96      0.95     229.0
# Solution Discussion                     0.98    0.86      0.92    1346.0
# Task Progress                           0.79    1.00      0.88     111.0
# Solution Usage                          0.86    0.96      0.91     367.0
# Workarounds                             0.95    0.98      0.96      89.0
# Avg/Total                               0.93    0.93      0.93    4222.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.67    0.67      0.67       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.25    0.20      0.22       5.0
# Expected Behaviour                      0.40    0.67      0.50       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.37    0.71      0.49      14.0
# Motivation                              0.00    0.00      0.00       2.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.83    0.37      0.51      65.0
# Task Progress                           0.22    0.14      0.17      14.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.62    0.38      0.44     108.0

# %% [markdown]
# ### Get list of F1 scores and support-weighted average F1 score

# %%
avg_f1 = []
for i in range(0,15):
    avg_f1.append(float('%.4f' % round(clf1_results['test_avg_fscore'][i],4)))
    
print('Pipeline1:')
print(avg_f1)

sum = 0
den = 0
for i in range(0,15):
    sum += clf1_results['test_avg_fscore'][i] * clf1_results['test_total_support'][i]
    den += clf1_results['test_total_support'][i]
print('Pipeline1: Total weighted F-Score: '+('%.4f' % round(sum/den,4)))
# Out:
# Pipeline1:
# [0.6298, 0.306, 0.2955, 0.4282, 0.6237, 0.4907, 0.3781, 0.2431, 0.2714, 0.4182, 0.3726, 0.6276, 0.275, 0.4011, 0.4358]
# Pipeline1: Total weighted F-Score: 0.4111

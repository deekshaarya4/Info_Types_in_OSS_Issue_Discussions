# %% [markdown]
# # Nested 5-Fold Cross Validation For Logistic Regression On Textual Features

# %%
import numpy as np
import pandas as pd
import xlrd as xl
from pandas import ExcelWriter
from pandas import ExcelFile
import pprint
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
import re
import pickle
from operator import itemgetter
import time, datetime
from functools import partial, update_wrapper
from openpyxl import load_workbook

from sklearn.feature_extraction.text import TfidfVectorizer

from imblearn.over_sampling import SMOTE

from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as Imb_Pipeline

from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate
from sklearn.metrics import precision_recall_fscore_support, classification_report, accuracy_score, make_scorer, confusion_matrix

pp = pprint.PrettyPrinter(indent=4)

## Ignore warnings
import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn
np.warnings.filterwarnings('ignore')

# %% [markdown]
# #### Use spaCy parser for word tokenization of a sentence:

# %%
import spacy
eng = spacy.load('en')
from spacy.lang.en import English
parser = English()

# %% [markdown]
# #### Define stopwords as punctuation + common contractions:

# %%
from string import punctuation
from nltk.corpus import stopwords

stop_words = list(punctuation) + ["'s","'m","n't","'re","-","'ll",'...'] #+ stopwords.words('english')

# %% [markdown]
# #### Code to lemmatize and tokenize:

# %%
def get_lemma(item):
    return WordNetLemmatizer().lemmatize(item)

def tokenize(line):
    line_tokens = []
    tokens = parser(line)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            line_tokens.append('URL')
        elif token.orth_.startswith('@'):
            line_tokens.append('SCREEN_NAME')
        elif str(token) not in stop_words:
            line_tokens.append(get_lemma(token.lower_))
    return line_tokens

# %%
### Read from the pickled file
all_data = pd.read_pickle('../../data/text_conv_data.pkl')

print("Size of corpus: "+str(len(all_data)))
# Out:
# Size of corpus: 4330

# %%
X = all_data['Text Content'].values
y = all_data['Code'].values

print("Number of unique labels: "+str(len(set(y))))

labels = list(set(y))
labels.sort()

pp.pprint(labels)
# Out:
# Number of unique labels: 13
# [   'Action on Issue',
#     'Bug Reproduction',
#     'Contribution and Commitment',
#     'Expected Behaviour',
#     'Investigation and Exploration',
#     'Social Conversation',
#     'Motivation',
#     'Observed Bug Behaviour',
#     'Potential New Issues and Requests',
#     'Solution Discussion',
#     'Task Progress',
#     'Solution Usage',
#     'Workarounds']

# %% [markdown]
# # Nested Cross-Validation on Logistic Regression:

# %%
# To be used within GridSearch
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# To be used in outer CV
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# ## Define Pipelines
#
# 1. Pipeline1: tfidf + class_weight=balanced
# 2. Pipeline2: tfidf + SMOTE

# %%
pipeline1 = Pipeline([
    ('vect', TfidfVectorizer(tokenizer=tokenize)),
    ('clf', LogisticRegression(class_weight='balanced')),
])
pipeline2 = Imb_Pipeline([
    ('vect', TfidfVectorizer(tokenizer=tokenize)),
    ('smote', SMOTE()),
    ('clf', LogisticRegression())
])

### Hyperparameters to search
parameters = {
    'vect__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams
    'clf__C': (0.01, 0.1, 1, 10),
}

# %% [markdown]
# ## Nested Cross Validation using GridSearch

# %%
### Define and create the scoring functions

def score_func(y_true, y_pred, score_index, i):
    return(precision_recall_fscore_support(y_true,y_pred)[score_index][i])

def avg_score(y_true, y_pred, score_index):
    return precision_recall_fscore_support(y_true,y_pred,average='weighted')[score_index]

def sum_support(y_true, y_pred):
    return len(y_true)

### Create partials for each of the metrics returned
score_funcs = {v: partial(score_func, score_index=k) for k, v in {0:'precision',1:'recall',2:'fscore',3:'support'}.items()}
prec_score = partial(score_func, score_index=0)
update_wrapper(prec_score,score_func)
rec_score = partial(score_func, score_index=1)
update_wrapper(rec_score,score_func)
f_score = partial(score_func, score_index=2)
update_wrapper(f_score,score_func)
support_score = partial(score_func, score_index=3)
update_wrapper(support_score,score_func)

### Create a callable scoring function for each of the metrics for each classification label
scorer = {}
for label_id in range(0,13):
    scorer['label'+str(label_id)+'_precision'] = make_scorer(prec_score, i=label_id)
    scorer['label'+str(label_id)+'_recall'] = make_scorer(rec_score, i=label_id)
    scorer['label'+str(label_id)+'_fscore'] = make_scorer(f_score, i=label_id)
    scorer['label'+str(label_id)+'_support'] = make_scorer(support_score, i=label_id)

### Create a callable scoring function for avg/total of the metrics across classification labels
scorer['avg_precision'] = make_scorer(avg_score,score_index=0)
scorer['avg_recall'] = make_scorer(avg_score,score_index=1)
scorer['avg_fscore'] = make_scorer(avg_score,score_index=2)
scorer['total_support'] = make_scorer(sum_support)

### Perform Nested cross-validation on Pipeline1
start = time.time()
clf1 = GridSearchCV(pipeline1, parameters, cv=inner_cv, scoring='f1_weighted')
clf1_results = cross_validate(clf1, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline1 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))

### Perform Nested cross-validation on Pipeline2
start = time.time()
clf2 = GridSearchCV(pipeline2, parameters, cv=inner_cv, scoring='f1_weighted')
clf2_results = cross_validate(clf2, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline2 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))
# Out:
# Completed Pipeline1 scenario in 0:48:44.902198
# Completed Pipeline2 scenario in 1:48:07.560490

# %% [markdown]
# # Display and Save Training and Testing Results for each Fold:

# %% [markdown]
# ## Pipeline1 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

writer = pd.ExcelWriter('../../results/5FOLD.xlsx')
# book = load_workbook('../../results/5FOLD.xlsx')
# writer = pd.ExcelWriter('../../results/5FOLD.xlsx', engine='openpyxl')
# writer.book = book
# writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,5):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf1_results['train_label'+str(label_id)+'_precision'][i],clf1_results['train_label'+str(label_id)+'_recall'][i],clf1_results['train_label'+str(label_id)+'_fscore'][i],clf1_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf1_results['test_label'+str(label_id)+'_precision'][i],clf1_results['test_label'+str(label_id)+'_recall'][i],clf1_results['test_label'+str(label_id)+'_fscore'][i],clf1_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf1_results['train_avg_precision'][i],clf1_results['train_avg_recall'][i],clf1_results['train_avg_fscore'][i],clf1_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf1_results['test_avg_precision'][i],clf1_results['test_avg_recall'][i],clf1_results['test_avg_fscore'][i],clf1_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'LTC',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'LTC',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'LTC',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['LTC_train_'+str(i)] = train_report
    result_dict['LTC_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      48.0
# Bug Reproduction                        0.92    0.97      0.94     196.0
# Contribution and Commitment             0.93    1.00      0.96      66.0
# Expected Behaviour                      0.95    0.99      0.97      99.0
# Investigation and Exploration           0.93    0.96      0.94     301.0
# Social Conversation                     0.96    0.95      0.96     638.0
# Motivation                              0.96    0.99      0.97     230.0
# Observed Bug Behaviour                  0.73    0.97      0.83     104.0
# Potential New Issues and Requests       0.95    0.96      0.95     184.0
# Solution Discussion                     0.99    0.89      0.94    1128.0
# Task Progress                           0.79    0.99      0.88     100.0
# Solution Usage                          0.90    0.95      0.92     294.0
# Workarounds                             0.95    0.97      0.96      71.0
# Avg/Total                               0.95    0.94      0.94    3459.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.47    0.54      0.50      13.0
# Bug Reproduction                        0.50    0.45      0.47      49.0
# Contribution and Commitment             0.50    0.59      0.54      17.0
# Expected Behaviour                      0.32    0.32      0.32      25.0
# Investigation and Exploration           0.39    0.38      0.39      76.0
# Social Conversation                     0.72    0.67      0.69     160.0
# Motivation                              0.29    0.21      0.24      58.0
# Observed Bug Behaviour                  0.18    0.26      0.21      27.0
# Potential New Issues and Requests       0.29    0.33      0.31      46.0
# Solution Discussion                     0.58    0.58      0.58     283.0
# Task Progress                           0.22    0.24      0.23      25.0
# Solution Usage                          0.52    0.62      0.57      74.0
# Workarounds                             0.29    0.22      0.25      18.0
# Avg/Total                               0.51    0.50      0.50     871.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.99    0.95      0.97     196.0
# Contribution and Commitment             0.97    1.00      0.99      66.0
# Expected Behaviour                      1.00    0.98      0.99      99.0
# Investigation and Exploration           0.99    0.97      0.98     301.0
# Social Conversation                     0.99    0.99      0.99     638.0
# Motivation                              1.00    1.00      1.00     230.0
# Observed Bug Behaviour                  0.97    0.97      0.97     105.0
# Potential New Issues and Requests       0.99    0.98      0.99     184.0
# Solution Discussion                     1.00    0.97      0.98    1129.0
# Task Progress                           0.85    1.00      0.92     100.0
# Solution Usage                          0.88    0.99      0.93     294.0
# Workarounds                             1.00    0.97      0.99      71.0
# Avg/Total                               0.98    0.98      0.98    3462.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.73    0.67      0.70      12.0
# Bug Reproduction                        0.51    0.43      0.47      49.0
# Contribution and Commitment             0.75    0.35      0.48      17.0
# Expected Behaviour                      0.40    0.16      0.23      25.0
# Investigation and Exploration           0.48    0.45      0.46      76.0
# Social Conversation                     0.73    0.74      0.74     160.0
# Motivation                              0.39    0.24      0.30      58.0
# Observed Bug Behaviour                  0.29    0.19      0.23      26.0
# Potential New Issues and Requests       0.26    0.15      0.19      46.0
# Solution Discussion                     0.52    0.68      0.59     282.0
# Task Progress                           0.27    0.24      0.26      25.0
# Solution Usage                          0.44    0.53      0.48      74.0
# Workarounds                             0.83    0.28      0.42      18.0
# Avg/Total                               0.52    0.53      0.51     868.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.98    0.96      0.97     196.0
# Contribution and Commitment             0.99    1.00      0.99      66.0
# Expected Behaviour                      1.00    0.99      0.99      99.0
# Investigation and Exploration           0.99    0.97      0.98     302.0
# Social Conversation                     1.00    0.99      0.99     638.0
# Motivation                              1.00    1.00      1.00     230.0
# Observed Bug Behaviour                  0.73    0.97      0.84     105.0
# Potential New Issues and Requests       0.99    0.98      0.99     184.0
# Solution Discussion                     0.99    0.98      0.99    1129.0
# Task Progress                           0.99    0.99      0.99     100.0
# Solution Usage                          1.00    0.97      0.98     294.0
# Workarounds                             0.99    0.99      0.99      71.0
# Avg/Total                               0.98    0.98      0.98    3463.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.75    0.50      0.60      12.0
# Bug Reproduction                        0.53    0.49      0.51      49.0
# Contribution and Commitment             0.67    0.35      0.46      17.0
# Expected Behaviour                      0.36    0.20      0.26      25.0
# Investigation and Exploration           0.49    0.43      0.46      75.0
# Social Conversation                     0.75    0.75      0.75     160.0
# Motivation                              0.38    0.31      0.34      58.0
# Observed Bug Behaviour                  0.13    0.15      0.14      26.0
# Potential New Issues and Requests       0.45    0.22      0.29      46.0
# Solution Discussion                     0.56    0.73      0.63     282.0
# Task Progress                           0.27    0.12      0.17      25.0
# Solution Usage                          0.50    0.55      0.53      74.0
# Workarounds                             0.80    0.22      0.35      18.0
# Avg/Total                               0.55    0.55      0.54     867.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.97    0.96      0.97     196.0
# Contribution and Commitment             0.97    1.00      0.99      67.0
# Expected Behaviour                      0.96    0.98      0.97      99.0
# Investigation and Exploration           0.98    0.98      0.98     302.0
# Social Conversation                     0.99    0.98      0.98     639.0
# Motivation                              0.99    1.00      0.99     231.0
# Observed Bug Behaviour                  0.98    0.94      0.96     105.0
# Potential New Issues and Requests       0.99    0.98      0.99     184.0
# Solution Discussion                     0.99    0.96      0.98    1129.0
# Task Progress                           0.85    1.00      0.92     100.0
# Solution Usage                          0.87    0.99      0.93     295.0
# Workarounds                             1.00    0.97      0.99      71.0
# Avg/Total                               0.97    0.97      0.97    3467.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.86    0.50      0.63      12.0
# Bug Reproduction                        0.46    0.53      0.50      49.0
# Contribution and Commitment             0.38    0.19      0.25      16.0
# Expected Behaviour                      0.38    0.24      0.29      25.0
# Investigation and Exploration           0.43    0.41      0.42      75.0
# Social Conversation                     0.75    0.78      0.76     159.0
# Motivation                              0.38    0.35      0.37      57.0
# Observed Bug Behaviour                  0.33    0.23      0.27      26.0
# Potential New Issues and Requests       0.46    0.26      0.33      46.0
# Solution Discussion                     0.55    0.63      0.59     282.0
# Task Progress                           0.53    0.40      0.45      25.0
# Solution Usage                          0.46    0.56      0.50      73.0
# Workarounds                             0.29    0.11      0.16      18.0
# Avg/Total                               0.53    0.54      0.53     863.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.98    0.97      0.97     196.0
# Contribution and Commitment             0.99    1.00      0.99      67.0
# Expected Behaviour                      0.96    0.98      0.97     100.0
# Investigation and Exploration           0.98    0.97      0.98     302.0
# Social Conversation                     0.99    0.97      0.98     639.0
# Motivation                              1.00    1.00      1.00     231.0
# Observed Bug Behaviour                  0.99    0.98      0.99     105.0
# Potential New Issues and Requests       0.99    0.99      0.99     184.0
# Solution Discussion                     0.98    0.97      0.97    1129.0
# Task Progress                           0.85    1.00      0.92     100.0
# Solution Usage                          0.97    0.97      0.97     295.0
# Workarounds                             0.97    0.99      0.98      72.0
# Avg/Total                               0.98    0.98      0.98    3469.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.78    0.58      0.67      12.0
# Bug Reproduction                        0.42    0.51      0.46      49.0
# Contribution and Commitment             0.47    0.56      0.51      16.0
# Expected Behaviour                      0.14    0.08      0.11      24.0
# Investigation and Exploration           0.45    0.45      0.45      75.0
# Social Conversation                     0.75    0.72      0.74     159.0
# Motivation                              0.33    0.28      0.30      57.0
# Observed Bug Behaviour                  0.46    0.23      0.31      26.0
# Potential New Issues and Requests       0.32    0.15      0.21      46.0
# Solution Discussion                     0.58    0.71      0.64     282.0
# Task Progress                           0.50    0.48      0.49      25.0
# Solution Usage                          0.44    0.47      0.45      73.0
# Workarounds                             0.50    0.18      0.26      17.0
# Avg/Total                               0.53    0.54      0.53     861.0

# %% [markdown]
# ## Pipeline2 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../../results/5FOLD.xlsx')
book = load_workbook('../../results/5FOLD.xlsx')
writer = pd.ExcelWriter('../../results/5FOLD.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,5):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf2_results['train_label'+str(label_id)+'_precision'][i],clf2_results['train_label'+str(label_id)+'_recall'][i],clf2_results['train_label'+str(label_id)+'_fscore'][i],clf2_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf2_results['test_label'+str(label_id)+'_precision'][i],clf2_results['test_label'+str(label_id)+'_recall'][i],clf2_results['test_label'+str(label_id)+'_fscore'][i],clf2_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf2_results['train_avg_precision'][i],clf2_results['train_avg_recall'][i],clf2_results['train_avg_fscore'][i],clf2_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf2_results['test_avg_precision'][i],clf2_results['test_avg_recall'][i],clf2_results['test_avg_fscore'][i],clf2_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'LTS',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'LTS',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'LTS',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['LTS_train_'+str(i)] = train_report
    result_dict['LTS_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      48.0
# Bug Reproduction                        0.97    0.98      0.98     196.0
# Contribution and Commitment             1.00    1.00      1.00      66.0
# Expected Behaviour                      0.99    0.99      0.99      99.0
# Investigation and Exploration           0.99    0.98      0.98     301.0
# Social Conversation                     1.00    0.99      0.99     638.0
# Motivation                              1.00    1.00      1.00     230.0
# Observed Bug Behaviour                  0.77    0.97      0.86     104.0
# Potential New Issues and Requests       0.99    0.99      0.99     184.0
# Solution Discussion                     1.00    0.97      0.99    1128.0
# Task Progress                           0.86    1.00      0.93     100.0
# Solution Usage                          0.99    0.97      0.98     294.0
# Workarounds                             0.99    0.97      0.98      71.0
# Avg/Total                               0.98    0.98      0.98    3459.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.56    0.38      0.45      13.0
# Bug Reproduction                        0.50    0.49      0.49      49.0
# Contribution and Commitment             0.67    0.71      0.69      17.0
# Expected Behaviour                      0.60    0.36      0.45      25.0
# Investigation and Exploration           0.46    0.41      0.43      76.0
# Social Conversation                     0.78    0.67      0.72     160.0
# Motivation                              0.39    0.33      0.36      58.0
# Observed Bug Behaviour                  0.14    0.19      0.16      27.0
# Potential New Issues and Requests       0.31    0.26      0.28      46.0
# Solution Discussion                     0.59    0.69      0.64     283.0
# Task Progress                           0.35    0.24      0.29      25.0
# Solution Usage                          0.52    0.66      0.58      74.0
# Workarounds                             0.56    0.28      0.37      18.0
# Avg/Total                               0.55    0.55      0.55     871.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.98    0.95      0.97     196.0
# Contribution and Commitment             1.00    1.00      1.00      66.0
# Expected Behaviour                      0.99    0.98      0.98      99.0
# Investigation and Exploration           0.99    0.97      0.98     301.0
# Social Conversation                     1.00    0.99      0.99     638.0
# Motivation                              1.00    1.00      1.00     230.0
# Observed Bug Behaviour                  0.97    0.96      0.97     105.0
# Potential New Issues and Requests       0.99    0.98      0.99     184.0
# Solution Discussion                     1.00    0.97      0.98    1129.0
# Task Progress                           0.86    1.00      0.93     100.0
# Solution Usage                          0.89    0.99      0.94     294.0
# Workarounds                             1.00    0.97      0.99      71.0
# Avg/Total                               0.98    0.98      0.98    3462.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.67    0.67      0.67      12.0
# Bug Reproduction                        0.44    0.41      0.43      49.0
# Contribution and Commitment             0.55    0.35      0.43      17.0
# Expected Behaviour                      0.42    0.40      0.41      25.0
# Investigation and Exploration           0.45    0.46      0.45      76.0
# Social Conversation                     0.75    0.73      0.74     160.0
# Motivation                              0.36    0.31      0.33      58.0
# Observed Bug Behaviour                  0.26    0.19      0.22      26.0
# Potential New Issues and Requests       0.23    0.15      0.18      46.0
# Solution Discussion                     0.57    0.65      0.61     282.0
# Task Progress                           0.26    0.28      0.27      25.0
# Solution Usage                          0.47    0.55      0.51      74.0
# Workarounds                             0.86    0.33      0.48      18.0
# Avg/Total                               0.53    0.53      0.53     868.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.98    0.97      0.98     196.0
# Contribution and Commitment             0.99    1.00      0.99      66.0
# Expected Behaviour                      1.00    0.99      0.99      99.0
# Investigation and Exploration           0.99    0.97      0.98     302.0
# Social Conversation                     1.00    0.99      0.99     638.0
# Motivation                              1.00    1.00      1.00     230.0
# Observed Bug Behaviour                  0.74    0.96      0.83     105.0
# Potential New Issues and Requests       0.91    1.00      0.95     184.0
# Solution Discussion                     1.00    0.98      0.99    1129.0
# Task Progress                           0.99    0.99      0.99     100.0
# Solution Usage                          1.00    0.97      0.98     294.0
# Workarounds                             0.99    0.99      0.99      71.0
# Avg/Total                               0.98    0.98      0.98    3463.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.73    0.67      0.70      12.0
# Bug Reproduction                        0.53    0.49      0.51      49.0
# Contribution and Commitment             0.58    0.41      0.48      17.0
# Expected Behaviour                      0.26    0.20      0.23      25.0
# Investigation and Exploration           0.48    0.43      0.45      75.0
# Social Conversation                     0.73    0.74      0.74     160.0
# Motivation                              0.35    0.34      0.35      58.0
# Observed Bug Behaviour                  0.12    0.15      0.14      26.0
# Potential New Issues and Requests       0.38    0.24      0.29      46.0
# Solution Discussion                     0.58    0.68      0.62     282.0
# Task Progress                           0.25    0.12      0.16      25.0
# Solution Usage                          0.48    0.55      0.52      74.0
# Workarounds                             0.80    0.22      0.35      18.0
# Avg/Total                               0.54    0.54      0.53     867.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.97    0.96      0.97     196.0
# Contribution and Commitment             0.96    1.00      0.98      67.0
# Expected Behaviour                      0.98    0.98      0.98      99.0
# Investigation and Exploration           0.99    0.97      0.98     302.0
# Social Conversation                     1.00    0.99      0.99     639.0
# Motivation                              1.00    1.00      1.00     231.0
# Observed Bug Behaviour                  0.98    0.94      0.96     105.0
# Potential New Issues and Requests       0.98    0.99      0.99     184.0
# Solution Discussion                     1.00    0.97      0.98    1129.0
# Task Progress                           0.85    1.00      0.92     100.0
# Solution Usage                          0.88    0.99      0.93     295.0
# Workarounds                             1.00    0.97      0.99      71.0
# Avg/Total                               0.98    0.98      0.98    3467.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.86    0.50      0.63      12.0
# Bug Reproduction                        0.45    0.53      0.49      49.0
# Contribution and Commitment             0.36    0.25      0.30      16.0
# Expected Behaviour                      0.29    0.20      0.24      25.0
# Investigation and Exploration           0.37    0.37      0.37      75.0
# Social Conversation                     0.74    0.79      0.76     159.0
# Motivation                              0.35    0.33      0.34      57.0
# Observed Bug Behaviour                  0.35    0.27      0.30      26.0
# Potential New Issues and Requests       0.37    0.28      0.32      46.0
# Solution Discussion                     0.57    0.61      0.59     282.0
# Task Progress                           0.44    0.44      0.44      25.0
# Solution Usage                          0.45    0.52      0.48      73.0
# Workarounds                             0.29    0.11      0.16      18.0
# Avg/Total                               0.52    0.53      0.52     863.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.99    0.97      0.98     196.0
# Contribution and Commitment             1.00    1.00      1.00      67.0
# Expected Behaviour                      0.98    0.98      0.98     100.0
# Investigation and Exploration           0.90    0.99      0.94     302.0
# Social Conversation                     1.00    0.99      0.99     639.0
# Motivation                              1.00    1.00      1.00     231.0
# Observed Bug Behaviour                  0.98    0.98      0.98     105.0
# Potential New Issues and Requests       1.00    0.99      1.00     184.0
# Solution Discussion                     1.00    0.97      0.98    1129.0
# Task Progress                           0.85    1.00      0.92     100.0
# Solution Usage                          1.00    0.97      0.98     295.0
# Workarounds                             0.99    0.99      0.99      72.0
# Avg/Total                               0.98    0.98      0.98    3469.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.78    0.58      0.67      12.0
# Bug Reproduction                        0.50    0.55      0.52      49.0
# Contribution and Commitment             0.44    0.50      0.47      16.0
# Expected Behaviour                      0.11    0.08      0.09      24.0
# Investigation and Exploration           0.43    0.45      0.44      75.0
# Social Conversation                     0.74    0.72      0.73     159.0
# Motivation                              0.32    0.32      0.32      57.0
# Observed Bug Behaviour                  0.35    0.23      0.28      26.0
# Potential New Issues and Requests       0.29    0.17      0.22      46.0
# Solution Discussion                     0.60    0.66      0.63     282.0
# Task Progress                           0.48    0.48      0.48      25.0
# Solution Usage                          0.44    0.51      0.47      73.0
# Workarounds                             0.56    0.29      0.38      17.0
# Avg/Total                               0.53    0.54      0.53     861.0

# %% [markdown]
# # Nested Leave-One-Issue-Out Cross Validation For Random Forest On Both Textual+Contextual Features using SMOTE

# %%
import numpy as np
import pandas as pd
import xlrd as xl
from pandas import ExcelWriter
from pandas import ExcelFile
import pprint
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
import re
import pickle
from operator import itemgetter
import time, datetime
from functools import partial, update_wrapper
from openpyxl import load_workbook
from copy import deepcopy

from sklearn.externals.joblib import Parallel, delayed
from sklearn.pipeline import FeatureUnion, _fit_transform_one, _transform_one
from scipy import sparse

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from imblearn.over_sampling import SMOTE

from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from imblearn.pipeline import Pipeline as Imb_Pipeline

from sklearn.preprocessing import FunctionTransformer

from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate, LeaveOneGroupOut
from sklearn.metrics import precision_recall_fscore_support, classification_report, accuracy_score, make_scorer, confusion_matrix

pp = pprint.PrettyPrinter(indent=4)

## Ignore warnings
import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn
np.warnings.filterwarnings('ignore')

# %% [markdown]
# #### Use spaCy parser for word tokenization of a sentence:

# %%
import spacy
eng = spacy.load('en')
from spacy.lang.en import English
parser = English()

# %% [markdown]
# #### Define stopwords as punctuation + common contractions:

# %%
from string import punctuation
from nltk.corpus import stopwords

stop_words = list(punctuation) + ["'s","'m","n't","'re","-","'ll",'...'] #+ stopwords.words('english')

# %% [markdown]
# #### Code to lemmatize and tokenize:

# %%
def get_lemma(item):
    return WordNetLemmatizer().lemmatize(item)

def tokenize(line):
    line_tokens = []
    tokens = parser(line)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            line_tokens.append('URL')
        elif token.orth_.startswith('@'):
            line_tokens.append('SCREEN_NAME')
        elif str(token) not in stop_words:
            line_tokens.append(get_lemma(token.lower_))
    return line_tokens

# %% [markdown]
# #### Read from the pickled file

# %%
all_data = pd.read_pickle('../../data/text_conv_data.pkl')

print("Size of corpus: "+str(len(all_data)))
# Out:
# Size of corpus: 4330

# %%
X = all_data.drop(['Code','Document'], axis=1)
y = all_data[['Code']]
doc_groups = all_data['Document'].values

print("Number of unique labels: "+str(len(set(y['Code']))))

labels = list(set(y['Code']))
labels.sort()

pp.pprint(labels)
# Out:
# Number of unique labels: 13
# [   'Action on Issue',
#     'Bug Reproduction',
#     'Contribution and Commitment',
#     'Expected Behaviour',
#     'Investigation and Exploration',
#     'Social Conversation',
#     'Motivation',
#     'Observed Bug Behaviour',
#     'Potential New Issues and Requests',
#     'Solution Discussion',
#     'Task Progress',
#     'Solution Usage',
#     'Workarounds']

# %% [markdown]
# # Nested Cross-Validation on RandomForest:

# %%
# To be used within GridSearch
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# To be used in outer CV
logo = LeaveOneGroupOut()
outer_cv = logo.split(X,y,groups=doc_groups)

non_transform_features = [col for col in X.columns.values if col not in ['Text Content']]

# %% [markdown]
# ## Define pandas-compatible feature unificator
#
# This is just a pandas compatible feature unificator.
#
# This is necessary because we have two types of features: textual + conversational
#
# Hence, we first use tf-idf to vectorize the textual content and then append the conversational features to this vector using the feature unificator.

# %%
class PandasFeatureUnion(FeatureUnion):
    def fit_transform(self, X, y=None, **fit_params):
        self._validate_transformers()
        result = Parallel(n_jobs=self.n_jobs)(
            delayed(_fit_transform_one)(trans, weight, X, y,
                                        **fit_params)
            for name, trans, weight in self._iter())
        if not result:
            return np.zeros((X.shape[0], 0))
        Xs, transformers = zip(*result)
        self._update_transformer_list(transformers)
        if any(sparse.issparse(f) for f in Xs):
            Xs = sparse.hstack(Xs).tocsr()
        else:
            Xs = self.merge_dataframes_by_column(Xs)
        return Xs

    def merge_dataframes_by_column(self, Xs):
        return pd.concat(Xs, axis="columns", copy=False)

    def transform(self, X):
        Xs = Parallel(n_jobs=self.n_jobs)(
            delayed(_transform_one)(trans, weight, X)
            for name, trans, weight in self._iter())
        if not Xs:
            return np.zeros((X.shape[0], 0))
        if any(sparse.issparse(f) for f in Xs):
            Xs = sparse.hstack(Xs).tocsr()
        else:
            Xs = self.merge_dataframes_by_column(Xs)
        return Xs

# %%
class PandasTransform(TransformerMixin, BaseEstimator):
    def __init__(self, columns):
        self.columns = columns
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None, copy=None):
        return X.loc[:, self.columns].astype(float)

# %% [markdown]
# ## Define Pipelines:
#
# 1. Pipeline2: tfidf + SMOTE

# %%
class ItemSelector(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
    def fit(self, x, y=None):
        return self
    def transform(self, data_array):
        return data_array[:, self.columns]

### Simply select the conversational features, and tfidf-vectorize the textual content
ling_features = PandasTransform(non_transform_features)
tfidf_text_features = Pipeline([('extract_field',FunctionTransformer(lambda x: x['Text Content'],validate=False)),('vect',TfidfVectorizer(tokenizer=tokenize))])

### Combine the two types of feature vectors
feature_union1 = PandasFeatureUnion([
    ('selector',ling_features),
    ('text_vectorizer',tfidf_text_features)
])

pipeline2 = Imb_Pipeline([
    ('features', feature_union1),
    ('smote', SMOTE()),
    ('clf', RandomForestClassifier())
])

### Hyperparameters to search
parameters = {
    'features__text_vectorizer__vect__ngram_range': ((1,1),(1,2)),  # unigrams or bigrams or trigrams
    'clf__n_estimators': (10, 50, 100),
    'clf__min_samples_split': (2, 5, 10),
}

# %% [markdown]
# ## Nested Cross Validation using GridSearch

# %%
### Define and create the scoring functions

def score_func(y_true, y_pred, score_index, i):
    return(precision_recall_fscore_support(y_true,y_pred,labels=labels)[score_index][i])

def avg_score(y_true, y_pred, score_index):
    return precision_recall_fscore_support(y_true,y_pred,average='weighted')[score_index]

def sum_support(y_true, y_pred):
    return len(y_true)

### Create partials for each of the metrics returned
score_funcs = {v: partial(score_func, score_index=k) for k, v in {0:'precision',1:'recall',2:'fscore',3:'support'}.items()}
prec_score = partial(score_func, score_index=0)
update_wrapper(prec_score,score_func)
rec_score = partial(score_func, score_index=1)
update_wrapper(rec_score,score_func)
f_score = partial(score_func, score_index=2)
update_wrapper(f_score,score_func)
support_score = partial(score_func, score_index=3)
update_wrapper(support_score,score_func)

### Create a callable scoring function for each of the metrics for each classification label
scorer = {}
for label_id in range(0,13):
    scorer['label'+str(label_id)+'_precision'] = make_scorer(prec_score, i=label_id)
    scorer['label'+str(label_id)+'_recall'] = make_scorer(rec_score, i=label_id)
    scorer['label'+str(label_id)+'_fscore'] = make_scorer(f_score, i=label_id)
    scorer['label'+str(label_id)+'_support'] = make_scorer(support_score, i=label_id)

### Create a callable scoring function for avg/total of the metrics across classification labels
scorer['avg_precision'] = make_scorer(avg_score,score_index=0)
scorer['avg_recall'] = make_scorer(avg_score,score_index=1)
scorer['avg_fscore'] = make_scorer(avg_score,score_index=2)
scorer['total_support'] = make_scorer(sum_support)

### Perform Nested cross-validation on Pipeline2
start = time.time()
clf2 = GridSearchCV(pipeline2, parameters, cv=inner_cv, scoring='f1_weighted')
clf2_results = cross_validate(clf2, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline2 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))
# Out:
# Completed Pipeline2 scenario in 1 day, 1:11:17.160368

# %% [markdown]
# # Display and Save Training and Testing Results for each Fold:

# %% [markdown]
# ## Pipeline2 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../../results/LOIO.xlsx')
book = load_workbook('../../results/LOIO.xlsx')
writer = pd.ExcelWriter('../../results/LOIO.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,15):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf2_results['train_label'+str(label_id)+'_precision'][i],clf2_results['train_label'+str(label_id)+'_recall'][i],clf2_results['train_label'+str(label_id)+'_fscore'][i],clf2_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf2_results['test_label'+str(label_id)+'_precision'][i],clf2_results['test_label'+str(label_id)+'_recall'][i],clf2_results['test_label'+str(label_id)+'_fscore'][i],clf2_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf2_results['train_avg_precision'][i],clf2_results['train_avg_recall'][i],clf2_results['train_avg_fscore'][i],clf2_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf2_results['test_avg_precision'][i],clf2_results['test_avg_recall'][i],clf2_results['test_avg_fscore'][i],clf2_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'RBS',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'RBS',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'RBS',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['RBS_train_'+str(i)] = train_report
    result_dict['RBS_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00       1.0      53.0
# Bug Reproduction                        1.00    1.00       1.0     245.0
# Contribution and Commitment             1.00    1.00       1.0      58.0
# Expected Behaviour                      1.00    0.99       1.0     119.0
# Investigation and Exploration           1.00    1.00       1.0     377.0
# Social Conversation                     1.00    1.00       1.0     546.0
# Motivation                              1.00    1.00       1.0     261.0
# Observed Bug Behaviour                  1.00    1.00       1.0     131.0
# Potential New Issues and Requests       1.00    1.00       1.0     208.0
# Solution Discussion                     1.00    1.00       1.0    1338.0
# Task Progress                           0.99    1.00       1.0     104.0
# Solution Usage                          1.00    1.00       1.0     368.0
# Workarounds                             1.00    1.00       1.0      86.0
# Avg/Total                               1.00    1.00       1.0    3894.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       8.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00      25.0
# Expected Behaviour                      0.33    0.40      0.36       5.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.89    0.85      0.87     252.0
# Motivation                              0.00    0.00      0.00      27.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      22.0
# Solution Discussion                     0.36    0.81      0.50      73.0
# Task Progress                           1.00    0.10      0.17      21.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.63    0.63      0.60     436.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      60.0
# Bug Reproduction                         1.0     1.0       1.0     245.0
# Contribution and Commitment              1.0     1.0       1.0      80.0
# Expected Behaviour                       1.0     1.0       1.0      42.0
# Investigation and Exploration            1.0     1.0       1.0     377.0
# Social Conversation                      1.0     1.0       1.0     716.0
# Motivation                               1.0     1.0       1.0     134.0
# Observed Bug Behaviour                   1.0     1.0       1.0     131.0
# Potential New Issues and Requests        1.0     1.0       1.0     217.0
# Solution Discussion                      1.0     1.0       1.0    1231.0
# Task Progress                            1.0     1.0       1.0     113.0
# Solution Usage                           1.0     1.0       1.0     272.0
# Workarounds                              1.0     1.0       1.0      66.0
# Avg/Total                                1.0     1.0       1.0    3684.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.20    0.33      0.25       3.0
# Expected Behaviour                      0.00    0.00      0.00      82.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.59    0.66      0.62      82.0
# Motivation                              0.73    0.05      0.10     154.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      13.0
# Solution Discussion                     0.32    0.82      0.46     180.0
# Task Progress                           0.67    0.17      0.27      12.0
# Solution Usage                          0.26    0.08      0.13      96.0
# Workarounds                             1.00    0.04      0.08      23.0
# Avg/Total                               0.43    0.34      0.26     646.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      58.0
# Bug Reproduction                        1.00    1.00      1.00     216.0
# Contribution and Commitment             1.00    1.00      1.00      77.0
# Expected Behaviour                      1.00    1.00      1.00     124.0
# Investigation and Exploration           0.99    0.99      0.99     309.0
# Social Conversation                     0.99    1.00      1.00     773.0
# Motivation                              1.00    1.00      1.00     288.0
# Observed Bug Behaviour                  1.00    0.99      1.00     125.0
# Potential New Issues and Requests       0.99    1.00      1.00     167.0
# Solution Discussion                     1.00    0.99      0.99    1386.0
# Task Progress                           0.99    0.98      0.99     117.0
# Solution Usage                          0.99    0.99      0.99     368.0
# Workarounds                             1.00    0.99      0.99      89.0
# Avg/Total                               1.00    1.00      1.00    4097.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       3.0
# Bug Reproduction                        0.57    0.28      0.37      29.0
# Contribution and Commitment             0.00    0.00      0.00       6.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.37    0.15      0.21      68.0
# Social Conversation                     0.33    0.76      0.46      25.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.50    0.17      0.25       6.0
# Potential New Issues and Requests       0.20    0.02      0.03      63.0
# Solution Discussion                     0.15    0.60      0.23      25.0
# Task Progress                           0.00    0.00      0.00       8.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.30    0.23      0.20     233.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      55.0
# Bug Reproduction                        1.00    1.00      1.00     201.0
# Contribution and Commitment             1.00    1.00      1.00      75.0
# Expected Behaviour                      1.00    1.00      1.00     124.0
# Investigation and Exploration           1.00    0.99      1.00     351.0
# Social Conversation                     1.00    1.00      1.00     752.0
# Motivation                              1.00    1.00      1.00     288.0
# Observed Bug Behaviour                  1.00    1.00      1.00     121.0
# Potential New Issues and Requests       1.00    1.00      1.00     218.0
# Solution Discussion                     1.00    1.00      1.00    1318.0
# Task Progress                           0.99    0.99      0.99     107.0
# Solution Usage                          0.99    0.99      0.99     366.0
# Workarounds                             1.00    0.99      0.99      85.0
# Avg/Total                               1.00    1.00      1.00    4061.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.50      0.67       6.0
# Bug Reproduction                        0.54    0.16      0.25      44.0
# Contribution and Commitment             0.00    0.00      0.00       8.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      26.0
# Social Conversation                     0.51    0.76      0.61      46.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.71    0.50      0.59      10.0
# Potential New Issues and Requests       1.00    0.08      0.15      12.0
# Solution Discussion                     0.40    0.60      0.48      93.0
# Task Progress                           0.00    0.00      0.00      18.0
# Solution Usage                          0.00    0.00      0.00       2.0
# Workarounds                             0.00    0.00      0.00       4.0
# Avg/Total                               0.41    0.40      0.35     269.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      53.0
# Bug Reproduction                        1.00    1.00      1.00     244.0
# Contribution and Commitment             1.00    1.00      1.00      83.0
# Expected Behaviour                      1.00    1.00      1.00     121.0
# Investigation and Exploration           1.00    0.99      0.99     376.0
# Social Conversation                     0.99    1.00      1.00     757.0
# Motivation                              1.00    1.00      1.00     272.0
# Observed Bug Behaviour                  0.99    0.98      0.99     131.0
# Potential New Issues and Requests       1.00    1.00      1.00     229.0
# Solution Discussion                     1.00    1.00      1.00    1214.0
# Task Progress                           0.99    0.99      0.99     117.0
# Solution Usage                          0.99    0.99      0.99     367.0
# Workarounds                             1.00    0.99      0.99      87.0
# Avg/Total                               1.00    1.00      1.00    4051.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.38      0.55       8.0
# Bug Reproduction                        0.00    0.00      0.00       1.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       1.0
# Social Conversation                     0.48    0.85      0.61      41.0
# Motivation                              0.00    0.00      0.00      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.86    0.72      0.78     197.0
# Task Progress                           0.00    0.00      0.00       8.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       2.0
# Avg/Total                               0.71    0.64      0.66     279.0
#
# ------------------------- FOLD 5: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      55.0
# Bug Reproduction                         1.0     1.0       1.0     160.0
# Contribution and Commitment              1.0     1.0       1.0      78.0
# Expected Behaviour                       1.0     1.0       1.0     124.0
# Investigation and Exploration            1.0     1.0       1.0     266.0
# Social Conversation                      1.0     1.0       1.0     759.0
# Motivation                               1.0     1.0       1.0     287.0
# Observed Bug Behaviour                   1.0     1.0       1.0     125.0
# Potential New Issues and Requests        1.0     1.0       1.0     230.0
# Solution Discussion                      1.0     1.0       1.0    1349.0
# Task Progress                            1.0     1.0       1.0     122.0
# Solution Usage                           1.0     1.0       1.0     368.0
# Workarounds                              1.0     1.0       1.0      89.0
# Avg/Total                                1.0     1.0       1.0    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       6.0
# Bug Reproduction                        0.69    0.29      0.41      85.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.60    0.11      0.18     111.0
# Social Conversation                     0.45    0.82      0.58      39.0
# Motivation                              0.00    0.00      0.00       1.0
# Observed Bug Behaviour                  1.00    0.83      0.91       6.0
# Potential New Issues and Requests       0.00    0.00      0.00       0.0
# Solution Discussion                     0.27    0.68      0.39      62.0
# Task Progress                           0.40    0.67      0.50       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.53    0.37      0.34     318.0
#
# ------------------------- FOLD 6: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      59.0
# Bug Reproduction                        1.00    1.00      1.00     204.0
# Contribution and Commitment             1.00    1.00      1.00      80.0
# Expected Behaviour                      1.00    1.00      1.00     124.0
# Investigation and Exploration           1.00    1.00      1.00     365.0
# Social Conversation                     1.00    1.00      1.00     760.0
# Motivation                              1.00    1.00      1.00     278.0
# Observed Bug Behaviour                  1.00    1.00      1.00     127.0
# Potential New Issues and Requests       1.00    1.00      1.00     228.0
# Solution Discussion                     1.00    1.00      1.00    1219.0
# Task Progress                           0.99    0.99      0.99     120.0
# Solution Usage                          1.00    1.00      1.00     368.0
# Workarounds                             1.00    1.00      1.00      80.0
# Avg/Total                               1.00    1.00      1.00    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.50      0.67       2.0
# Bug Reproduction                        0.55    0.15      0.23      41.0
# Contribution and Commitment             0.00    0.00      0.00       3.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      12.0
# Social Conversation                     0.28    0.82      0.42      38.0
# Motivation                              0.00    0.00      0.00      10.0
# Observed Bug Behaviour                  0.44    1.00      0.62       4.0
# Potential New Issues and Requests       0.00    0.00      0.00       2.0
# Solution Discussion                     0.71    0.42      0.52     192.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       9.0
# Avg/Total                               0.54    0.38      0.41     318.0
#
# ------------------------- FOLD 7: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      52.0
# Bug Reproduction                        1.00    1.00      1.00     245.0
# Contribution and Commitment             1.00    1.00      1.00      78.0
# Expected Behaviour                      1.00    1.00      1.00     123.0
# Investigation and Exploration           1.00    0.99      1.00     377.0
# Social Conversation                     1.00    1.00      1.00     726.0
# Motivation                              1.00    1.00      1.00     285.0
# Observed Bug Behaviour                  1.00    0.98      0.99     131.0
# Potential New Issues and Requests       1.00    1.00      1.00     226.0
# Solution Discussion                     1.00    1.00      1.00    1342.0
# Task Progress                           0.98    0.99      0.99     120.0
# Solution Usage                          1.00    0.97      0.99     105.0
# Workarounds                             1.00    0.99      0.99      89.0
# Avg/Total                               1.00    1.00      1.00    3899.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.67      0.80       9.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.59    0.69      0.64      72.0
# Motivation                              0.10    0.33      0.15       3.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       4.0
# Solution Discussion                     0.21    0.80      0.33      69.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.75    0.02      0.04     263.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.61    0.27      0.20     431.0
#
# ------------------------- FOLD 8: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00     1.0       1.0      57.0
# Bug Reproduction                        1.00     1.0       1.0     245.0
# Contribution and Commitment             1.00     1.0       1.0      81.0
# Expected Behaviour                      1.00     1.0       1.0     121.0
# Investigation and Exploration           1.00     1.0       1.0     377.0
# Social Conversation                     1.00     1.0       1.0     774.0
# Motivation                              1.00     1.0       1.0     272.0
# Observed Bug Behaviour                  1.00     1.0       1.0     131.0
# Potential New Issues and Requests       1.00     1.0       1.0     179.0
# Solution Discussion                     1.00     1.0       1.0    1386.0
# Task Progress                           0.99     1.0       1.0     120.0
# Solution Usage                          1.00     1.0       1.0     368.0
# Workarounds                             1.00     1.0       1.0      83.0
# Avg/Total                               1.00     1.0       1.0    4194.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.50      0.67       4.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       2.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.64    0.29      0.40      24.0
# Motivation                              0.00    0.00      0.00      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      51.0
# Solution Discussion                     0.19    0.92      0.32      25.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       6.0
# Avg/Total                               0.18    0.24      0.15     136.0
#
# ------------------------- FOLD 9: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      58.0
# Bug Reproduction                        1.00    0.99      1.00     245.0
# Contribution and Commitment             1.00    1.00      1.00      78.0
# Expected Behaviour                      1.00    1.00      1.00     118.0
# Investigation and Exploration           1.00    1.00      1.00     349.0
# Social Conversation                     0.99    1.00      0.99     766.0
# Motivation                              1.00    1.00      1.00     282.0
# Observed Bug Behaviour                  1.00    0.99      1.00     115.0
# Potential New Issues and Requests       1.00    1.00      1.00     229.0
# Solution Discussion                     1.00    1.00      1.00    1335.0
# Task Progress                           0.99    0.99      0.99     111.0
# Solution Usage                          1.00    1.00      1.00     365.0
# Workarounds                             1.00    0.98      0.99      59.0
# Avg/Total                               1.00    1.00      1.00    4110.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.40    0.40      0.40       5.0
# Expected Behaviour                      0.67    0.33      0.44       6.0
# Investigation and Exploration           0.25    0.04      0.06      28.0
# Social Conversation                     0.68    0.66      0.67      32.0
# Motivation                              0.67    0.33      0.44       6.0
# Observed Bug Behaviour                  0.23    0.19      0.21      16.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.49    0.79      0.61      76.0
# Task Progress                           0.50    0.14      0.22      14.0
# Solution Usage                          0.00    0.00      0.00       3.0
# Workarounds                             0.00    0.00      0.00      30.0
# Avg/Total                               0.41    0.44      0.39     220.0
#
# ------------------------- FOLD 10: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      56.0
# Bug Reproduction                         1.0     1.0       1.0     238.0
# Contribution and Commitment              1.0     1.0       1.0      83.0
# Expected Behaviour                       1.0     1.0       1.0     124.0
# Investigation and Exploration            1.0     1.0       1.0     353.0
# Social Conversation                      1.0     1.0       1.0     788.0
# Motivation                               1.0     1.0       1.0     288.0
# Observed Bug Behaviour                   1.0     1.0       1.0     123.0
# Potential New Issues and Requests        1.0     1.0       1.0     202.0
# Solution Discussion                      1.0     1.0       1.0    1411.0
# Task Progress                            1.0     1.0       1.0     122.0
# Solution Usage                           1.0     1.0       1.0     368.0
# Workarounds                              1.0     1.0       1.0      88.0
# Avg/Total                                1.0     1.0       1.0    4244.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.50    0.60      0.55       5.0
# Bug Reproduction                        0.43    0.43      0.43       7.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      24.0
# Social Conversation                     0.62    0.50      0.56      10.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.75    0.75      0.75       8.0
# Potential New Issues and Requests       0.00    0.00      0.00      28.0
# Solution Discussion                     0.00    0.00      0.00       0.0
# Task Progress                           0.00    0.00      0.00       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       1.0
# Avg/Total                               0.21    0.20      0.20      86.0
#
# ------------------------- FOLD 11: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      60.0
# Bug Reproduction                         1.0     1.0       1.0     245.0
# Contribution and Commitment              1.0     1.0       1.0      81.0
# Expected Behaviour                       1.0     1.0       1.0     118.0
# Investigation and Exploration            1.0     1.0       1.0     377.0
# Social Conversation                      1.0     1.0       1.0     755.0
# Motivation                               1.0     1.0       1.0     268.0
# Observed Bug Behaviour                   1.0     1.0       1.0     131.0
# Potential New Issues and Requests        1.0     1.0       1.0     225.0
# Solution Discussion                      1.0     1.0       1.0    1224.0
# Task Progress                            1.0     1.0       1.0     121.0
# Solution Usage                           1.0     1.0       1.0     368.0
# Workarounds                              1.0     1.0       1.0      86.0
# Avg/Total                                1.0     1.0       1.0    4059.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       2.0
# Expected Behaviour                      1.00    0.17      0.29       6.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.67    0.47      0.55      43.0
# Motivation                              0.17    0.05      0.08      20.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       5.0
# Solution Discussion                     0.72    0.67      0.70     187.0
# Task Progress                           0.00    0.00      0.00       4.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.64    0.55      0.58     271.0
#
# ------------------------- FOLD 12: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      59.0
# Bug Reproduction                        0.99    1.00      1.00     207.0
# Contribution and Commitment             1.00    1.00      1.00      76.0
# Expected Behaviour                      1.00    0.99      1.00     123.0
# Investigation and Exploration           1.00    0.99      0.99     273.0
# Social Conversation                     0.99    1.00      1.00     756.0
# Motivation                              1.00    1.00      1.00     288.0
# Observed Bug Behaviour                  1.00    0.98      0.99      50.0
# Potential New Issues and Requests       1.00    1.00      1.00     228.0
# Solution Discussion                     1.00    0.99      0.99    1367.0
# Task Progress                           0.99    0.98      0.99     125.0
# Solution Usage                          0.99    1.00      0.99     368.0
# Workarounds                             1.00    0.99      0.99      81.0
# Avg/Total                               1.00    1.00      1.00    4001.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.50    0.50      0.50       2.0
# Bug Reproduction                        0.35    0.16      0.22      38.0
# Contribution and Commitment             0.00    0.00      0.00       7.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.40    0.10      0.16     104.0
# Social Conversation                     0.31    0.48      0.38      42.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.25    0.02      0.04      81.0
# Potential New Issues and Requests       0.00    0.00      0.00       2.0
# Solution Discussion                     0.15    0.64      0.25      44.0
# Task Progress                           0.00    0.00      0.00       0.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       8.0
# Avg/Total                               0.29    0.20      0.17     329.0
#
# ------------------------- FOLD 13: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      61.0
# Bug Reproduction                        0.99    1.00      1.00     245.0
# Contribution and Commitment             1.00    1.00      1.00      76.0
# Expected Behaviour                      1.00    0.99      1.00     110.0
# Investigation and Exploration           1.00    0.99      0.99     374.0
# Social Conversation                     0.99    1.00      1.00     760.0
# Motivation                              1.00    1.00      1.00     255.0
# Observed Bug Behaviour                  0.99    0.98      0.99     131.0
# Potential New Issues and Requests       1.00    0.99      1.00     205.0
# Solution Discussion                     0.99    0.99      0.99    1288.0
# Task Progress                           0.99    0.99      0.99     120.0
# Solution Usage                          1.00    0.99      1.00     366.0
# Workarounds                             0.99    0.99      0.99      89.0
# Avg/Total                               1.00    1.00      1.00    4080.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       0.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       7.0
# Expected Behaviour                      0.00    0.00      0.00      14.0
# Investigation and Exploration           0.00    0.00      0.00       3.0
# Social Conversation                     0.66    0.50      0.57      38.0
# Motivation                              0.14    0.27      0.18      33.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.50    0.04      0.07      25.0
# Solution Discussion                     0.46    0.53      0.49     123.0
# Task Progress                           0.17    0.20      0.18       5.0
# Solution Usage                          0.00    0.00      0.00       2.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.40    0.38      0.36     250.0
#
# ------------------------- FOLD 14: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      58.0
# Bug Reproduction                        0.99    0.99      0.99     245.0
# Contribution and Commitment             1.00    1.00      1.00      78.0
# Expected Behaviour                      1.00    1.00      1.00     121.0
# Investigation and Exploration           0.99    0.99      0.99     377.0
# Social Conversation                     0.99    1.00      1.00     784.0
# Motivation                              1.00    1.00      1.00     286.0
# Observed Bug Behaviour                  1.00    0.98      0.99     131.0
# Potential New Issues and Requests       1.00    1.00      1.00     229.0
# Solution Discussion                     0.99    0.99      0.99    1346.0
# Task Progress                           0.99    1.00      1.00     111.0
# Solution Usage                          1.00    0.99      0.99     367.0
# Workarounds                             1.00    0.98      0.99      89.0
# Avg/Total                               1.00    1.00      1.00    4222.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.25    0.33      0.29       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.35    0.93      0.51      14.0
# Motivation                              0.00    0.00      0.00       2.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.82    0.72      0.77      65.0
# Task Progress                           1.00    0.14      0.25      14.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.71    0.61      0.60     108.0

# %% [markdown]
# ### Get list of F1 scores and support-weighted average F1 score

# %%
avg_f1 = []
for i in range(0,15):
    avg_f1.append(float('%.4f' % round(clf2_results['test_avg_fscore'][i],4)))
    
print('Pipeline2:')
print(avg_f1)

sum = 0
den = 0
for i in range(0,15):
    sum += clf2_results['test_avg_fscore'][i] * clf2_results['test_total_support'][i]
    den += clf2_results['test_total_support'][i]
print('Pipeline2: Total weighted F-Score: '+('%.4f' % round(sum/den,4)))
# Out:
# Pipeline2:
# [0.5981, 0.2592, 0.197, 0.3533, 0.6574, 0.3428, 0.4081, 0.2042, 0.1493, 0.3904, 0.201, 0.5793, 0.1698, 0.3644, 0.5979]
# Pipeline2: Total weighted F-Score: 0.3629

# %% [markdown]
# # Nested Leave-One-Issue-Out Cross Validation For Random Forest On Textual Features using class_weight=balanced

# %%
import numpy as np
import pandas as pd
import xlrd as xl
from pandas import ExcelWriter
from pandas import ExcelFile
import pprint
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
import re
import pickle
from operator import itemgetter
import time, datetime
from functools import partial, update_wrapper
from openpyxl import load_workbook

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from imblearn.over_sampling import SMOTE

from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as Imb_Pipeline

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate, LeaveOneGroupOut
from sklearn.metrics import precision_recall_fscore_support, classification_report, accuracy_score, make_scorer, confusion_matrix

pp = pprint.PrettyPrinter(indent=4)

## Ignore warnings
import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn
np.warnings.filterwarnings('ignore')

# %% [markdown]
# #### Use spaCy parser for word tokenization of a sentence:

# %%
import spacy
eng = spacy.load('en')
from spacy.lang.en import English
parser = English()

# %% [markdown]
# #### Define stopwords as punctuation + common contractions:

# %%
from string import punctuation
from nltk.corpus import stopwords

stop_words = list(punctuation) + ["'s","'m","n't","'re","-","'ll",'...'] #+ stopwords.words('english')

# %% [markdown]
# #### Code to lemmatize and tokenize:

# %%
def get_lemma(item):
    return WordNetLemmatizer().lemmatize(item)

def tokenize(line):
    line_tokens = []
    tokens = parser(line)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            line_tokens.append('URL')
        elif token.orth_.startswith('@'):
            line_tokens.append('SCREEN_NAME')
        elif str(token) not in stop_words:
            line_tokens.append(get_lemma(token.lower_))
    return line_tokens

# %% [markdown]
# #### Read from the pickled file:

# %%
all_data = pd.read_pickle('../../data/text_conv_data.pkl')

print("Size of corpus: "+str(len(all_data)))
# Out:
# Size of corpus: 4330

# %%
X = all_data['Text Content'].values
y = all_data['Code'].values
doc_groups = all_data['Document'].values

print("Number of unique labels: "+str(len(set(y))))

labels = list(set(y))
labels.sort()

pp.pprint(labels)
# Out:
# Number of unique labels: 13
# [   'Action on Issue',
#     'Bug Reproduction',
#     'Contribution and Commitment',
#     'Expected Behaviour',
#     'Investigation and Exploration',
#     'Social Conversation',
#     'Motivation',
#     'Observed Bug Behaviour',
#     'Potential New Issues and Requests',
#     'Solution Discussion',
#     'Task Progress',
#     'Solution Usage',
#     'Workarounds']

# %% [markdown]
# ## Nested Cross-Validation on Random Forest:

# %%
# To be used within GridSearch
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# To be used in outer CV
logo = LeaveOneGroupOut()
outer_cv = logo.split(X,y,groups=doc_groups)

# %% [markdown]
# ### Define Pipelines:
#
# 1. Pipeline1: tfidf + class_weight=balanced

# %%
pipeline1 = Pipeline([
    ('vect', TfidfVectorizer(tokenizer=tokenize)),
    ('clf', RandomForestClassifier(class_weight='balanced')),
])

### Hyperparameters to search
parameters = {
    'vect__ngram_range': ((1, 1), (1, 2)),  # unigrams and/or bigrams
    'clf__n_estimators': (10, 50, 100),
    'clf__min_samples_split': (2, 5, 10),
}

# %% [markdown]
# ## Nested Cross Validation Using GridSearch

# %%
### Define and create the scoring functions

def score_func(y_true, y_pred, score_index, i):
    return(precision_recall_fscore_support(y_true,y_pred,labels=labels)[score_index][i])

def avg_score(y_true, y_pred, score_index):
    return precision_recall_fscore_support(y_true,y_pred,average='weighted')[score_index]

def sum_support(y_true, y_pred):
    return len(y_true)

### Create partials for each of the metrics returned
score_funcs = {v: partial(score_func, score_index=k) for k, v in {0:'precision',1:'recall',2:'fscore',3:'support'}.items()}
prec_score = partial(score_func, score_index=0)
update_wrapper(prec_score,score_func)
rec_score = partial(score_func, score_index=1)
update_wrapper(rec_score,score_func)
f_score = partial(score_func, score_index=2)
update_wrapper(f_score,score_func)
support_score = partial(score_func, score_index=3)
update_wrapper(support_score,score_func)

### Create a callable scoring function for each of the metrics for each classification label
scorer = {}
for label_id in range(0,13):
    scorer['label'+str(label_id)+'_precision'] = make_scorer(prec_score, i=label_id)
    scorer['label'+str(label_id)+'_recall'] = make_scorer(rec_score, i=label_id)
    scorer['label'+str(label_id)+'_fscore'] = make_scorer(f_score, i=label_id)
    scorer['label'+str(label_id)+'_support'] = make_scorer(support_score, i=label_id)

### Create a callable scoring function for avg/total of the metrics across classification labels
scorer['avg_precision'] = make_scorer(avg_score,score_index=0)
scorer['avg_recall'] = make_scorer(avg_score,score_index=1)
scorer['avg_fscore'] = make_scorer(avg_score,score_index=2)
scorer['total_support'] = make_scorer(sum_support)

### Perform Nested cross-validation on Pipeline1
outer_cv = logo.split(X,y,groups=doc_groups)

start = time.time()
clf1 = GridSearchCV(pipeline1, parameters, cv=inner_cv, scoring='f1_weighted')
clf1_results = cross_validate(clf1, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline1 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))
# Out:
# Completed Pipeline1 scenario in 10:11:42.612070

# %% [markdown]
# # Display and Save Training and Testing Results for each Fold:

# %% [markdown]
# ## Pipeline1 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

writer = pd.ExcelWriter('../../results/LOIO.xlsx')
# book = load_workbook('../../results/LOIO.xlsx')
# writer = pd.ExcelWriter('../../results/LOIO.xlsx', engine='openpyxl')
# writer.book = book
# writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,15):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf1_results['train_label'+str(label_id)+'_precision'][i],clf1_results['train_label'+str(label_id)+'_recall'][i],clf1_results['train_label'+str(label_id)+'_fscore'][i],clf1_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf1_results['test_label'+str(label_id)+'_precision'][i],clf1_results['test_label'+str(label_id)+'_recall'][i],clf1_results['test_label'+str(label_id)+'_fscore'][i],clf1_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf1_results['train_avg_precision'][i],clf1_results['train_avg_recall'][i],clf1_results['train_avg_fscore'][i],clf1_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf1_results['test_avg_precision'][i],clf1_results['test_avg_recall'][i],clf1_results['test_avg_fscore'][i],clf1_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'RTC',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'RTC',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'RTC',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['RTC_train_'+str(i)] = train_report
    result_dict['RTC_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.94      0.97      53.0
# Bug Reproduction                        0.99    0.93      0.96     245.0
# Contribution and Commitment             1.00    0.86      0.93      58.0
# Expected Behaviour                      0.98    0.84      0.90     119.0
# Investigation and Exploration           0.99    0.90      0.94     377.0
# Social Conversation                     0.97    0.98      0.97     546.0
# Motivation                              1.00    0.87      0.93     261.0
# Observed Bug Behaviour                  0.98    0.89      0.93     131.0
# Potential New Issues and Requests       0.99    0.95      0.97     208.0
# Solution Discussion                     0.89    0.99      0.94    1338.0
# Task Progress                           1.00    0.87      0.93     104.0
# Solution Usage                          0.99    0.94      0.96     368.0
# Workarounds                             0.99    0.92      0.95      86.0
# Avg/Total                               0.95    0.95      0.95    3894.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       8.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.75    0.12      0.21      25.0
# Expected Behaviour                      0.00    0.00      0.00       5.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.91    0.77      0.83     252.0
# Motivation                              0.20    0.04      0.06      27.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.20    0.05      0.07      22.0
# Solution Discussion                     0.32    0.81      0.46      73.0
# Task Progress                           0.20    0.10      0.13      21.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.66    0.59      0.58     436.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.95      0.97      60.0
# Bug Reproduction                        0.96    0.92      0.94     245.0
# Contribution and Commitment             1.00    0.85      0.92      80.0
# Expected Behaviour                      1.00    0.88      0.94      42.0
# Investigation and Exploration           0.98    0.91      0.95     377.0
# Social Conversation                     0.96    0.98      0.97     716.0
# Motivation                              0.99    0.92      0.95     134.0
# Observed Bug Behaviour                  0.98    0.91      0.94     131.0
# Potential New Issues and Requests       0.99    0.94      0.96     217.0
# Solution Discussion                     0.90    0.99      0.95    1231.0
# Task Progress                           0.99    0.87      0.92     113.0
# Solution Usage                          0.99    0.92      0.95     272.0
# Workarounds                             1.00    0.88      0.94      66.0
# Avg/Total                               0.95    0.95      0.95    3684.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       3.0
# Expected Behaviour                      0.00    0.00      0.00      82.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.52    0.61      0.56      82.0
# Motivation                              0.00    0.00      0.00     154.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.20    0.08      0.11      13.0
# Solution Discussion                     0.32    0.91      0.48     180.0
# Task Progress                           0.00    0.00      0.00      12.0
# Solution Usage                          0.43    0.06      0.11      96.0
# Workarounds                             0.00    0.00      0.00      23.0
# Avg/Total                               0.22    0.34      0.22     646.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.98      0.99      58.0
# Bug Reproduction                        0.98    0.91      0.94     216.0
# Contribution and Commitment             1.00    0.94      0.97      77.0
# Expected Behaviour                      1.00    0.87      0.93     124.0
# Investigation and Exploration           0.99    0.90      0.94     309.0
# Social Conversation                     0.96    0.98      0.97     773.0
# Motivation                              1.00    0.90      0.95     288.0
# Observed Bug Behaviour                  0.97    0.89      0.93     125.0
# Potential New Issues and Requests       1.00    0.90      0.95     167.0
# Solution Discussion                     0.89    0.99      0.94    1386.0
# Task Progress                           0.97    0.89      0.93     117.0
# Solution Usage                          0.99    0.92      0.95     368.0
# Workarounds                             1.00    0.88      0.93      89.0
# Avg/Total                               0.95    0.95      0.95    4097.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       3.0
# Bug Reproduction                        0.50    0.17      0.26      29.0
# Contribution and Commitment             0.00    0.00      0.00       6.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.56    0.07      0.13      68.0
# Social Conversation                     0.36    0.72      0.48      25.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.00    0.00      0.00       6.0
# Potential New Issues and Requests       0.00    0.00      0.00      63.0
# Solution Discussion                     0.14    0.84      0.24      25.0
# Task Progress                           0.00    0.00      0.00       8.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.28    0.21      0.15     233.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.93      0.96      55.0
# Bug Reproduction                        0.98    0.93      0.95     201.0
# Contribution and Commitment             1.00    0.93      0.97      75.0
# Expected Behaviour                      0.99    0.90      0.94     124.0
# Investigation and Exploration           0.99    0.90      0.94     351.0
# Social Conversation                     0.96    0.99      0.98     752.0
# Motivation                              1.00    0.91      0.95     288.0
# Observed Bug Behaviour                  1.00    0.89      0.94     121.0
# Potential New Issues and Requests       1.00    0.92      0.95     218.0
# Solution Discussion                     0.89    0.99      0.94    1318.0
# Task Progress                           1.00    0.89      0.94     107.0
# Solution Usage                          0.99    0.92      0.95     366.0
# Workarounds                             0.99    0.87      0.92      85.0
# Avg/Total                               0.95    0.95      0.95    4061.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.67    0.33      0.44       6.0
# Bug Reproduction                        0.35    0.14      0.20      44.0
# Contribution and Commitment             0.00    0.00      0.00       8.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      26.0
# Social Conversation                     0.46    0.78      0.58      46.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.25    0.10      0.14      10.0
# Potential New Issues and Requests       0.50    0.08      0.14      12.0
# Solution Discussion                     0.40    0.62      0.49      93.0
# Task Progress                           0.00    0.00      0.00      18.0
# Solution Usage                          0.07    0.50      0.12       2.0
# Workarounds                             0.00    0.00      0.00       4.0
# Avg/Total                               0.32    0.39      0.32     269.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      53.0
# Bug Reproduction                        0.99    0.97      0.98     244.0
# Contribution and Commitment             1.00    1.00      1.00      83.0
# Expected Behaviour                      1.00    0.98      0.99     121.0
# Investigation and Exploration           0.99    0.97      0.98     376.0
# Social Conversation                     1.00    1.00      1.00     757.0
# Motivation                              1.00    1.00      1.00     272.0
# Observed Bug Behaviour                  0.99    0.94      0.96     131.0
# Potential New Issues and Requests       1.00    0.98      0.99     229.0
# Solution Discussion                     0.96    1.00      0.98    1214.0
# Task Progress                           1.00    0.97      0.98     117.0
# Solution Usage                          1.00    0.96      0.98     367.0
# Workarounds                             1.00    0.97      0.98      87.0
# Avg/Total                               0.99    0.99      0.99    4051.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.67    0.25      0.36       8.0
# Bug Reproduction                        0.00    0.00      0.00       1.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       1.0
# Social Conversation                     0.56    0.85      0.68      41.0
# Motivation                              0.00    0.00      0.00      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.82    0.88      0.85     197.0
# Task Progress                           0.00    0.00      0.00       8.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       2.0
# Avg/Total                               0.68    0.76      0.71     279.0
#
# ------------------------- FOLD 5: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.89      0.94      55.0
# Bug Reproduction                        0.94    0.86      0.90     160.0
# Contribution and Commitment             1.00    0.85      0.92      78.0
# Expected Behaviour                      1.00    0.79      0.88     124.0
# Investigation and Exploration           0.98    0.83      0.90     266.0
# Social Conversation                     0.95    0.97      0.96     759.0
# Motivation                              1.00    0.86      0.92     287.0
# Observed Bug Behaviour                  0.98    0.82      0.89     125.0
# Potential New Issues and Requests       0.98    0.82      0.89     230.0
# Solution Discussion                     0.83    0.99      0.90    1349.0
# Task Progress                           1.00    0.80      0.89     122.0
# Solution Usage                          0.96    0.85      0.90     368.0
# Workarounds                             0.99    0.83      0.90      89.0
# Avg/Total                               0.92    0.91      0.91    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.17      0.29       6.0
# Bug Reproduction                        0.62    0.12      0.20      85.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.70    0.06      0.12     111.0
# Social Conversation                     0.44    0.69      0.54      39.0
# Motivation                              0.00    0.00      0.00       1.0
# Observed Bug Behaviour                  0.00    0.00      0.00       6.0
# Potential New Issues and Requests       0.00    0.00      0.00       0.0
# Solution Discussion                     0.23    0.77      0.36      62.0
# Task Progress                           1.00    0.33      0.50       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.54    0.30      0.24     318.0
#
# ------------------------- FOLD 6: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.98      0.99      59.0
# Bug Reproduction                        0.98    0.98      0.98     204.0
# Contribution and Commitment             1.00    0.99      0.99      80.0
# Expected Behaviour                      1.00    0.98      0.99     124.0
# Investigation and Exploration           0.99    0.97      0.98     365.0
# Social Conversation                     0.99    0.99      0.99     760.0
# Motivation                              1.00    0.99      0.99     278.0
# Observed Bug Behaviour                  1.00    0.94      0.97     127.0
# Potential New Issues and Requests       1.00    0.98      0.99     228.0
# Solution Discussion                     0.96    1.00      0.98    1219.0
# Task Progress                           0.99    0.98      0.98     120.0
# Solution Usage                          1.00    0.97      0.98     368.0
# Workarounds                             1.00    0.99      0.99      80.0
# Avg/Total                               0.99    0.99      0.99    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       2.0
# Bug Reproduction                        1.00    0.20      0.33      41.0
# Contribution and Commitment             0.00    0.00      0.00       3.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      12.0
# Social Conversation                     0.30    0.63      0.40      38.0
# Motivation                              0.00    0.00      0.00      10.0
# Observed Bug Behaviour                  0.00    0.00      0.00       4.0
# Potential New Issues and Requests       0.00    0.00      0.00       2.0
# Solution Discussion                     0.68    0.78      0.73     192.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       9.0
# Avg/Total                               0.58    0.57      0.53     318.0
#
# ------------------------- FOLD 7: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      52.0
# Bug Reproduction                        0.99    0.96      0.98     245.0
# Contribution and Commitment             1.00    1.00      1.00      78.0
# Expected Behaviour                      1.00    0.96      0.98     123.0
# Investigation and Exploration           0.99    0.97      0.98     377.0
# Social Conversation                     0.99    1.00      0.99     726.0
# Motivation                              1.00    0.99      1.00     285.0
# Observed Bug Behaviour                  0.99    0.94      0.96     131.0
# Potential New Issues and Requests       1.00    0.97      0.98     226.0
# Solution Discussion                     0.96    1.00      0.98    1342.0
# Task Progress                           1.00    0.95      0.97     120.0
# Solution Usage                          1.00    0.93      0.97     105.0
# Workarounds                             1.00    0.97      0.98      89.0
# Avg/Total                               0.98    0.98      0.98    3899.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       9.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.73    0.71      0.72      72.0
# Motivation                              0.00    0.00      0.00       3.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       4.0
# Solution Discussion                     0.18    0.93      0.31      69.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          1.00    0.00      0.01     263.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.76    0.27      0.17     431.0
#
# ------------------------- FOLD 8: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.96      0.98      57.0
# Bug Reproduction                        0.97    0.94      0.96     245.0
# Contribution and Commitment             1.00    0.93      0.96      81.0
# Expected Behaviour                      0.98    0.93      0.95     121.0
# Investigation and Exploration           0.98    0.93      0.96     377.0
# Social Conversation                     0.97    0.97      0.97     774.0
# Motivation                              0.99    0.93      0.96     272.0
# Observed Bug Behaviour                  0.98    0.89      0.94     131.0
# Potential New Issues and Requests       1.00    0.91      0.95     179.0
# Solution Discussion                     0.90    0.99      0.95    1386.0
# Task Progress                           1.00    0.84      0.91     120.0
# Solution Usage                          1.00    0.93      0.96     368.0
# Workarounds                             1.00    0.90      0.95      83.0
# Avg/Total                               0.96    0.95      0.95    4194.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.50      0.67       4.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       2.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.52    0.62      0.57      24.0
# Motivation                              1.00    0.06      0.12      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      51.0
# Solution Discussion                     0.20    0.76      0.31      25.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       6.0
# Avg/Total                               0.27    0.27      0.19     136.0
#
# ------------------------- FOLD 9: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.88      0.94      58.0
# Bug Reproduction                        0.99    0.91      0.95     245.0
# Contribution and Commitment             1.00    0.92      0.96      78.0
# Expected Behaviour                      0.97    0.94      0.96     118.0
# Investigation and Exploration           0.98    0.89      0.93     349.0
# Social Conversation                     0.97    0.98      0.98     766.0
# Motivation                              1.00    0.90      0.95     282.0
# Observed Bug Behaviour                  0.98    0.91      0.95     115.0
# Potential New Issues and Requests       1.00    0.93      0.96     229.0
# Solution Discussion                     0.88    1.00      0.94    1335.0
# Task Progress                           1.00    0.89      0.94     111.0
# Solution Usage                          0.99    0.91      0.95     365.0
# Workarounds                             1.00    0.83      0.91      59.0
# Avg/Total                               0.95    0.95      0.95    4110.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.67      0.80       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       6.0
# Investigation and Exploration           0.00    0.00      0.00      28.0
# Social Conversation                     0.61    0.72      0.66      32.0
# Motivation                              0.00    0.00      0.00       6.0
# Observed Bug Behaviour                  1.00    0.06      0.12      16.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.43    0.96      0.59      76.0
# Task Progress                           0.00    0.00      0.00      14.0
# Solution Usage                          0.00    0.00      0.00       3.0
# Workarounds                             0.00    0.00      0.00      30.0
# Avg/Total                               0.32    0.45      0.32     220.0
#
# ------------------------- FOLD 10: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.91      0.95      56.0
# Bug Reproduction                        0.98    0.93      0.95     238.0
# Contribution and Commitment             1.00    0.94      0.97      83.0
# Expected Behaviour                      1.00    0.92      0.96     124.0
# Investigation and Exploration           0.99    0.93      0.96     353.0
# Social Conversation                     0.98    0.99      0.98     788.0
# Motivation                              1.00    0.88      0.94     288.0
# Observed Bug Behaviour                  0.98    0.83      0.90     123.0
# Potential New Issues and Requests       1.00    0.91      0.95     202.0
# Solution Discussion                     0.89    1.00      0.94    1411.0
# Task Progress                           1.00    0.89      0.94     122.0
# Solution Usage                          0.99    0.92      0.95     368.0
# Workarounds                             1.00    0.90      0.95      88.0
# Avg/Total                               0.96    0.95      0.95    4244.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.60      0.75       5.0
# Bug Reproduction                        1.00    0.57      0.73       7.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      24.0
# Social Conversation                     0.43    0.60      0.50      10.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.00    0.00      0.00       8.0
# Potential New Issues and Requests       0.00    0.00      0.00      28.0
# Solution Discussion                     0.00    0.00      0.00       0.0
# Task Progress                           0.00    0.00      0.00       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       1.0
# Avg/Total                               0.19    0.15      0.16      86.0
#
# ------------------------- FOLD 11: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.98      0.99      60.0
# Bug Reproduction                        0.99    0.97      0.98     245.0
# Contribution and Commitment             1.00    0.99      0.99      81.0
# Expected Behaviour                      1.00    0.96      0.98     118.0
# Investigation and Exploration           0.99    0.97      0.98     377.0
# Social Conversation                     0.99    0.99      0.99     755.0
# Motivation                              1.00    1.00      1.00     268.0
# Observed Bug Behaviour                  0.99    0.93      0.96     131.0
# Potential New Issues and Requests       1.00    0.99      0.99     225.0
# Solution Discussion                     0.96    1.00      0.98    1224.0
# Task Progress                           1.00    0.97      0.98     121.0
# Solution Usage                          1.00    0.97      0.98     368.0
# Workarounds                             1.00    0.97      0.98      86.0
# Avg/Total                               0.98    0.98      0.98    4059.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       2.0
# Expected Behaviour                      0.00    0.00      0.00       6.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.62    0.58      0.60      43.0
# Motivation                              0.00    0.00      0.00      20.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       5.0
# Solution Discussion                     0.76    0.91      0.83     187.0
# Task Progress                           0.00    0.00      0.00       4.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.63    0.72      0.67     271.0
#
# ------------------------- FOLD 12: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.95      0.97      59.0
# Bug Reproduction                        0.98    0.88      0.93     207.0
# Contribution and Commitment             1.00    0.92      0.96      76.0
# Expected Behaviour                      0.99    0.95      0.97     123.0
# Investigation and Exploration           0.99    0.90      0.94     273.0
# Social Conversation                     0.96    0.97      0.97     756.0
# Motivation                              1.00    0.92      0.96     288.0
# Observed Bug Behaviour                  0.91    0.86      0.89      50.0
# Potential New Issues and Requests       0.99    0.85      0.92     228.0
# Solution Discussion                     0.89    1.00      0.94    1367.0
# Task Progress                           0.98    0.87      0.92     125.0
# Solution Usage                          1.00    0.92      0.95     368.0
# Workarounds                             1.00    0.84      0.91      81.0
# Avg/Total                               0.95    0.95      0.95    4001.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       2.0
# Bug Reproduction                        0.65    0.29      0.40      38.0
# Contribution and Commitment             1.00    0.14      0.25       7.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.64    0.07      0.12     104.0
# Social Conversation                     0.36    0.57      0.44      42.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.00    0.00      0.00      81.0
# Potential New Issues and Requests       0.00    0.00      0.00       2.0
# Solution Discussion                     0.15    0.70      0.25      44.0
# Task Progress                           0.00    0.00      0.00       0.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       8.0
# Avg/Total                               0.36    0.22      0.18     329.0
#
# ------------------------- FOLD 13: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.93      0.97      61.0
# Bug Reproduction                        0.98    0.96      0.97     245.0
# Contribution and Commitment             1.00    0.93      0.97      76.0
# Expected Behaviour                      1.00    0.90      0.95     110.0
# Investigation and Exploration           0.99    0.94      0.96     374.0
# Social Conversation                     0.98    0.98      0.98     760.0
# Motivation                              1.00    0.91      0.95     255.0
# Observed Bug Behaviour                  0.98    0.91      0.94     131.0
# Potential New Issues and Requests       0.99    0.92      0.95     205.0
# Solution Discussion                     0.90    0.99      0.95    1288.0
# Task Progress                           1.00    0.89      0.94     120.0
# Solution Usage                          0.99    0.92      0.96     366.0
# Workarounds                             0.99    0.92      0.95      89.0
# Avg/Total                               0.96    0.96      0.96    4080.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       0.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       7.0
# Expected Behaviour                      0.00    0.00      0.00      14.0
# Investigation and Exploration           0.00    0.00      0.00       3.0
# Social Conversation                     0.52    0.63      0.57      38.0
# Motivation                              0.00    0.00      0.00      33.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      25.0
# Solution Discussion                     0.57    0.92      0.71     123.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       2.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.36    0.55      0.43     250.0
#
# ------------------------- FOLD 14: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.96    0.95      0.96      58.0
# Bug Reproduction                        0.96    0.93      0.94     245.0
# Contribution and Commitment             1.00    0.92      0.96      78.0
# Expected Behaviour                      0.99    0.85      0.92     121.0
# Investigation and Exploration           0.99    0.93      0.96     377.0
# Social Conversation                     0.97    0.98      0.98     784.0
# Motivation                              1.00    0.90      0.95     286.0
# Observed Bug Behaviour                  0.99    0.85      0.92     131.0
# Potential New Issues and Requests       1.00    0.88      0.93     229.0
# Solution Discussion                     0.88    1.00      0.94    1346.0
# Task Progress                           1.00    0.87      0.93     111.0
# Solution Usage                          1.00    0.93      0.96     367.0
# Workarounds                             1.00    0.88      0.93      89.0
# Avg/Total                               0.95    0.95      0.95    4222.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.67      0.80       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.41    0.79      0.54      14.0
# Motivation                              0.00    0.00      0.00       2.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.70    0.71      0.70      65.0
# Task Progress                           0.00    0.00      0.00      14.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.50    0.55      0.51     108.0

# %% [markdown]
# ### Get list of F1 scores and support-weighted average F1 score

# %%
avg_f1 = []
for i in range(0,15):
    avg_f1.append(float('%.4f' % round(clf1_results['test_avg_fscore'][i],4)))
    
print('Pipeline1:')
print(avg_f1)
# Out:
# Pipeline1:
# [0.5847, 0.2222, 0.1469, 0.3232, 0.7126, 0.2395, 0.5299, 0.1735, 0.1911, 0.3201, 0.1609, 0.6678, 0.1795, 0.4343, 0.5145]

# %%
sum = 0
den = 0
for i in range(0,15):
    sum += clf1_results['test_avg_fscore'][i] * clf1_results['test_total_support'][i]
    den += clf1_results['test_total_support'][i]
print('Pipeline1: Total weighted F-Score: '+('%.4f' % round(sum/den,4)))
# Out:
# Pipeline1: Total weighted F-Score: 0.3585

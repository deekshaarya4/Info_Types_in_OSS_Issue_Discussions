# %% [markdown]
# # Nested Leave-One-Issue-Out Cross Validation For Random Forest On Contextual Features

# %%
import numpy as np
import pandas as pd
import xlrd as xl
from pandas import ExcelWriter
from pandas import ExcelFile
import pprint
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
import re
import pickle
from operator import itemgetter
import time, datetime
from functools import partial, update_wrapper
from openpyxl import load_workbook

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN 

from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as Imb_Pipeline

from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
# from imblearn.ensemble import BalancedBaggingClassifier

from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate, LeaveOneGroupOut
from sklearn.metrics import precision_recall_fscore_support, classification_report, accuracy_score, make_scorer, confusion_matrix

pp = pprint.PrettyPrinter(indent=4)

## Ignore warnings
import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn
np.warnings.filterwarnings('ignore')

# %% [markdown]
# #### Read from the pickled file:

# %%
all_data = pd.read_pickle('../../data/text_conv_data.pkl')

print("Size of corpus: "+str(len(all_data)))
# Out:
# Size of corpus: 4330

# %%
X = all_data.drop(['Code','Text Content','Document'], axis=1)
y = all_data['Code'].values
doc_groups = all_data['Document'].values

print("Number of unique labels: "+str(len(set(y))))

labels = list(set(y))
labels.sort()

pp.pprint(labels)
# Out:
# Number of unique labels: 13
# [   'Action on Issue',
#     'Bug Reproduction',
#     'Contribution and Commitment',
#     'Expected Behaviour',
#     'Investigation and Exploration',
#     'Social Conversation',
#     'Motivation',
#     'Observed Bug Behaviour',
#     'Potential New Issues and Requests',
#     'Solution Discussion',
#     'Task Progress',
#     'Solution Usage',
#     'Workarounds']

# %% [markdown]
# ## Nested Cross-Validation on Random Forest:

# %%
# To be used within GridSearch
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# To be used in outer CV
logo = LeaveOneGroupOut()
outer_cv = logo.split(X,y,groups=doc_groups)

# %% [markdown]
# ### Define Pipelines:
#
# 1. Pipeline1: class_weight=balanced
# 2. Pipeline2: SMOTE

# %%
pipeline1 = Pipeline([
    ('clf', RandomForestClassifier(class_weight='balanced')),
])

pipeline2 = Imb_Pipeline([
    ('smote', SMOTE()),
    ('clf', RandomForestClassifier())
])

### Hyperparameters to search
parameters = {
    'clf__n_estimators': (10, 50, 100),
    'clf__min_samples_split': (2, 5, 10),
}

# %% [markdown]
# ## Nested Cross Validation Using GridSearch

# %%
### Define and create the scoring functions

def score_func(y_true, y_pred, score_index, i):
    return(precision_recall_fscore_support(y_true,y_pred,labels=labels)[score_index][i])

def avg_score(y_true, y_pred, score_index):
    return precision_recall_fscore_support(y_true,y_pred,average='weighted')[score_index]

def sum_support(y_true, y_pred):
    return len(y_true)

### Create partials for each of the metrics returned
score_funcs = {v: partial(score_func, score_index=k) for k, v in {0:'precision',1:'recall',2:'fscore',3:'support'}.items()}
prec_score = partial(score_func, score_index=0)
update_wrapper(prec_score,score_func)
rec_score = partial(score_func, score_index=1)
update_wrapper(rec_score,score_func)
f_score = partial(score_func, score_index=2)
update_wrapper(f_score,score_func)
support_score = partial(score_func, score_index=3)
update_wrapper(support_score,score_func)

### Create a callable scoring function for each of the metrics for each classification label
scorer = {}
for label_id in range(0,13):
    scorer['label'+str(label_id)+'_precision'] = make_scorer(prec_score, i=label_id)
    scorer['label'+str(label_id)+'_recall'] = make_scorer(rec_score, i=label_id)
    scorer['label'+str(label_id)+'_fscore'] = make_scorer(f_score, i=label_id)
    scorer['label'+str(label_id)+'_support'] = make_scorer(support_score, i=label_id)

### Create a callable scoring function for avg/total of the metrics across classification labels
scorer['avg_precision'] = make_scorer(avg_score,score_index=0)
scorer['avg_recall'] = make_scorer(avg_score,score_index=1)
scorer['avg_fscore'] = make_scorer(avg_score,score_index=2)
scorer['total_support'] = make_scorer(sum_support)

### Perform Nested cross-validation on Pipeline1
outer_cv = logo.split(X,y,groups=doc_groups)

start = time.time()
clf1 = GridSearchCV(pipeline1, parameters, cv=inner_cv, scoring='f1_weighted')
clf1_results = cross_validate(clf1, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline1 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))

### Perform Nested cross-validation on Pipeline2
outer_cv = logo.split(X,y,groups=doc_groups)

start = time.time()
clf2 = GridSearchCV(pipeline2, parameters, cv=inner_cv, scoring='f1_weighted')
clf2_results = cross_validate(clf2, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline2 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))
# Out:
# Completed Pipeline1 scenario in 0:31:10.909444
# Completed Pipeline2 scenario in 1:10:38.189200

# %% [markdown]
# # Display and Save Training and Testing Results for each Fold:

# %% [markdown]
# ## Pipeline1 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../../results/LOIO.xlsx')
book = load_workbook('../../results/LOIO.xlsx')
writer = pd.ExcelWriter('../../results/LOIO.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,15):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf1_results['train_label'+str(label_id)+'_precision'][i],clf1_results['train_label'+str(label_id)+'_recall'][i],clf1_results['train_label'+str(label_id)+'_fscore'][i],clf1_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf1_results['test_label'+str(label_id)+'_precision'][i],clf1_results['test_label'+str(label_id)+'_recall'][i],clf1_results['test_label'+str(label_id)+'_fscore'][i],clf1_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf1_results['train_avg_precision'][i],clf1_results['train_avg_recall'][i],clf1_results['train_avg_fscore'][i],clf1_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf1_results['test_avg_precision'][i],clf1_results['test_avg_recall'][i],clf1_results['test_avg_fscore'][i],clf1_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'RCC',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'RCC',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'RCC',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['RCC_train_'+str(i)] = train_report
    result_dict['RCC_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.87    1.00      0.93      53.0
# Bug Reproduction                        0.97    0.99      0.98     245.0
# Contribution and Commitment             0.94    1.00      0.97      58.0
# Expected Behaviour                      0.96    0.98      0.97     119.0
# Investigation and Exploration           0.96    0.98      0.97     377.0
# Social Conversation                     0.96    0.93      0.94     546.0
# Motivation                              0.95    0.98      0.97     261.0
# Observed Bug Behaviour                  0.90    1.00      0.95     131.0
# Potential New Issues and Requests       0.98    1.00      0.99     208.0
# Solution Discussion                     1.00    0.93      0.97    1338.0
# Task Progress                           0.95    1.00      0.98     104.0
# Solution Usage                          0.92    1.00      0.96     368.0
# Workarounds                             0.95    1.00      0.97      86.0
# Avg/Total                               0.97    0.96      0.96    3894.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       8.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00      25.0
# Expected Behaviour                      0.00    0.00      0.00       5.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.88    0.59      0.70     252.0
# Motivation                              0.00    0.00      0.00      27.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      22.0
# Solution Discussion                     0.32    0.44      0.37      73.0
# Task Progress                           0.00    0.00      0.00      21.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.56    0.41      0.47     436.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.87    0.98      0.92      60.0
# Bug Reproduction                        0.96    0.99      0.98     245.0
# Contribution and Commitment             0.89    1.00      0.94      80.0
# Expected Behaviour                      0.91    1.00      0.95      42.0
# Investigation and Exploration           0.95    0.98      0.97     377.0
# Social Conversation                     0.98    0.93      0.95     716.0
# Motivation                              0.91    0.99      0.95     134.0
# Observed Bug Behaviour                  0.90    1.00      0.95     131.0
# Potential New Issues and Requests       0.96    1.00      0.98     217.0
# Solution Discussion                     1.00    0.93      0.96    1231.0
# Task Progress                           0.97    0.99      0.98     113.0
# Solution Usage                          0.89    1.00      0.94     272.0
# Workarounds                             0.96    1.00      0.98      66.0
# Avg/Total                               0.96    0.96      0.96    3684.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       3.0
# Expected Behaviour                      0.00    0.00      0.00      82.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.57    0.48      0.52      82.0
# Motivation                              0.65    0.08      0.15     154.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      13.0
# Solution Discussion                     0.34    0.63      0.44     180.0
# Task Progress                           0.00    0.00      0.00      12.0
# Solution Usage                          0.22    0.04      0.07      96.0
# Workarounds                             0.00    0.00      0.00      23.0
# Avg/Total                               0.36    0.26      0.24     646.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.89    1.00      0.94      58.0
# Bug Reproduction                        0.96    1.00      0.98     216.0
# Contribution and Commitment             0.89    1.00      0.94      77.0
# Expected Behaviour                      0.96    0.99      0.98     124.0
# Investigation and Exploration           0.94    0.99      0.97     309.0
# Social Conversation                     0.98    0.92      0.95     773.0
# Motivation                              0.94    0.99      0.96     288.0
# Observed Bug Behaviour                  0.90    1.00      0.95     125.0
# Potential New Issues and Requests       0.95    1.00      0.97     167.0
# Solution Discussion                     0.99    0.94      0.97    1386.0
# Task Progress                           0.96    1.00      0.98     117.0
# Solution Usage                          0.93    1.00      0.96     368.0
# Workarounds                             0.93    1.00      0.96      89.0
# Avg/Total                               0.96    0.96      0.96    4097.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.29    0.67      0.40       3.0
# Bug Reproduction                        0.40    0.07      0.12      29.0
# Contribution and Commitment             0.00    0.00      0.00       6.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.29    0.24      0.26      68.0
# Social Conversation                     0.31    0.72      0.43      25.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.00    0.00      0.00       6.0
# Potential New Issues and Requests       0.00    0.00      0.00      63.0
# Solution Discussion                     0.16    0.48      0.24      25.0
# Task Progress                           0.33    0.12      0.18       8.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.20    0.22      0.17     233.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.90    1.00      0.95      55.0
# Bug Reproduction                        0.95    1.00      0.97     201.0
# Contribution and Commitment             0.87    1.00      0.93      75.0
# Expected Behaviour                      0.92    0.99      0.96     124.0
# Investigation and Exploration           0.96    0.98      0.97     351.0
# Social Conversation                     0.98    0.92      0.95     752.0
# Motivation                              0.94    0.98      0.96     288.0
# Observed Bug Behaviour                  0.90    1.00      0.95     121.0
# Potential New Issues and Requests       0.97    1.00      0.98     218.0
# Solution Discussion                     0.99    0.94      0.97    1318.0
# Task Progress                           0.95    1.00      0.97     107.0
# Solution Usage                          0.92    0.99      0.96     366.0
# Workarounds                             0.90    1.00      0.95      85.0
# Avg/Total                               0.96    0.96      0.96    4061.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.50    0.33      0.40       6.0
# Bug Reproduction                        0.00    0.00      0.00      44.0
# Contribution and Commitment             0.00    0.00      0.00       8.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      26.0
# Social Conversation                     0.44    0.67      0.53      46.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  1.00    0.40      0.57      10.0
# Potential New Issues and Requests       0.40    0.50      0.44      12.0
# Solution Discussion                     0.34    0.48      0.40      93.0
# Task Progress                           0.00    0.00      0.00      18.0
# Solution Usage                          0.00    0.00      0.00       2.0
# Workarounds                             0.00    0.00      0.00       4.0
# Avg/Total                               0.26    0.33      0.28     269.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.88    1.00      0.94      53.0
# Bug Reproduction                        0.96    0.99      0.98     244.0
# Contribution and Commitment             0.87    1.00      0.93      83.0
# Expected Behaviour                      0.92    0.99      0.95     121.0
# Investigation and Exploration           0.95    0.98      0.97     376.0
# Social Conversation                     0.99    0.92      0.95     757.0
# Motivation                              0.94    0.99      0.96     272.0
# Observed Bug Behaviour                  0.89    1.00      0.94     131.0
# Potential New Issues and Requests       0.96    1.00      0.98     229.0
# Solution Discussion                     0.99    0.93      0.96    1214.0
# Task Progress                           0.95    1.00      0.98     117.0
# Solution Usage                          0.93    0.99      0.96     367.0
# Workarounds                             0.90    1.00      0.95      87.0
# Avg/Total                               0.96    0.96      0.96    4051.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.75    0.38      0.50       8.0
# Bug Reproduction                        0.00    0.00      0.00       1.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       1.0
# Social Conversation                     0.41    0.68      0.51      41.0
# Motivation                              0.00    0.00      0.00      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.03    1.00      0.06       1.0
# Solution Discussion                     0.81    0.42      0.55     197.0
# Task Progress                           0.00    0.00      0.00       8.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       2.0
# Avg/Total                               0.65    0.41      0.48     279.0
#
# ------------------------- FOLD 5: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.89    1.00      0.94      55.0
# Bug Reproduction                        0.96    0.99      0.98     160.0
# Contribution and Commitment             0.92    1.00      0.96      78.0
# Expected Behaviour                      0.95    1.00      0.98     124.0
# Investigation and Exploration           0.94    0.97      0.95     266.0
# Social Conversation                     0.98    0.92      0.95     759.0
# Motivation                              0.94    0.99      0.96     287.0
# Observed Bug Behaviour                  0.90    1.00      0.95     125.0
# Potential New Issues and Requests       0.96    1.00      0.98     230.0
# Solution Discussion                     1.00    0.95      0.97    1349.0
# Task Progress                           0.95    1.00      0.97     122.0
# Solution Usage                          0.92    1.00      0.96     368.0
# Workarounds                             0.93    1.00      0.96      89.0
# Avg/Total                               0.97    0.96      0.96    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       6.0
# Bug Reproduction                        0.57    0.05      0.09      85.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.60    0.03      0.05     111.0
# Social Conversation                     0.38    0.54      0.45      39.0
# Motivation                              0.00    0.00      0.00       1.0
# Observed Bug Behaviour                  0.83    0.83      0.83       6.0
# Potential New Issues and Requests       0.00    0.00      0.00       0.0
# Solution Discussion                     0.19    0.45      0.27      62.0
# Task Progress                           0.08    0.33      0.13       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.46    0.19      0.17     318.0
#
# ------------------------- FOLD 6: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.87    1.00      0.93      59.0
# Bug Reproduction                        0.94    1.00      0.97     204.0
# Contribution and Commitment             0.94    1.00      0.97      80.0
# Expected Behaviour                      0.93    1.00      0.96     124.0
# Investigation and Exploration           0.95    0.98      0.97     365.0
# Social Conversation                     0.98    0.91      0.95     760.0
# Motivation                              0.95    0.99      0.97     278.0
# Observed Bug Behaviour                  0.91    1.00      0.95     127.0
# Potential New Issues and Requests       0.96    1.00      0.98     228.0
# Solution Discussion                     0.99    0.94      0.96    1219.0
# Task Progress                           0.93    1.00      0.96     120.0
# Solution Usage                          0.92    1.00      0.96     368.0
# Workarounds                             0.92    1.00      0.96      80.0
# Avg/Total                               0.96    0.96      0.96    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       2.0
# Bug Reproduction                        0.23    0.17      0.20      41.0
# Contribution and Commitment             0.00    0.00      0.00       3.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      12.0
# Social Conversation                     0.31    0.68      0.43      38.0
# Motivation                              0.00    0.00      0.00      10.0
# Observed Bug Behaviour                  0.08    1.00      0.15       4.0
# Potential New Issues and Requests       0.00    0.00      0.00       2.0
# Solution Discussion                     0.75    0.24      0.36     192.0
# Task Progress                           0.33    0.20      0.25       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       9.0
# Avg/Total                               0.53    0.26      0.30     318.0
#
# ------------------------- FOLD 7: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.91    1.00      0.95      52.0
# Bug Reproduction                        0.96    0.99      0.98     245.0
# Contribution and Commitment             0.93    1.00      0.96      78.0
# Expected Behaviour                      0.95    1.00      0.97     123.0
# Investigation and Exploration           0.95    0.98      0.96     377.0
# Social Conversation                     0.98    0.92      0.95     726.0
# Motivation                              0.95    0.98      0.96     285.0
# Observed Bug Behaviour                  0.89    1.00      0.94     131.0
# Potential New Issues and Requests       0.96    1.00      0.98     226.0
# Solution Discussion                     0.99    0.95      0.97    1342.0
# Task Progress                           0.95    1.00      0.98     120.0
# Solution Usage                          0.93    1.00      0.96     105.0
# Workarounds                             0.92    1.00      0.96      89.0
# Avg/Total                               0.97    0.97      0.97    3899.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.60    0.33      0.43       9.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.50    0.20      0.29       5.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.56    0.61      0.58      72.0
# Motivation                              0.10    0.67      0.17       3.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       4.0
# Solution Discussion                     0.21    0.58      0.31      69.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.80    0.05      0.09     263.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.63    0.24      0.21     431.0
#
# ------------------------- FOLD 8: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.90    0.98      0.94      57.0
# Bug Reproduction                        0.96    0.99      0.98     245.0
# Contribution and Commitment             0.93    1.00      0.96      81.0
# Expected Behaviour                      0.94    0.99      0.97     121.0
# Investigation and Exploration           0.96    0.98      0.97     377.0
# Social Conversation                     0.98    0.93      0.95     774.0
# Motivation                              0.93    0.97      0.95     272.0
# Observed Bug Behaviour                  0.88    1.00      0.94     131.0
# Potential New Issues and Requests       0.96    0.99      0.98     179.0
# Solution Discussion                     0.99    0.95      0.97    1386.0
# Task Progress                           0.96    1.00      0.98     120.0
# Solution Usage                          0.93    1.00      0.96     368.0
# Workarounds                             0.91    1.00      0.95      83.0
# Avg/Total                               0.97    0.96      0.96    4194.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.50      0.67       4.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       2.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.67    0.25      0.36      24.0
# Motivation                              0.00    0.00      0.00      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.60    0.06      0.11      51.0
# Solution Discussion                     0.22    0.92      0.35      25.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       6.0
# Avg/Total                               0.41    0.25      0.19     136.0
#
# ------------------------- FOLD 9: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.92    1.00      0.96      58.0
# Bug Reproduction                        0.96    0.99      0.97     245.0
# Contribution and Commitment             0.90    1.00      0.95      78.0
# Expected Behaviour                      0.96    1.00      0.98     118.0
# Investigation and Exploration           0.95    0.98      0.97     349.0
# Social Conversation                     0.98    0.93      0.95     766.0
# Motivation                              0.93    0.99      0.96     282.0
# Observed Bug Behaviour                  0.89    1.00      0.94     115.0
# Potential New Issues and Requests       0.95    1.00      0.97     229.0
# Solution Discussion                     0.99    0.94      0.97    1335.0
# Task Progress                           0.95    1.00      0.97     111.0
# Solution Usage                          0.94    1.00      0.97     365.0
# Workarounds                             0.94    1.00      0.97      59.0
# Avg/Total                               0.97    0.96      0.96    4110.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.33    1.00      0.50       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       6.0
# Investigation and Exploration           0.00    0.00      0.00      28.0
# Social Conversation                     0.57    0.62      0.60      32.0
# Motivation                              0.00    0.00      0.00       6.0
# Observed Bug Behaviour                  0.25    0.25      0.25      16.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.48    0.78      0.59      76.0
# Task Progress                           0.00    0.00      0.00      14.0
# Solution Usage                          0.00    0.00      0.00       3.0
# Workarounds                             0.00    0.00      0.00      30.0
# Avg/Total                               0.27    0.39      0.32     220.0
#
# ------------------------- FOLD 10: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.88    1.00      0.93      56.0
# Bug Reproduction                        0.98    1.00      0.99     238.0
# Contribution and Commitment             0.87    1.00      0.93      83.0
# Expected Behaviour                      0.93    1.00      0.96     124.0
# Investigation and Exploration           0.94    0.98      0.96     353.0
# Social Conversation                     0.99    0.92      0.95     788.0
# Motivation                              0.94    0.98      0.96     288.0
# Observed Bug Behaviour                  0.90    1.00      0.95     123.0
# Potential New Issues and Requests       0.96    1.00      0.98     202.0
# Solution Discussion                     0.99    0.94      0.97    1411.0
# Task Progress                           0.97    1.00      0.98     122.0
# Solution Usage                          0.92    1.00      0.96     368.0
# Workarounds                             0.91    1.00      0.95      88.0
# Avg/Total                               0.96    0.96      0.96    4244.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.40      0.57       5.0
# Bug Reproduction                        0.33    0.43      0.38       7.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      24.0
# Social Conversation                     0.44    0.40      0.42      10.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.71    0.62      0.67       8.0
# Potential New Issues and Requests       0.50    0.04      0.07      28.0
# Solution Discussion                     0.00    0.00      0.00       0.0
# Task Progress                           0.00    0.00      0.00       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       1.0
# Avg/Total                               0.37    0.17      0.20      86.0
#
# ------------------------- FOLD 11: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.87    1.00      0.93      60.0
# Bug Reproduction                        0.97    1.00      0.98     245.0
# Contribution and Commitment             0.91    1.00      0.95      81.0
# Expected Behaviour                      0.94    1.00      0.97     118.0
# Investigation and Exploration           0.96    0.98      0.97     377.0
# Social Conversation                     0.99    0.92      0.95     755.0
# Motivation                              0.94    0.98      0.96     268.0
# Observed Bug Behaviour                  0.89    1.00      0.94     131.0
# Potential New Issues and Requests       0.96    1.00      0.98     225.0
# Solution Discussion                     1.00    0.94      0.97    1224.0
# Task Progress                           0.96    1.00      0.98     121.0
# Solution Usage                          0.93    1.00      0.97     368.0
# Workarounds                             0.91    1.00      0.96      86.0
# Avg/Total                               0.97    0.96      0.96    4059.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       2.0
# Expected Behaviour                      0.00    0.00      0.00       6.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.71    0.47      0.56      43.0
# Motivation                              0.00    0.00      0.00      20.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       5.0
# Solution Discussion                     0.80    0.56      0.66     187.0
# Task Progress                           0.00    0.00      0.00       4.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.67    0.46      0.55     271.0
#
# ------------------------- FOLD 12: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.88    1.00      0.94      59.0
# Bug Reproduction                        0.98    0.99      0.98     207.0
# Contribution and Commitment             0.92    1.00      0.96      76.0
# Expected Behaviour                      0.96    0.99      0.98     123.0
# Investigation and Exploration           0.96    0.99      0.98     273.0
# Social Conversation                     0.98    0.93      0.95     756.0
# Motivation                              0.94    0.98      0.96     288.0
# Observed Bug Behaviour                  0.88    1.00      0.93      50.0
# Potential New Issues and Requests       0.97    1.00      0.98     228.0
# Solution Discussion                     0.99    0.95      0.97    1367.0
# Task Progress                           0.95    1.00      0.97     125.0
# Solution Usage                          0.92    0.99      0.96     368.0
# Workarounds                             0.92    1.00      0.96      81.0
# Avg/Total                               0.97    0.96      0.96    4001.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       2.0
# Bug Reproduction                        0.00    0.00      0.00      38.0
# Contribution and Commitment             0.00    0.00      0.00       7.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.33    0.02      0.04     104.0
# Social Conversation                     0.20    0.48      0.28      42.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.29    0.02      0.05      81.0
# Potential New Issues and Requests       0.07    0.50      0.12       2.0
# Solution Discussion                     0.15    0.52      0.23      44.0
# Task Progress                           0.00    0.00      0.00       0.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       8.0
# Avg/Total                               0.22    0.15      0.09     329.0
#
# ------------------------- FOLD 13: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.91    0.98      0.94      61.0
# Bug Reproduction                        0.98    1.00      0.99     245.0
# Contribution and Commitment             0.92    1.00      0.96      76.0
# Expected Behaviour                      0.92    0.99      0.95     110.0
# Investigation and Exploration           0.96    0.97      0.97     374.0
# Social Conversation                     0.98    0.92      0.95     760.0
# Motivation                              0.93    0.98      0.95     255.0
# Observed Bug Behaviour                  0.88    1.00      0.94     131.0
# Potential New Issues and Requests       0.97    1.00      0.98     205.0
# Solution Discussion                     0.99    0.94      0.97    1288.0
# Task Progress                           0.95    1.00      0.98     120.0
# Solution Usage                          0.93    1.00      0.96     366.0
# Workarounds                             0.95    0.99      0.97      89.0
# Avg/Total                               0.97    0.96      0.96    4080.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       0.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       7.0
# Expected Behaviour                      0.00    0.00      0.00      14.0
# Investigation and Exploration           0.00    0.00      0.00       3.0
# Social Conversation                     0.56    0.37      0.44      38.0
# Motivation                              0.16    0.24      0.19      33.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      25.0
# Solution Discussion                     0.46    0.58      0.51     123.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       2.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.33    0.37      0.35     250.0
#
# ------------------------- FOLD 14: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.88    1.00      0.94      58.0
# Bug Reproduction                        0.96    1.00      0.98     245.0
# Contribution and Commitment             0.91    1.00      0.95      78.0
# Expected Behaviour                      0.95    0.99      0.97     121.0
# Investigation and Exploration           0.96    0.98      0.97     377.0
# Social Conversation                     0.99    0.92      0.95     784.0
# Motivation                              0.95    0.98      0.96     286.0
# Observed Bug Behaviour                  0.89    1.00      0.94     131.0
# Potential New Issues and Requests       0.97    1.00      0.98     229.0
# Solution Discussion                     1.00    0.95      0.97    1346.0
# Task Progress                           0.96    1.00      0.98     111.0
# Solution Usage                          0.92    1.00      0.96     367.0
# Workarounds                             0.95    1.00      0.97      89.0
# Avg/Total                               0.97    0.97      0.97    4222.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.50    0.67      0.57       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.35    0.79      0.49      14.0
# Motivation                              0.00    0.00      0.00       2.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.76    0.57      0.65      65.0
# Task Progress                           0.50    0.14      0.22      14.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.58    0.48      0.50     108.0

# %% [markdown]
# ## Pipeline2 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../../results/LOIO.xlsx')
book = load_workbook('../../results/LOIO.xlsx')
writer = pd.ExcelWriter('../../results/LOIO.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,15):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf2_results['train_label'+str(label_id)+'_precision'][i],clf2_results['train_label'+str(label_id)+'_recall'][i],clf2_results['train_label'+str(label_id)+'_fscore'][i],clf2_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf2_results['test_label'+str(label_id)+'_precision'][i],clf2_results['test_label'+str(label_id)+'_recall'][i],clf2_results['test_label'+str(label_id)+'_fscore'][i],clf2_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf2_results['train_avg_precision'][i],clf2_results['train_avg_recall'][i],clf2_results['train_avg_fscore'][i],clf2_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf2_results['test_avg_precision'][i],clf2_results['test_avg_recall'][i],clf2_results['test_avg_fscore'][i],clf2_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'RCS',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'RCS',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'RCS',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['RCS_train_'+str(i)] = train_report
    result_dict['RCS_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      53.0
# Bug Reproduction                         1.0     1.0       1.0     245.0
# Contribution and Commitment              1.0     1.0       1.0      58.0
# Expected Behaviour                       1.0     1.0       1.0     119.0
# Investigation and Exploration            1.0     1.0       1.0     377.0
# Social Conversation                      1.0     1.0       1.0     546.0
# Motivation                               1.0     1.0       1.0     261.0
# Observed Bug Behaviour                   1.0     1.0       1.0     131.0
# Potential New Issues and Requests        1.0     1.0       1.0     208.0
# Solution Discussion                      1.0     1.0       1.0    1338.0
# Task Progress                            1.0     1.0       1.0     104.0
# Solution Usage                           1.0     1.0       1.0     368.0
# Workarounds                              1.0     1.0       1.0      86.0
# Avg/Total                                1.0     1.0       1.0    3894.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       8.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00      25.0
# Expected Behaviour                      0.18    0.40      0.25       5.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.87    0.69      0.77     252.0
# Motivation                              0.00    0.00      0.00      27.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      22.0
# Solution Discussion                     0.33    0.19      0.24      73.0
# Task Progress                           0.00    0.00      0.00      21.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.56    0.44      0.49     436.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      60.0
# Bug Reproduction                         1.0     1.0       1.0     245.0
# Contribution and Commitment              1.0     1.0       1.0      80.0
# Expected Behaviour                       1.0     1.0       1.0      42.0
# Investigation and Exploration            1.0     1.0       1.0     377.0
# Social Conversation                      1.0     1.0       1.0     716.0
# Motivation                               1.0     1.0       1.0     134.0
# Observed Bug Behaviour                   1.0     1.0       1.0     131.0
# Potential New Issues and Requests        1.0     1.0       1.0     217.0
# Solution Discussion                      1.0     1.0       1.0    1231.0
# Task Progress                            1.0     1.0       1.0     113.0
# Solution Usage                           1.0     1.0       1.0     272.0
# Workarounds                              1.0     1.0       1.0      66.0
# Avg/Total                                1.0     1.0       1.0    3684.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       3.0
# Expected Behaviour                      0.09    0.02      0.04      82.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.52    0.49      0.50      82.0
# Motivation                              0.43    0.06      0.10     154.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      13.0
# Solution Discussion                     0.33    0.41      0.36     180.0
# Task Progress                           0.00    0.00      0.00      12.0
# Solution Usage                          0.21    0.04      0.07      96.0
# Workarounds                             0.00    0.00      0.00      23.0
# Avg/Total                               0.30    0.20      0.20     646.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      58.0
# Bug Reproduction                         1.0     1.0       1.0     216.0
# Contribution and Commitment              1.0     1.0       1.0      77.0
# Expected Behaviour                       1.0     1.0       1.0     124.0
# Investigation and Exploration            1.0     1.0       1.0     309.0
# Social Conversation                      1.0     1.0       1.0     773.0
# Motivation                               1.0     1.0       1.0     288.0
# Observed Bug Behaviour                   1.0     1.0       1.0     125.0
# Potential New Issues and Requests        1.0     1.0       1.0     167.0
# Solution Discussion                      1.0     1.0       1.0    1386.0
# Task Progress                            1.0     1.0       1.0     117.0
# Solution Usage                           1.0     1.0       1.0     368.0
# Workarounds                              1.0     1.0       1.0      89.0
# Avg/Total                                1.0     1.0       1.0    4097.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.05    0.67      0.09       3.0
# Bug Reproduction                        0.40    0.21      0.27      29.0
# Contribution and Commitment             0.00    0.00      0.00       6.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.35    0.35      0.35      68.0
# Social Conversation                     0.50    0.60      0.55      25.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.00    0.00      0.00       6.0
# Potential New Issues and Requests       0.00    0.00      0.00      63.0
# Solution Discussion                     0.22    0.24      0.23      25.0
# Task Progress                           0.17    0.12      0.14       8.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.24    0.23      0.23     233.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      55.0
# Bug Reproduction                         1.0     1.0       1.0     201.0
# Contribution and Commitment              1.0     1.0       1.0      75.0
# Expected Behaviour                       1.0     1.0       1.0     124.0
# Investigation and Exploration            1.0     1.0       1.0     351.0
# Social Conversation                      1.0     1.0       1.0     752.0
# Motivation                               1.0     1.0       1.0     288.0
# Observed Bug Behaviour                   1.0     1.0       1.0     121.0
# Potential New Issues and Requests        1.0     1.0       1.0     218.0
# Solution Discussion                      1.0     1.0       1.0    1318.0
# Task Progress                            1.0     1.0       1.0     107.0
# Solution Usage                           1.0     1.0       1.0     366.0
# Workarounds                              1.0     1.0       1.0      85.0
# Avg/Total                                1.0     1.0       1.0    4061.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.40    0.33      0.36       6.0
# Bug Reproduction                        0.33    0.02      0.04      44.0
# Contribution and Commitment             0.50    0.12      0.20       8.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      26.0
# Social Conversation                     0.47    0.72      0.57      46.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.50    0.30      0.37      10.0
# Potential New Issues and Requests       0.27    0.25      0.26      12.0
# Solution Discussion                     0.33    0.28      0.30      93.0
# Task Progress                           0.00    0.00      0.00      18.0
# Solution Usage                          0.00    0.00      0.00       2.0
# Workarounds                             0.00    0.00      0.00       4.0
# Avg/Total                               0.30    0.26      0.25     269.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      53.0
# Bug Reproduction                         1.0     1.0       1.0     244.0
# Contribution and Commitment              1.0     1.0       1.0      83.0
# Expected Behaviour                       1.0     1.0       1.0     121.0
# Investigation and Exploration            1.0     1.0       1.0     376.0
# Social Conversation                      1.0     1.0       1.0     757.0
# Motivation                               1.0     1.0       1.0     272.0
# Observed Bug Behaviour                   1.0     1.0       1.0     131.0
# Potential New Issues and Requests        1.0     1.0       1.0     229.0
# Solution Discussion                      1.0     1.0       1.0    1214.0
# Task Progress                            1.0     1.0       1.0     117.0
# Solution Usage                           1.0     1.0       1.0     367.0
# Workarounds                              1.0     1.0       1.0      87.0
# Avg/Total                                1.0     1.0       1.0    4051.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.60    0.38      0.46       8.0
# Bug Reproduction                        0.00    0.00      0.00       1.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       1.0
# Social Conversation                     0.51    0.61      0.56      41.0
# Motivation                              0.12    0.06      0.08      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.01    1.00      0.03       1.0
# Solution Discussion                     0.87    0.20      0.32     197.0
# Task Progress                           0.05    0.12      0.07       8.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       2.0
# Avg/Total                               0.71    0.25      0.33     279.0
#
# ------------------------- FOLD 5: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      55.0
# Bug Reproduction                         1.0     1.0       1.0     160.0
# Contribution and Commitment              1.0     1.0       1.0      78.0
# Expected Behaviour                       1.0     1.0       1.0     124.0
# Investigation and Exploration            1.0     1.0       1.0     266.0
# Social Conversation                      1.0     1.0       1.0     759.0
# Motivation                               1.0     1.0       1.0     287.0
# Observed Bug Behaviour                   1.0     1.0       1.0     125.0
# Potential New Issues and Requests        1.0     1.0       1.0     230.0
# Solution Discussion                      1.0     1.0       1.0    1349.0
# Task Progress                            1.0     1.0       1.0     122.0
# Solution Usage                           1.0     1.0       1.0     368.0
# Workarounds                              1.0     1.0       1.0      89.0
# Avg/Total                                1.0     1.0       1.0    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       6.0
# Bug Reproduction                        0.44    0.05      0.09      85.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.50    0.13      0.20     111.0
# Social Conversation                     0.41    0.54      0.47      39.0
# Motivation                              0.00    0.00      0.00       1.0
# Observed Bug Behaviour                  0.45    0.83      0.59       6.0
# Potential New Issues and Requests       0.00    0.00      0.00       0.0
# Solution Discussion                     0.22    0.21      0.21      62.0
# Task Progress                           0.00    0.00      0.00       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.40    0.18      0.20     318.0
#
# ------------------------- FOLD 6: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      59.0
# Bug Reproduction                         1.0     1.0       1.0     204.0
# Contribution and Commitment              1.0     1.0       1.0      80.0
# Expected Behaviour                       1.0     1.0       1.0     124.0
# Investigation and Exploration            1.0     1.0       1.0     365.0
# Social Conversation                      1.0     1.0       1.0     760.0
# Motivation                               1.0     1.0       1.0     278.0
# Observed Bug Behaviour                   1.0     1.0       1.0     127.0
# Potential New Issues and Requests        1.0     1.0       1.0     228.0
# Solution Discussion                      1.0     1.0       1.0    1219.0
# Task Progress                            1.0     1.0       1.0     120.0
# Solution Usage                           1.0     1.0       1.0     368.0
# Workarounds                              1.0     1.0       1.0      80.0
# Avg/Total                                1.0     1.0       1.0    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       2.0
# Bug Reproduction                        0.22    0.17      0.19      41.0
# Contribution and Commitment             0.00    0.00      0.00       3.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.08    0.08      0.08      12.0
# Social Conversation                     0.31    0.66      0.42      38.0
# Motivation                              0.00    0.00      0.00      10.0
# Observed Bug Behaviour                  0.10    1.00      0.18       4.0
# Potential New Issues and Requests       0.00    0.00      0.00       2.0
# Solution Discussion                     0.64    0.12      0.20     192.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       9.0
# Avg/Total                               0.46    0.19      0.20     318.0
#
# ------------------------- FOLD 7: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      52.0
# Bug Reproduction                         1.0     1.0       1.0     245.0
# Contribution and Commitment              1.0     1.0       1.0      78.0
# Expected Behaviour                       1.0     1.0       1.0     123.0
# Investigation and Exploration            1.0     1.0       1.0     377.0
# Social Conversation                      1.0     1.0       1.0     726.0
# Motivation                               1.0     1.0       1.0     285.0
# Observed Bug Behaviour                   1.0     1.0       1.0     131.0
# Potential New Issues and Requests        1.0     1.0       1.0     226.0
# Solution Discussion                      1.0     1.0       1.0    1342.0
# Task Progress                            1.0     1.0       1.0     120.0
# Solution Usage                           1.0     1.0       1.0     105.0
# Workarounds                              1.0     1.0       1.0      89.0
# Avg/Total                                1.0     1.0       1.0    3899.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.25    0.22      0.24       9.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.50    0.54      0.52      72.0
# Motivation                              0.07    0.67      0.12       3.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       4.0
# Solution Discussion                     0.20    0.26      0.22      69.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.58    0.05      0.10     263.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.48    0.17      0.19     431.0
#
# ------------------------- FOLD 8: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      57.0
# Bug Reproduction                         1.0     1.0       1.0     245.0
# Contribution and Commitment              1.0     1.0       1.0      81.0
# Expected Behaviour                       1.0     1.0       1.0     121.0
# Investigation and Exploration            1.0     1.0       1.0     377.0
# Social Conversation                      1.0     1.0       1.0     774.0
# Motivation                               1.0     1.0       1.0     272.0
# Observed Bug Behaviour                   1.0     1.0       1.0     131.0
# Potential New Issues and Requests        1.0     1.0       1.0     179.0
# Solution Discussion                      1.0     1.0       1.0    1386.0
# Task Progress                            1.0     1.0       1.0     120.0
# Solution Usage                           1.0     1.0       1.0     368.0
# Workarounds                              1.0     1.0       1.0      83.0
# Avg/Total                                1.0     1.0       1.0    4194.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.50      0.67       4.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       2.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.73    0.33      0.46      24.0
# Motivation                              0.00    0.00      0.00      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       1.00    0.10      0.18      51.0
# Solution Discussion                     0.24    0.80      0.37      25.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       6.0
# Avg/Total                               0.58    0.26      0.24     136.0
#
# ------------------------- FOLD 9: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      58.0
# Bug Reproduction                         1.0     1.0       1.0     245.0
# Contribution and Commitment              1.0     1.0       1.0      78.0
# Expected Behaviour                       1.0     1.0       1.0     118.0
# Investigation and Exploration            1.0     1.0       1.0     349.0
# Social Conversation                      1.0     1.0       1.0     766.0
# Motivation                               1.0     1.0       1.0     282.0
# Observed Bug Behaviour                   1.0     1.0       1.0     115.0
# Potential New Issues and Requests        1.0     1.0       1.0     229.0
# Solution Discussion                      1.0     1.0       1.0    1335.0
# Task Progress                            1.0     1.0       1.0     111.0
# Solution Usage                           1.0     1.0       1.0     365.0
# Workarounds                              1.0     1.0       1.0      59.0
# Avg/Total                                1.0     1.0       1.0    4110.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.19    1.00      0.32       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.25    0.40      0.31       5.0
# Expected Behaviour                      0.00    0.00      0.00       6.0
# Investigation and Exploration           0.25    0.18      0.21      28.0
# Social Conversation                     0.69    0.69      0.69      32.0
# Motivation                              0.00    0.00      0.00       6.0
# Observed Bug Behaviour                  0.25    0.25      0.25      16.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.36    0.16      0.22      76.0
# Task Progress                           0.00    0.00      0.00      14.0
# Solution Usage                          0.00    0.00      0.00       3.0
# Workarounds                             0.00    0.00      0.00      30.0
# Avg/Total                               0.28    0.22      0.23     220.0
#
# ------------------------- FOLD 10: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      56.0
# Bug Reproduction                         1.0     1.0       1.0     238.0
# Contribution and Commitment              1.0     1.0       1.0      83.0
# Expected Behaviour                       1.0     1.0       1.0     124.0
# Investigation and Exploration            1.0     1.0       1.0     353.0
# Social Conversation                      1.0     1.0       1.0     788.0
# Motivation                               1.0     1.0       1.0     288.0
# Observed Bug Behaviour                   1.0     1.0       1.0     123.0
# Potential New Issues and Requests        1.0     1.0       1.0     202.0
# Solution Discussion                      1.0     1.0       1.0    1411.0
# Task Progress                            1.0     1.0       1.0     122.0
# Solution Usage                           1.0     1.0       1.0     368.0
# Workarounds                              1.0     1.0       1.0      88.0
# Avg/Total                                1.0     1.0       1.0    4244.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.67    0.40      0.50       5.0
# Bug Reproduction                        0.23    0.43      0.30       7.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      24.0
# Social Conversation                     0.33    0.30      0.32      10.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.80    0.50      0.62       8.0
# Potential New Issues and Requests       0.50    0.11      0.18      28.0
# Solution Discussion                     0.00    0.00      0.00       0.0
# Task Progress                           0.00    0.00      0.00       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       1.0
# Avg/Total                               0.33    0.17      0.20      86.0
#
# ------------------------- FOLD 11: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      60.0
# Bug Reproduction                         1.0     1.0       1.0     245.0
# Contribution and Commitment              1.0     1.0       1.0      81.0
# Expected Behaviour                       1.0     1.0       1.0     118.0
# Investigation and Exploration            1.0     1.0       1.0     377.0
# Social Conversation                      1.0     1.0       1.0     755.0
# Motivation                               1.0     1.0       1.0     268.0
# Observed Bug Behaviour                   1.0     1.0       1.0     131.0
# Potential New Issues and Requests        1.0     1.0       1.0     225.0
# Solution Discussion                      1.0     1.0       1.0    1224.0
# Task Progress                            1.0     1.0       1.0     121.0
# Solution Usage                           1.0     1.0       1.0     368.0
# Workarounds                              1.0     1.0       1.0      86.0
# Avg/Total                                1.0     1.0       1.0    4059.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       2.0
# Expected Behaviour                      0.00    0.00      0.00       6.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.63    0.40      0.49      43.0
# Motivation                              0.00    0.00      0.00      20.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       5.0
# Solution Discussion                     0.78    0.43      0.56     187.0
# Task Progress                           0.00    0.00      0.00       4.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.64    0.36      0.46     271.0
#
# ------------------------- FOLD 12: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      59.0
# Bug Reproduction                         1.0     1.0       1.0     207.0
# Contribution and Commitment              1.0     1.0       1.0      76.0
# Expected Behaviour                       1.0     1.0       1.0     123.0
# Investigation and Exploration            1.0     1.0       1.0     273.0
# Social Conversation                      1.0     1.0       1.0     756.0
# Motivation                               1.0     1.0       1.0     288.0
# Observed Bug Behaviour                   1.0     1.0       1.0      50.0
# Potential New Issues and Requests        1.0     1.0       1.0     228.0
# Solution Discussion                      1.0     1.0       1.0    1367.0
# Task Progress                            1.0     1.0       1.0     125.0
# Solution Usage                           1.0     1.0       1.0     368.0
# Workarounds                              1.0     1.0       1.0      81.0
# Avg/Total                                1.0     1.0       1.0    4001.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.07    0.50      0.12       2.0
# Bug Reproduction                        0.00    0.00      0.00      38.0
# Contribution and Commitment             0.00    0.00      0.00       7.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.44    0.08      0.13     104.0
# Social Conversation                     0.24    0.50      0.33      42.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.33    0.02      0.05      81.0
# Potential New Issues and Requests       0.07    0.50      0.12       2.0
# Solution Discussion                     0.14    0.34      0.20      44.0
# Task Progress                           0.00    0.00      0.00       0.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       8.0
# Avg/Total                               0.27    0.15      0.12     329.0
#
# ------------------------- FOLD 13: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      61.0
# Bug Reproduction                         1.0     1.0       1.0     245.0
# Contribution and Commitment              1.0     1.0       1.0      76.0
# Expected Behaviour                       1.0     1.0       1.0     110.0
# Investigation and Exploration            1.0     1.0       1.0     374.0
# Social Conversation                      1.0     1.0       1.0     760.0
# Motivation                               1.0     1.0       1.0     255.0
# Observed Bug Behaviour                   1.0     1.0       1.0     131.0
# Potential New Issues and Requests        1.0     1.0       1.0     205.0
# Solution Discussion                      1.0     1.0       1.0    1288.0
# Task Progress                            1.0     1.0       1.0     120.0
# Solution Usage                           1.0     1.0       1.0     366.0
# Workarounds                              1.0     1.0       1.0      89.0
# Avg/Total                                1.0     1.0       1.0    4080.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       0.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       7.0
# Expected Behaviour                      0.00    0.00      0.00      14.0
# Investigation and Exploration           0.00    0.00      0.00       3.0
# Social Conversation                     0.49    0.45      0.47      38.0
# Motivation                              0.11    0.24      0.15      33.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.26    0.32      0.29      25.0
# Solution Discussion                     0.51    0.33      0.40     123.0
# Task Progress                           0.17    0.20      0.18       5.0
# Solution Usage                          0.00    0.00      0.00       2.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.37    0.30      0.32     250.0
#
# ------------------------- FOLD 14: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                          1.0     1.0       1.0      58.0
# Bug Reproduction                         1.0     1.0       1.0     245.0
# Contribution and Commitment              1.0     1.0       1.0      78.0
# Expected Behaviour                       1.0     1.0       1.0     121.0
# Investigation and Exploration            1.0     1.0       1.0     377.0
# Social Conversation                      1.0     1.0       1.0     784.0
# Motivation                               1.0     1.0       1.0     286.0
# Observed Bug Behaviour                   1.0     1.0       1.0     131.0
# Potential New Issues and Requests        1.0     1.0       1.0     229.0
# Solution Discussion                      1.0     1.0       1.0    1346.0
# Task Progress                            1.0     1.0       1.0     111.0
# Solution Usage                           1.0     1.0       1.0     367.0
# Workarounds                              1.0     1.0       1.0      89.0
# Avg/Total                                1.0     1.0       1.0    4222.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.40    0.67      0.50       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.08    0.33      0.12       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.34    0.86      0.49      14.0
# Motivation                              0.00    0.00      0.00       2.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.92    0.37      0.53      65.0
# Task Progress                           0.60    0.21      0.32      14.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.69    0.39      0.44     108.0

# %% [markdown]
# ### Get lists of F1 scores and support-weighted average F1 score

# %%
avg_f1 = []
for i in range(0,15):
    avg_f1.append(float('%.4f' % round(clf1_results['test_avg_fscore'][i],4)))
    
print('Pipeline1:')
print(avg_f1)

avg_f1 = []
for i in range(0,15):
    avg_f1.append(float('%.4f' % round(clf2_results['test_avg_fscore'][i],4)))

print('\nPipeline2:')
print(avg_f1)
# Out:
# Pipeline1:
# [0.4687, 0.2359, 0.1745, 0.2783, 0.4808, 0.1661, 0.3022, 0.2125, 0.189, 0.3157, 0.1964, 0.5451, 0.0906, 0.3452, 0.4987]
#
# Pipeline2:
# [0.4886, 0.2043, 0.2256, 0.249, 0.3293, 0.2033, 0.2022, 0.1882, 0.236, 0.2321, 0.2049, 0.4612, 0.1229, 0.3217, 0.4392]

# %%
sum = 0
den = 0
for i in range(0,15):
    sum += clf2_results['test_avg_fscore'][i] * clf2_results['test_total_support'][i]
    den += clf2_results['test_total_support'][i]
print('Pipeline2: Total weighted F-Score: '+('%.4f' % round(sum/den,4)))

sum = 0
den = 0
for i in range(0,15):
    sum += clf3_results['test_avg_fscore'][i] * clf3_results['test_total_support'][i]
    den += clf3_results['test_total_support'][i]
print('Pipeline3: Total weighted F-Score: '+('%.4f' % round(sum/den,4)))
# Out:
# Pipeline1: Total weighted F-Score: 0.2948
# Pipeline2: Total weighted F-Score: 0.2680

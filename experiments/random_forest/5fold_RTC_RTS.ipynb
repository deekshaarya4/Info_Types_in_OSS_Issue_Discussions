# %% [markdown]
# # Nested 5-Fold Cross Validation For Random Forest On Textual Features

# %%
import numpy as np
import pandas as pd
import xlrd as xl
from pandas import ExcelWriter
from pandas import ExcelFile
import pprint
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
import re
import pickle
from operator import itemgetter
import time, datetime
from functools import partial, update_wrapper
from beautifultable import BeautifulTable
from openpyxl import load_workbook

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN 

from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as Imb_Pipeline

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate
from sklearn.metrics import precision_recall_fscore_support, classification_report, accuracy_score, make_scorer, confusion_matrix

pp = pprint.PrettyPrinter(indent=4)

## Ignore warnings
import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn
np.warnings.filterwarnings('ignore')

# %% [markdown]
# #### Use spaCy parser for word tokenization of a sentence:

# %%
import spacy
eng = spacy.load('en')
from spacy.lang.en import English
parser = English()

# %% [markdown]
# #### Define stopwords as punctuation + common contractions:

# %%
from string import punctuation
from nltk.corpus import stopwords

stop_words = list(punctuation) + ["'s","'m","n't","'re","-","'ll",'...'] #+ stopwords.words('english')

# %% [markdown]
# #### Code to lemmatize and tokenize:

# %%
def get_lemma(item):
    return WordNetLemmatizer().lemmatize(item)

def tokenize(line):
    line_tokens = []
    tokens = parser(line)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            line_tokens.append('URL')
        elif token.orth_.startswith('@'):
            line_tokens.append('SCREEN_NAME')
        elif str(token) not in stop_words:
            line_tokens.append(get_lemma(token.lower_))
    return line_tokens

# %% [markdown]
# #### Read from the pickled file:

# %%
all_data = pd.read_pickle('../../data/text_conv_data.pkl')

print("Size of corpus: "+str(len(all_data)))
# Out:
# Size of corpus: 4330

# %%
X = all_data['Text Content'].values
y = all_data['Code'].values

print("Number of unique labels: "+str(len(set(y))))

labels = list(set(y))
labels.sort()

pp.pprint(labels)
# Out:
# Number of unique labels: 13
# [   'Action on Issue',
#     'Bug Reproduction',
#     'Contribution and Commitment',
#     'Expected Behaviour',
#     'Investigation and Exploration',
#     'Social Conversation',
#     'Motivation',
#     'Observed Bug Behaviour',
#     'Potential New Issues and Requests',
#     'Solution Discussion',
#     'Task Progress',
#     'Solution Usage',
#     'Workarounds']

# %% [markdown]
# ## Nested Cross-Validation on Random Forest:

# %%
# To be used within GridSearch
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# To be used in outer CV
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# ## Define Pipelines:
#
# 1. tfidf + class_weight=balanced
# 2. tfidf + SMOTE

# %%
pipeline1 = Pipeline([
    ('vect', TfidfVectorizer(tokenizer=tokenize)),
    ('clf', RandomForestClassifier()),
])
pipeline2 = Imb_Pipeline([
    ('vect', TfidfVectorizer(tokenizer=tokenize)),
    ('smote', SMOTE()),
    ('clf', RandomForestClassifier())
])

### Hyperparameters to search:
parameters = {
    'vect__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams or trigrams
    'clf__n_estimators': (10, 50, 100),
    'clf__min_samples_split': (2, 5, 10),
}

# %%
### Define and create the scoring functions

def score_func(y_true, y_pred, score_index, i):
    return(precision_recall_fscore_support(y_true,y_pred)[score_index][i])

def avg_score(y_true, y_pred, score_index):
    return precision_recall_fscore_support(y_true,y_pred,average='weighted')[score_index]

def sum_support(y_true, y_pred):
    return len(y_true)

### Create partials for each of the metrics returned
score_funcs = {v: partial(score_func, score_index=k) for k, v in {0:'precision',1:'recall',2:'fscore',3:'support'}.items()}
prec_score = partial(score_func, score_index=0)
update_wrapper(prec_score,score_func)
rec_score = partial(score_func, score_index=1)
update_wrapper(rec_score,score_func)
f_score = partial(score_func, score_index=2)
update_wrapper(f_score,score_func)
support_score = partial(score_func, score_index=3)
update_wrapper(support_score,score_func)

### Create a callable scoring function for each of the metrics for each classification label
scorer = {}
for label_id in range(0,13):
    scorer['label'+str(label_id)+'_precision'] = make_scorer(prec_score, i=label_id)
    scorer['label'+str(label_id)+'_recall'] = make_scorer(rec_score, i=label_id)
    scorer['label'+str(label_id)+'_fscore'] = make_scorer(f_score, i=label_id)
    scorer['label'+str(label_id)+'_support'] = make_scorer(support_score, i=label_id)

### Create a callable scoring function for avg/total of the metrics across classification labels
scorer['avg_precision'] = make_scorer(avg_score,score_index=0)
scorer['avg_recall'] = make_scorer(avg_score,score_index=1)
scorer['avg_fscore'] = make_scorer(avg_score,score_index=2)
scorer['total_support'] = make_scorer(sum_support)

### Perform Nested cross-validation on Pipeline1
start = time.time()
clf1 = GridSearchCV(pipeline1, parameters, cv=inner_cv, scoring='f1_weighted')
clf1_results = cross_validate(clf1, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline1 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))

### Perform Nested cross-validation on Pipeline2
start = time.time()
clf2 = GridSearchCV(pipeline2, parameters, cv=inner_cv, scoring='f1_weighted')
clf2_results = cross_validate(clf2, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline2 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))
# Out:
# Completed Pipeline1 scenario in 0:45:22.040127
# Completed Pipeline2 scenario in 1:36:36.051158

# %% [markdown]
# # Display and Save Training and Testing Results for each Fold:

# %% [markdown]
# ## Pipeline1 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../results/5FOLD.xlsx')
book = load_workbook('../results/5FOLD.xlsx')
writer = pd.ExcelWriter('../results/5FOLD.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,5):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf1_results['train_label'+str(label_id)+'_precision'][i],clf1_results['train_label'+str(label_id)+'_recall'][i],clf1_results['train_label'+str(label_id)+'_fscore'][i],clf1_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf1_results['test_label'+str(label_id)+'_precision'][i],clf1_results['test_label'+str(label_id)+'_recall'][i],clf1_results['test_label'+str(label_id)+'_fscore'][i],clf1_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf1_results['train_avg_precision'][i],clf1_results['train_avg_recall'][i],clf1_results['train_avg_fscore'][i],clf1_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf1_results['test_avg_precision'][i],clf1_results['test_avg_recall'][i],clf1_results['test_avg_fscore'][i],clf1_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'RTC',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'RTC',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'RTC',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['RTC_train_'+str(i)] = train_report
    result_dict['RTC_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.98    0.88      0.92      48.0
# Bug Reproduction                        0.96    0.88      0.92     196.0
# Contribution and Commitment             1.00    0.71      0.83      66.0
# Expected Behaviour                      1.00    0.84      0.91      99.0
# Investigation and Exploration           0.97    0.89      0.93     301.0
# Social Conversation                     0.95    0.97      0.96     638.0
# Motivation                              0.99    0.82      0.90     230.0
# Observed Bug Behaviour                  0.98    0.87      0.92     104.0
# Potential New Issues and Requests       0.99    0.80      0.89     184.0
# Solution Discussion                     0.82    0.99      0.90    1128.0
# Task Progress                           1.00    0.76      0.86     100.0
# Solution Usage                          0.98    0.86      0.92     294.0
# Workarounds                             1.00    0.76      0.86      71.0
# Avg/Total                               0.92    0.91      0.91    3459.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.83    0.38      0.53      13.0
# Bug Reproduction                        0.48    0.22      0.31      49.0
# Contribution and Commitment             0.00    0.00      0.00      17.0
# Expected Behaviour                      0.00    0.00      0.00      25.0
# Investigation and Exploration           0.33    0.12      0.17      76.0
# Social Conversation                     0.63    0.62      0.62     160.0
# Motivation                              0.30    0.05      0.09      58.0
# Observed Bug Behaviour                  0.25    0.04      0.06      27.0
# Potential New Issues and Requests       0.14    0.02      0.04      46.0
# Solution Discussion                     0.39    0.85      0.54     283.0
# Task Progress                           0.00    0.00      0.00      25.0
# Solution Usage                          0.33    0.09      0.15      74.0
# Workarounds                             1.00    0.06      0.11      18.0
# Avg/Total                               0.40    0.43      0.35     871.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.88      0.93      49.0
# Bug Reproduction                        0.97    0.88      0.93     196.0
# Contribution and Commitment             1.00    0.82      0.90      66.0
# Expected Behaviour                      0.99    0.84      0.91      99.0
# Investigation and Exploration           0.99    0.86      0.92     301.0
# Social Conversation                     0.94    0.98      0.96     638.0
# Motivation                              0.99    0.87      0.92     230.0
# Observed Bug Behaviour                  0.99    0.87      0.92     105.0
# Potential New Issues and Requests       1.00    0.80      0.89     184.0
# Solution Discussion                     0.84    0.99      0.91    1129.0
# Task Progress                           1.00    0.80      0.89     100.0
# Solution Usage                          0.98    0.85      0.91     294.0
# Workarounds                             1.00    0.93      0.96      71.0
# Avg/Total                               0.93    0.92      0.92    3462.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.33      0.50      12.0
# Bug Reproduction                        0.47    0.18      0.26      49.0
# Contribution and Commitment             0.00    0.00      0.00      17.0
# Expected Behaviour                      0.67    0.08      0.14      25.0
# Investigation and Exploration           0.50    0.09      0.16      76.0
# Social Conversation                     0.58    0.74      0.65     160.0
# Motivation                              0.40    0.03      0.06      58.0
# Observed Bug Behaviour                  0.75    0.12      0.20      26.0
# Potential New Issues and Requests       0.00    0.00      0.00      46.0
# Solution Discussion                     0.41    0.86      0.55     282.0
# Task Progress                           0.50    0.04      0.07      25.0
# Solution Usage                          0.56    0.12      0.20      74.0
# Workarounds                             0.00    0.00      0.00      18.0
# Avg/Total                               0.45    0.46      0.37     868.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.96      0.98      49.0
# Bug Reproduction                        0.97    0.93      0.95     196.0
# Contribution and Commitment             1.00    0.92      0.96      66.0
# Expected Behaviour                      1.00    0.92      0.96      99.0
# Investigation and Exploration           0.97    0.89      0.93     302.0
# Social Conversation                     0.97    0.97      0.97     638.0
# Motivation                              1.00    0.94      0.97     230.0
# Observed Bug Behaviour                  0.99    0.85      0.91     105.0
# Potential New Issues and Requests       1.00    0.91      0.95     184.0
# Solution Discussion                     0.89    1.00      0.94    1129.0
# Task Progress                           1.00    0.94      0.97     100.0
# Solution Usage                          1.00    0.91      0.95     294.0
# Workarounds                             1.00    0.87      0.93      71.0
# Avg/Total                               0.96    0.95      0.95    3463.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.75    0.25      0.38      12.0
# Bug Reproduction                        0.71    0.20      0.32      49.0
# Contribution and Commitment             1.00    0.06      0.11      17.0
# Expected Behaviour                      0.00    0.00      0.00      25.0
# Investigation and Exploration           0.32    0.11      0.16      75.0
# Social Conversation                     0.60    0.70      0.65     160.0
# Motivation                              0.45    0.09      0.14      58.0
# Observed Bug Behaviour                  0.33    0.08      0.12      26.0
# Potential New Issues and Requests       0.00    0.00      0.00      46.0
# Solution Discussion                     0.43    0.88      0.58     282.0
# Task Progress                           0.50    0.04      0.07      25.0
# Solution Usage                          0.45    0.19      0.27      74.0
# Workarounds                             0.00    0.00      0.00      18.0
# Avg/Total                               0.44    0.47      0.38     867.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.98      0.99      49.0
# Bug Reproduction                        0.98    0.91      0.94     196.0
# Contribution and Commitment             1.00    0.90      0.94      67.0
# Expected Behaviour                      1.00    0.87      0.93      99.0
# Investigation and Exploration           0.99    0.93      0.96     302.0
# Social Conversation                     0.95    0.98      0.97     639.0
# Motivation                              1.00    0.90      0.95     231.0
# Observed Bug Behaviour                  0.98    0.89      0.93     105.0
# Potential New Issues and Requests       1.00    0.92      0.96     184.0
# Solution Discussion                     0.89    0.99      0.94    1129.0
# Task Progress                           1.00    0.91      0.95     100.0
# Solution Usage                          1.00    0.91      0.95     295.0
# Workarounds                             1.00    0.87      0.93      71.0
# Avg/Total                               0.95    0.95      0.95    3467.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.75    0.25      0.38      12.0
# Bug Reproduction                        0.59    0.27      0.37      49.0
# Contribution and Commitment             0.50    0.06      0.11      16.0
# Expected Behaviour                      0.00    0.00      0.00      25.0
# Investigation and Exploration           0.50    0.19      0.27      75.0
# Social Conversation                     0.52    0.77      0.62     159.0
# Motivation                              0.29    0.04      0.06      57.0
# Observed Bug Behaviour                  0.33    0.04      0.07      26.0
# Potential New Issues and Requests       0.17    0.02      0.04      46.0
# Solution Discussion                     0.40    0.75      0.52     282.0
# Task Progress                           1.00    0.04      0.08      25.0
# Solution Usage                          0.38    0.14      0.20      73.0
# Workarounds                             0.00    0.00      0.00      18.0
# Avg/Total                               0.42    0.44      0.36     863.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.98    0.88      0.92      49.0
# Bug Reproduction                        0.98    0.86      0.92     196.0
# Contribution and Commitment             1.00    0.84      0.91      67.0
# Expected Behaviour                      1.00    0.81      0.90     100.0
# Investigation and Exploration           0.98    0.83      0.90     302.0
# Social Conversation                     0.95    0.98      0.96     639.0
# Motivation                              0.98    0.80      0.88     231.0
# Observed Bug Behaviour                  1.00    0.86      0.92     105.0
# Potential New Issues and Requests       0.99    0.86      0.92     184.0
# Solution Discussion                     0.82    0.99      0.90    1129.0
# Task Progress                           1.00    0.77      0.87     100.0
# Solution Usage                          1.00    0.85      0.92     295.0
# Workarounds                             0.98    0.79      0.88      72.0
# Avg/Total                               0.93    0.91      0.91    3469.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.17      0.29      12.0
# Bug Reproduction                        0.37    0.14      0.21      49.0
# Contribution and Commitment             0.67    0.12      0.21      16.0
# Expected Behaviour                      0.00    0.00      0.00      24.0
# Investigation and Exploration           0.46    0.08      0.14      75.0
# Social Conversation                     0.56    0.69      0.62     159.0
# Motivation                              0.17    0.02      0.03      57.0
# Observed Bug Behaviour                  0.20    0.04      0.06      26.0
# Potential New Issues and Requests       0.14    0.02      0.04      46.0
# Solution Discussion                     0.41    0.84      0.55     282.0
# Task Progress                           0.00    0.00      0.00      25.0
# Solution Usage                          0.36    0.11      0.17      73.0
# Workarounds                             1.00    0.06      0.11      17.0
# Avg/Total                               0.40    0.44      0.35     861.0

# %% [markdown]
# ## Pipeline2 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../results/5FOLD.xlsx')
book = load_workbook('../results/5FOLD.xlsx')
writer = pd.ExcelWriter('../results/5FOLD.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,5):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf2_results['train_label'+str(label_id)+'_precision'][i],clf2_results['train_label'+str(label_id)+'_recall'][i],clf2_results['train_label'+str(label_id)+'_fscore'][i],clf2_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf2_results['test_label'+str(label_id)+'_precision'][i],clf2_results['test_label'+str(label_id)+'_recall'][i],clf2_results['test_label'+str(label_id)+'_fscore'][i],clf2_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf2_results['train_avg_precision'][i],clf2_results['train_avg_recall'][i],clf2_results['train_avg_fscore'][i],clf2_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf2_results['test_avg_precision'][i],clf2_results['test_avg_recall'][i],clf2_results['test_avg_fscore'][i],clf2_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'RTS',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'RTS',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'RTS',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['RTS_train_'+str(i)] = train_report
    result_dict['RTS_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.98      0.99      48.0
# Bug Reproduction                        0.99    0.97      0.98     196.0
# Contribution and Commitment             1.00    1.00      1.00      66.0
# Expected Behaviour                      0.99    0.99      0.99      99.0
# Investigation and Exploration           1.00    0.97      0.98     301.0
# Social Conversation                     0.99    0.99      0.99     638.0
# Motivation                              1.00    1.00      1.00     230.0
# Observed Bug Behaviour                  0.74    0.99      0.85     104.0
# Potential New Issues and Requests       1.00    0.98      0.99     184.0
# Solution Discussion                     1.00    0.98      0.99    1128.0
# Task Progress                           0.87    0.99      0.93     100.0
# Solution Usage                          1.00    0.97      0.98     294.0
# Workarounds                             0.97    0.97      0.97      71.0
# Avg/Total                               0.99    0.98      0.98    3459.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.58    0.54      0.56      13.0
# Bug Reproduction                        0.45    0.31      0.37      49.0
# Contribution and Commitment             0.60    0.35      0.44      17.0
# Expected Behaviour                      0.50    0.08      0.14      25.0
# Investigation and Exploration           0.45    0.18      0.26      76.0
# Social Conversation                     0.59    0.66      0.62     160.0
# Motivation                              0.33    0.12      0.18      58.0
# Observed Bug Behaviour                  0.19    0.19      0.19      27.0
# Potential New Issues and Requests       0.30    0.07      0.11      46.0
# Solution Discussion                     0.43    0.73      0.54     283.0
# Task Progress                           0.29    0.16      0.21      25.0
# Solution Usage                          0.48    0.30      0.37      74.0
# Workarounds                             0.33    0.06      0.10      18.0
# Avg/Total                               0.45    0.46      0.42     871.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.99    0.96      0.97     196.0
# Contribution and Commitment             1.00    1.00      1.00      66.0
# Expected Behaviour                      0.99    0.98      0.98      99.0
# Investigation and Exploration           0.89    0.99      0.94     301.0
# Social Conversation                     0.99    1.00      0.99     638.0
# Motivation                              1.00    1.00      1.00     230.0
# Observed Bug Behaviour                  0.98    0.96      0.97     105.0
# Potential New Issues and Requests       1.00    0.97      0.99     184.0
# Solution Discussion                     1.00    0.97      0.99    1129.0
# Task Progress                           0.86    0.99      0.92     100.0
# Solution Usage                          1.00    0.96      0.98     294.0
# Workarounds                             1.00    0.97      0.99      71.0
# Avg/Total                               0.98    0.98      0.98    3462.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.67    0.50      0.57      12.0
# Bug Reproduction                        0.39    0.29      0.33      49.0
# Contribution and Commitment             0.75    0.18      0.29      17.0
# Expected Behaviour                      0.44    0.16      0.24      25.0
# Investigation and Exploration           0.35    0.22      0.27      76.0
# Social Conversation                     0.58    0.76      0.66     160.0
# Motivation                              0.40    0.14      0.21      58.0
# Observed Bug Behaviour                  0.35    0.27      0.30      26.0
# Potential New Issues and Requests       0.20    0.04      0.07      46.0
# Solution Discussion                     0.45    0.69      0.55     282.0
# Task Progress                           0.31    0.20      0.24      25.0
# Solution Usage                          0.53    0.36      0.43      74.0
# Workarounds                             0.29    0.11      0.16      18.0
# Avg/Total                               0.45    0.47      0.44     868.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.98      0.99      49.0
# Bug Reproduction                        0.98    0.95      0.97     196.0
# Contribution and Commitment             1.00    1.00      1.00      66.0
# Expected Behaviour                      0.98    0.99      0.98      99.0
# Investigation and Exploration           0.99    0.96      0.98     302.0
# Social Conversation                     0.99    0.99      0.99     638.0
# Motivation                              1.00    1.00      1.00     230.0
# Observed Bug Behaviour                  0.97    0.94      0.96     105.0
# Potential New Issues and Requests       1.00    0.98      0.99     184.0
# Solution Discussion                     0.99    0.98      0.99    1129.0
# Task Progress                           0.99    0.98      0.98     100.0
# Solution Usage                          0.89    0.99      0.94     294.0
# Workarounds                             0.99    0.99      0.99      71.0
# Avg/Total                               0.98    0.98      0.98    3463.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.83    0.42      0.56      12.0
# Bug Reproduction                        0.50    0.41      0.45      49.0
# Contribution and Commitment             0.71    0.29      0.42      17.0
# Expected Behaviour                      0.00    0.00      0.00      25.0
# Investigation and Exploration           0.43    0.24      0.31      75.0
# Social Conversation                     0.63    0.74      0.68     160.0
# Motivation                              0.29    0.12      0.17      58.0
# Observed Bug Behaviour                  0.57    0.15      0.24      26.0
# Potential New Issues and Requests       0.17    0.02      0.04      46.0
# Solution Discussion                     0.45    0.74      0.56     282.0
# Task Progress                           0.43    0.12      0.19      25.0
# Solution Usage                          0.42    0.35      0.38      74.0
# Workarounds                             0.80    0.22      0.35      18.0
# Avg/Total                               0.46    0.49      0.44     867.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.99    0.96      0.98     196.0
# Contribution and Commitment             1.00    1.00      1.00      67.0
# Expected Behaviour                      1.00    0.98      0.99      99.0
# Investigation and Exploration           0.99    0.98      0.98     302.0
# Social Conversation                     0.99    1.00      0.99     639.0
# Motivation                              1.00    0.99      1.00     231.0
# Observed Bug Behaviour                  0.70    0.98      0.82     105.0
# Potential New Issues and Requests       1.00    0.97      0.99     184.0
# Solution Discussion                     0.99    0.98      0.99    1129.0
# Task Progress                           1.00    0.98      0.99     100.0
# Solution Usage                          1.00    0.96      0.98     295.0
# Workarounds                             1.00    0.97      0.99      71.0
# Avg/Total                               0.99    0.98      0.98    3467.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.86    0.50      0.63      12.0
# Bug Reproduction                        0.48    0.47      0.47      49.0
# Contribution and Commitment             0.50    0.19      0.27      16.0
# Expected Behaviour                      0.22    0.08      0.12      25.0
# Investigation and Exploration           0.38    0.24      0.29      75.0
# Social Conversation                     0.60    0.81      0.69     159.0
# Motivation                              0.33    0.18      0.23      57.0
# Observed Bug Behaviour                  0.24    0.15      0.19      26.0
# Potential New Issues and Requests       0.30    0.07      0.11      46.0
# Solution Discussion                     0.49    0.72      0.58     282.0
# Task Progress                           0.43    0.12      0.19      25.0
# Solution Usage                          0.51    0.34      0.41      73.0
# Workarounds                             0.00    0.00      0.00      18.0
# Avg/Total                               0.46    0.49      0.45     863.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      49.0
# Bug Reproduction                        0.99    0.97      0.98     196.0
# Contribution and Commitment             1.00    1.00      1.00      67.0
# Expected Behaviour                      1.00    0.98      0.99     100.0
# Investigation and Exploration           0.90    0.99      0.94     302.0
# Social Conversation                     0.99    1.00      0.99     639.0
# Motivation                              1.00    0.99      0.99     231.0
# Observed Bug Behaviour                  0.99    0.97      0.98     105.0
# Potential New Issues and Requests       1.00    0.99      1.00     184.0
# Solution Discussion                     1.00    0.97      0.98    1129.0
# Task Progress                           0.85    1.00      0.92     100.0
# Solution Usage                          1.00    0.97      0.98     295.0
# Workarounds                             0.99    0.99      0.99      72.0
# Avg/Total                               0.98    0.98      0.98    3469.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.42      0.59      12.0
# Bug Reproduction                        0.47    0.57      0.52      49.0
# Contribution and Commitment             0.45    0.31      0.37      16.0
# Expected Behaviour                      0.00    0.00      0.00      24.0
# Investigation and Exploration           0.40    0.21      0.28      75.0
# Social Conversation                     0.59    0.76      0.67     159.0
# Motivation                              0.22    0.12      0.16      57.0
# Observed Bug Behaviour                  0.24    0.15      0.19      26.0
# Potential New Issues and Requests       0.45    0.11      0.18      46.0
# Solution Discussion                     0.48    0.68      0.56     282.0
# Task Progress                           0.38    0.20      0.26      25.0
# Solution Usage                          0.40    0.32      0.35      73.0
# Workarounds                             0.40    0.12      0.18      17.0
# Avg/Total                               0.45    0.48      0.44     861.0

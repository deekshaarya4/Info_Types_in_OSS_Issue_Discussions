# %% [markdown]
# # Nested Leave-One-Issue-Out Cross Validation For Random Forest On Both Textual+Contextual Features using class_weight=balanced

# %%
import numpy as np
import pandas as pd
import xlrd as xl
from pandas import ExcelWriter
from pandas import ExcelFile
import pprint
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
import re
import pickle
from operator import itemgetter
import time, datetime
from functools import partial, update_wrapper
from openpyxl import load_workbook
from copy import deepcopy

from sklearn.externals.joblib import Parallel, delayed
from sklearn.pipeline import FeatureUnion, _fit_transform_one, _transform_one
from scipy import sparse

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from imblearn.over_sampling import SMOTE

from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from imblearn.pipeline import Pipeline as Imb_Pipeline

from sklearn_pandas import DataFrameMapper, gen_features
from sklearn.preprocessing import FunctionTransformer

from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate, LeaveOneGroupOut
from sklearn.metrics import precision_recall_fscore_support, classification_report, accuracy_score, make_scorer, confusion_matrix

pp = pprint.PrettyPrinter(indent=4)

## Ignore warnings
import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn
np.warnings.filterwarnings('ignore')

# %% [markdown]
# #### Use spaCy parser for word tokenization of a sentence:

# %%
import spacy
eng = spacy.load('en')
from spacy.lang.en import English
parser = English()

# %% [markdown]
# #### Define stopwords as punctuation + common contractions:

# %%
from string import punctuation
from nltk.corpus import stopwords

stop_words = list(punctuation) + ["'s","'m","n't","'re","-","'ll",'...'] #+ stopwords.words('english')

# %% [markdown]
# #### Code to lemmatize and tokenize:

# %%
def get_lemma(item):
    return WordNetLemmatizer().lemmatize(item)

def tokenize(line):
    line_tokens = []
    tokens = parser(line)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            line_tokens.append('URL')
        elif token.orth_.startswith('@'):
            line_tokens.append('SCREEN_NAME')
        elif str(token) not in stop_words:
            line_tokens.append(get_lemma(token.lower_))
    return line_tokens

# %% [markdown]
# #### Read from the pickled file:

# %%
all_data = pd.read_pickle('../../data/text_conv_data.pkl')

print("Size of corpus: "+str(len(all_data)))
print("Feature Size: "+str(len(list(all_data.columns.values))-1))
# Out:
# Size of corpus: 4330
# Feature Size: 23

# %%
X = all_data.drop(['Code','Document'], axis=1)
y = all_data[['Code']]
doc_groups = all_data['Document'].values

print("Number of unique labels: "+str(len(set(y['Code']))))

labels = list(set(y['Code']))
labels.sort()

pp.pprint(labels)
# Out:
# Number of unique labels: 13
# [   'Action on Issue',
#     'Bug Reproduction',
#     'Contribution and Commitment',
#     'Expected Behaviour',
#     'Investigation and Exploration',
#     'Social Conversation',
#     'Motivation',
#     'Observed Bug Behaviour',
#     'Potential New Issues and Requests',
#     'Solution Discussion',
#     'Task Progress',
#     'Solution Usage',
#     'Workarounds'])

# %% [markdown]
# # Nested Cross-Validation on Random Forest:

# %%
# To be used within GridSearch
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# To be used in outer CV
logo = LeaveOneGroupOut()
outer_cv = logo.split(X,y,groups=doc_groups)

non_transform_features = [col for col in X.columns.values if col not in ['Text Content']]

# %% [markdown]
# ## Define pandas-compatible feature unificator
#
# This is just a pandas compatible feature unificator.
#
# This is necessary because we have two types of features: textual + conversational
#
# Hence, we first use tf-idf to vectorize the textual content and then append the conversational features to this vector using the feature unificator.

# %%
class PandasFeatureUnion(FeatureUnion):
    def fit_transform(self, X, y=None, **fit_params):
        self._validate_transformers()
        result = Parallel(n_jobs=self.n_jobs)(
            delayed(_fit_transform_one)(trans, weight, X, y,
                                        **fit_params)
            for name, trans, weight in self._iter())
        if not result:
            return np.zeros((X.shape[0], 0))
        Xs, transformers = zip(*result)
        self._update_transformer_list(transformers)
        if any(sparse.issparse(f) for f in Xs):
            Xs = sparse.hstack(Xs).tocsr()
        else:
            Xs = self.merge_dataframes_by_column(Xs)
        return Xs

    def merge_dataframes_by_column(self, Xs):
        return pd.concat(Xs, axis="columns", copy=False)

    def transform(self, X):
        Xs = Parallel(n_jobs=self.n_jobs)(
            delayed(_transform_one)(trans, weight, X)
            for name, trans, weight in self._iter())
        if not Xs:
            return np.zeros((X.shape[0], 0))
        if any(sparse.issparse(f) for f in Xs):
            Xs = sparse.hstack(Xs).tocsr()
        else:
            Xs = self.merge_dataframes_by_column(Xs)
        return Xs

# %%
class PandasTransform(TransformerMixin, BaseEstimator):
    def __init__(self, columns):
        self.columns = columns
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None, copy=None):
        return X.loc[:, self.columns].astype(float)

# %% [markdown]
# ### Define Pipelines
#
# 1. Pipeline1: tfidf + class_weight=balanced

# %%
class ItemSelector(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
    def fit(self, x, y=None):
        print(self)
        return self
    def transform(self, data_array):
        print(len(data_array[:, self.columns]))
        return data_array[:, self.columns]

### Simply select the conversational features, and tfidf-vectorize the textual content
ling_features = PandasTransform(non_transform_features)
tfidf_text_features = Pipeline([('extract_field',FunctionTransformer(lambda x: x['Text Content'],validate=False)),('vect',TfidfVectorizer(tokenizer=tokenize))])

### Combine the two types of feature vectors
feature_union1 = PandasFeatureUnion([
    ('selector',ling_features),
    ('text_vectorizer',tfidf_text_features)
])

pipeline1 = Pipeline([
    ('features',feature_union1),
    ('clf', RandomForestClassifier(class_weight='balanced')),
])

### Hyperparameters to search
parameters = {
    'features__text_vectorizer__vect__ngram_range': ((1,1),(1,2)),  # unigrams or bigrams or trigrams
    'clf__n_estimators': (10, 50, 100),
    'clf__min_samples_split': (2, 5, 10),
}

# %% [markdown]
# ## Nested Cross Validation Using GridSearch

# %%
### Define and create the scoring functions

def score_func(y_true, y_pred, score_index, i):
    return(precision_recall_fscore_support(y_true,y_pred,labels=labels)[score_index][i])

def avg_score(y_true, y_pred, score_index):
    return precision_recall_fscore_support(y_true,y_pred,average='weighted')[score_index]

def sum_support(y_true, y_pred):
    return len(y_true)

### Create partials for each of the metrics returned
score_funcs = {v: partial(score_func, score_index=k) for k, v in {0:'precision',1:'recall',2:'fscore',3:'support'}.items()}
prec_score = partial(score_func, score_index=0)
update_wrapper(prec_score,score_func)
rec_score = partial(score_func, score_index=1)
update_wrapper(rec_score,score_func)
f_score = partial(score_func, score_index=2)
update_wrapper(f_score,score_func)
support_score = partial(score_func, score_index=3)
update_wrapper(support_score,score_func)

### Create a callable scoring function for each of the metrics for each classification label
scorer = {}
for label_id in range(0,13):
    scorer['label'+str(label_id)+'_precision'] = make_scorer(prec_score, i=label_id)
    scorer['label'+str(label_id)+'_recall'] = make_scorer(rec_score, i=label_id)
    scorer['label'+str(label_id)+'_fscore'] = make_scorer(f_score, i=label_id)
    scorer['label'+str(label_id)+'_support'] = make_scorer(support_score, i=label_id)

### Create a callable scoring function for avg/total of the metrics across classification labels
scorer['avg_precision'] = make_scorer(avg_score,score_index=0)
scorer['avg_recall'] = make_scorer(avg_score,score_index=1)
scorer['avg_fscore'] = make_scorer(avg_score,score_index=2)
scorer['total_support'] = make_scorer(sum_support)

### Perform Nested cross-validation on Pipeline1

clf1 = GridSearchCV(pipeline1, parameters, cv=inner_cv, scoring='f1_weighted')

start = time.time()
clf1_results = cross_validate(clf1, X=X, y=y, cv=outer_cv, scoring=scorer)
print("Completed Pipeline1 scenario in "+ str(datetime.timedelta(seconds=(time.time()-start))))
# Out:
# Completed Pipeline1 scenario in 17:33:32.202196

# %% [markdown]
# # Display and Save Training and Testing Results for each Fold:

# %% [markdown]
# ## Pipeline1 Results:

# %%
train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

result_dict = {}

# writer = pd.ExcelWriter('../../results/LOIO.xlsx')
book = load_workbook('../../results/LOIO.xlsx')
writer = pd.ExcelWriter('../../results/LOIO.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

datalength = 0

for i in range(0,15):
    for label_id in range(0,13):
        train_report.loc[labels[label_id], :] = [clf1_results['train_label'+str(label_id)+'_precision'][i],clf1_results['train_label'+str(label_id)+'_recall'][i],clf1_results['train_label'+str(label_id)+'_fscore'][i],clf1_results['train_label'+str(label_id)+'_support'][i]]
        test_report.loc[labels[label_id], :] = [clf1_results['test_label'+str(label_id)+'_precision'][i],clf1_results['test_label'+str(label_id)+'_recall'][i],clf1_results['test_label'+str(label_id)+'_fscore'][i],clf1_results['test_label'+str(label_id)+'_support'][i]]

    train_report.loc['Avg/Total', :] = [clf1_results['train_avg_precision'][i],clf1_results['train_avg_recall'][i],clf1_results['train_avg_fscore'][i],clf1_results['train_total_support'][i]]
    test_report.loc['Avg/Total', :] = [clf1_results['test_avg_precision'][i],clf1_results['test_avg_recall'][i],clf1_results['test_avg_fscore'][i],clf1_results['test_total_support'][i]]

    fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
    fold_index.to_excel(writer,'RBC',startrow=datalength, index=False)
    datalength+=(len(fold_index)+2)
    train_report.to_excel(writer,'RBC',startrow=datalength)
    datalength+=(len(train_report)+2)
    test_report.to_excel(writer,'RBC',startrow=datalength)
    datalength+=(len(test_report)+2)

    result_dict['RBC_train_'+str(i)] = train_report
    result_dict['RBC_test_'+str(i)] = test_report

    train_report = train_report.astype(float).round(2)
    test_report = test_report.astype(float).round(2)

    print("\n------------------------- FOLD "+str(i)+": -------------------------")
    print("\nTraining Results:")
    print(train_report)
    print("\nTest Results:")
    print(test_report)

writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.96    1.00      0.98      53.0
# Bug Reproduction                        0.98    0.99      0.99     245.0
# Contribution and Commitment             1.00    1.00      1.00      58.0
# Expected Behaviour                      1.00    1.00      1.00     119.0
# Investigation and Exploration           0.99    0.99      0.99     377.0
# Social Conversation                     0.97    1.00      0.99     546.0
# Motivation                              0.98    1.00      0.99     261.0
# Observed Bug Behaviour                  0.94    1.00      0.97     131.0
# Potential New Issues and Requests       1.00    1.00      1.00     208.0
# Solution Discussion                     1.00    0.97      0.98    1338.0
# Task Progress                           0.99    0.99      0.99     104.0
# Solution Usage                          0.98    1.00      0.99     368.0
# Workarounds                             0.99    1.00      0.99      86.0
# Avg/Total                               0.99    0.99      0.99    3894.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       8.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00      25.0
# Expected Behaviour                      0.00    0.00      0.00       5.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.88    0.85      0.86     252.0
# Motivation                              0.00    0.00      0.00      27.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      22.0
# Solution Discussion                     0.35    0.66      0.45      73.0
# Task Progress                           0.67    0.10      0.17      21.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.60    0.61      0.58     436.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      60.0
# Bug Reproduction                        0.98    0.99      0.99     245.0
# Contribution and Commitment             1.00    1.00      1.00      80.0
# Expected Behaviour                      0.95    1.00      0.98      42.0
# Investigation and Exploration           0.99    0.99      0.99     377.0
# Social Conversation                     0.99    1.00      0.99     716.0
# Motivation                              0.99    1.00      0.99     134.0
# Observed Bug Behaviour                  0.94    1.00      0.97     131.0
# Potential New Issues and Requests       1.00    1.00      1.00     217.0
# Solution Discussion                     1.00    0.97      0.99    1231.0
# Task Progress                           0.97    1.00      0.99     113.0
# Solution Usage                          0.96    1.00      0.98     272.0
# Workarounds                             0.99    1.00      0.99      66.0
# Avg/Total                               0.99    0.99      0.99    3684.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.25    0.33      0.29       3.0
# Expected Behaviour                      0.00    0.00      0.00      82.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.56    0.57      0.57      82.0
# Motivation                              0.54    0.05      0.08     154.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00
0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.75    0.38      0.50       8.0
# Bug Reproduction                        0.00    0.00      0.00       1.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       1.0
# Social Conversation                     0.39    0.66      0.49      41.0
# Motivation                              0.00    0.00      0.00      16.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.85    0.67      0.75     197.0
# Task Progress                           0.50    0.12      0.20       8.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       2.0
# Avg/Total                               0.69    0.58      0.62     279.0
#
# ------------------------- FOLD 5: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.98    1.00      0.99      55.0
# Bug Reproduction                        0.99    1.00      0.99     160.0
# Contribution and Commitment             1.00    1.00      1.00      78.0
# Expected Behaviour                      0.99    1.00      1.00     124.0
# Investigation and Exploration           1.00    0.99      0.99     266.0
# Social Conversation                     0.99    0.99      0.99     759.0
# Motivation                              0.98    1.00      0.99     287.0
# Observed Bug Behaviour                  0.98    1.00      0.99     125.0
# Potential New Issues and Requests       0.99    1.00      1.00     230.0
# Solution Discussion                     1.00    0.98      0.99    1349.0
# Task Progress                           0.98    1.00      0.99     122.0
# Solution Usage                          0.98    1.00      0.99     368.0
# Workarounds                             0.99    1.00      0.99      89.0
# Avg/Total                               0.99    0.99      0.99    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.33    0.17      0.22       6.0
# Bug Reproduction                        0.81    0.26      0.39      85.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00     111.0
# Social Conversation                     0.48    0.74      0.58      39.0
# Motivation                              0.00    0.00      0.00       1.0
# Observed Bug Behaviour                  0.83    0.83      0.83       6.0
# Potential New Issues and Requests       0.00    0.00      0.00       0.0
# Solution Discussion                     0.26    0.77      0.39      62.0
# Task Progress                           0.67    0.67      0.67       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.36    0.34      0.28     318.0
#
# ------------------------- FOLD 6: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      59.0
# Bug Reproduction                        0.99    0.99      0.99     204.0
# Contribution and Commitment             1.00    1.00      1.00      80.0
# Expected Behaviour                      0.99    1.00      1.00     124.0
# Investigation and Exploration           0.99    0.99      0.99     365.0
# Social Conversation                     0.99    1.00      0.99     760.0
# Motivation                              0.98    1.00      0.99     278.0
# Observed Bug Behaviour                  0.97    1.00      0.98     127.0
# Potential New Issues and Requests       1.00    1.00      1.00     228.0
# Solution Discussion                     1.00    0.97      0.99    1219.0
# Task Progress                           0.98    1.00      0.99     120.0
# Solution Usage                          0.98    1.00      0.99     368.0
# Workarounds                             1.00    1.00      1.00      80.0
# Avg/Total                               0.99    0.99      0.99    4012.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    0.50      0.67       2.0
# Bug Reproduction                        0.45    0.22      0.30      41.0
# Contribution and Commitment             0.00    0.00      0.00       3.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      12.0
# Social Conversation                     0.31    0.76      0.44      38.0
# Motivation                              0.00    0.00      0.00      10.0
# Observed Bug Behaviour                  0.29    1.00      0.44       4.0
# Potential New Issues and Requests       0.00    0.00      0.00       2.0
# Solution Discussion                     0.76    0.45      0.56     192.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       9.0
# Avg/Total                               0.56    0.41      0.44     318.0
#
# ------------------------- FOLD 7: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      52.0
# Bug Reproduction                        0.98    1.00      0.99     245.0
# Contribution and Commitment             1.00    1.00      1.00      78.0
# Expected Behaviour                
0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.80    0.80      0.80       5.0
# Bug Reproduction                        0.43    0.43      0.43       7.0
# Contribution and Commitment             0.00    0.00      0.00       0.0
# Expected Behaviour                      0.00    0.00      0.00       0.0
# Investigation and Exploration           0.00    0.00      0.00      24.0
# Social Conversation                     0.80    0.40      0.53      10.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.75    0.75      0.75       8.0
# Potential New Issues and Requests       0.00    0.00      0.00      28.0
# Solution Discussion                     0.00    0.00      0.00       0.0
# Task Progress                           0.00    0.00      0.00       3.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       1.0
# Avg/Total                               0.24    0.20      0.21      86.0
#
# ------------------------- FOLD 11: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      60.0
# Bug Reproduction                        0.98    0.99      0.99     245.0
# Contribution and Commitment             1.00    1.00      1.00      81.0
# Expected Behaviour                      1.00    1.00      1.00     118.0
# Investigation and Exploration           1.00    0.99      0.99     377.0
# Social Conversation                     0.98    0.99      0.99     755.0
# Motivation                              0.97    1.00      0.99     268.0
# Observed Bug Behaviour                  0.96    1.00      0.98     131.0
# Potential New Issues and Requests       0.99    1.00      1.00     225.0
# Solution Discussion                     1.00    0.97      0.99    1224.0
# Task Progress                           0.98    1.00      0.99     121.0
# Solution Usage                          0.98    1.00      0.99     368.0
# Workarounds                             0.99    1.00      0.99      86.0
# Avg/Total                               0.99    0.99      0.99    4059.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       1.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       2.0
# Expected Behaviour                      0.00    0.00      0.00       6.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.64    0.42      0.51      43.0
# Motivation                              0.20    0.10      0.13      20.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       5.0
# Solution Discussion                     0.74    0.70      0.72     187.0
# Task Progress                           1.00    0.25      0.40       4.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       3.0
# Avg/Total                               0.65    0.56      0.59     271.0
#
# ------------------------- FOLD 12: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      59.0
# Bug Reproduction                        0.98    0.99      0.98     207.0
# Contribution and Commitment             1.00    1.00      1.00      76.0
# Expected Behaviour                      1.00    0.99      1.00     123.0
# Investigation and Exploration           1.00    0.99      0.99     273.0
# Social Conversation                     0.98    0.99      0.99     756.0
# Motivation                              0.97    1.00      0.98     288.0
# Observed Bug Behaviour                  0.88    1.00      0.93      50.0
# Potential New Issues and Requests       0.99    1.00      1.00     228.0
# Solution Discussion                     1.00    0.97      0.99    1367.0
# Task Progress                           0.98    1.00      0.99     125.0
# Solution Usage                          0.97    1.00      0.99     368.0
# Workarounds                             0.99    1.00      0.99      81.0
# Avg/Total                               0.99    0.99      0.99    4001.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       2.0
# Bug Reproduction                        0.33    0.13      0.19      38.0
# Contribution and Commitment             0.00    0.00      0.00       7.0
# Expected Behaviour                      0.00    0.00      0.00       1.0
# Investigation and Exploration           0.32    0.09      0.14     104.0
# Social Conversation                     0.32    0.55      0.41      42.0
# Motivation                              0.00    0.00      0.00       0.0
# Observed Bug Behaviour                  0.29    0.02      0.05      81.0
# Potential New Issues and Requests       0.00    0.00      0.00       2.0
# Solution Discussion                     0.12    0.48      0.19      44.0
# Task Progress                           0.00    0.00      0.00       0.0
# Solution Usage                          0.00    0.00      0.00       0.0
# Workarounds                             0.00    0.00      0.00       8.0
# Avg/Total                               0.27    0.18      0.15     329.0
#
# ------------------------- FOLD 13: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         1.00    1.00      1.00      61.0
# Bug Reproduction                        0.98    1.00      0.99     245.0
# Contribution and Commitment             1.00    1.00      1.00      76.0
# Expected Behaviour                      0.99    1.00      1.00     110.0
# Investigation and Exploration           0.99    0.98      0.99     374.0
# Social Conversation                     0.99    1.00      0.99     760.0
# Motivation                              0.98    1.00      0.99     255.0
# Observed Bug Behaviour                  0.94    1.00      0.97     131.0
# Potential New Issues and Requests       0.99    1.00      1.00     205.0
# Solution Discussion                     1.00    0.98      0.99    1288.0
# Task Progress                           0.98    1.00      0.99     120.0
# Solution Usage                          0.99    1.00      0.99     366.0
# Workarounds                             0.99    1.00      0.99      89.0
# Avg/Total                               0.99    0.99      0.99    4080.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.00    0.00      0.00       0.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       7.0
# Expected Behaviour                      0.00    0.00      0.00      14.0
# Investigation and Exploration           0.00    0.00      0.00       3.0
# Social Conversation                     0.62    0.55      0.58      38.0
# Motivation                              0.14    0.18      0.16      33.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00      25.0
# Solution Discussion                     0.50    0.64      0.56     123.0
# Task Progress                           0.00    0.00      0.00       5.0
# Solution Usage                          0.00    0.00      0.00       2.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.36    0.42      0.39     250.0
#
# ------------------------- FOLD 14: -------------------------
#
# Training Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.98    1.00      0.99      58.0
# Bug Reproduction                        0.98    1.00      0.99     245.0
# Contribution and Commitment             1.00    1.00      1.00      78.0
# Expected Behaviour                      1.00    1.00      1.00     121.0
# Investigation and Exploration           0.99    0.99      0.99     377.0
# Social Conversation                     0.98    0.99      0.99     784.0
# Motivation                              0.97    1.00      0.98     286.0
# Observed Bug Behaviour                  0.96    1.00      0.98     131.0
# Potential New Issues and Requests       0.99    1.00      1.00     229.0
# Solution Discussion                     1.00    0.97      0.98    1346.0
# Task Progress                           0.98    1.00      0.99     111.0
# Solution Usage                          0.99    1.00      0.99     367.0
# Workarounds                             0.99    1.00      0.99      89.0
# Avg/Total                               0.99    0.99      0.99    4222.0
#
# Test Results:
#                                    Precision  Recall  F1-score  Support
# Action on Issue                         0.67    0.67      0.67       3.0
# Bug Reproduction                        0.00    0.00      0.00       0.0
# Contribution and Commitment             0.00    0.00      0.00       5.0
# Expected Behaviour                      0.00    0.00      0.00       3.0
# Investigation and Exploration           0.00    0.00      0.00       0.0
# Social Conversation                     0.37    0.93      0.53      14.0
# Motivation                              0.00    0.00      0.00       2.0
# Observed Bug Behaviour                  0.00    0.00      0.00       0.0
# Potential New Issues and Requests       0.00    0.00      0.00       1.0
# Solution Discussion                     0.78    0.71      0.74      65.0
# Task Progress                           0.50    0.07      0.12      14.0
# Solution Usage                          0.00    0.00      0.00       1.0
# Workarounds                             0.00    0.00      0.00       0.0
# Avg/Total                               0.60    0.57      0.55     108.0

# %% [markdown]
# ### Get list of F1 scores and support-weighted average F1 score

# %%
avg_f1 = []
for i in range(0,15):
    avg_f1.append(float('%.4f' % round(clf1_results['test_avg_fscore'][i],4)))
    
print('Pipeline1:')
print(avg_f1)

sum = 0
den = 0
for i in range(0,15):
    sum += clf1_results['test_avg_fscore'][i] * clf1_results['test_total_support'][i]
    den += clf1_results['test_total_support'][i]
print('Pipeline1: Total weighted F-Score: '+('%.4f' % round(sum/den,4)))
# Out:
# Pipeline1:
# [0.5826, 0.2337, 0.2221, 0.3556, 0.6211, 0.2791, 0.4404, 0.1816, 0.1568, 0.3284, 0.2132, 0.5942, 0.1539, 0.3861, 0.55]
# Pipeline1: Total weighted F-Score: 0.3493
